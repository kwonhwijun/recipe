# %% [markdown]
# <a href="https://colab.research.google.com/github/kwonhwijun/recipe/blob/main/fin_recipe_009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd drive/My\ Drive/원/recipe/models
# Out:
# /content/drive/My Drive/원/recipe/models

# %%
# !pip install oracledb

# %% [markdown]
# ## Github 연동

# %%
# !git clone https://github.com/kwonhwijun/recipe
# Out:
# Cloning into 'recipe'...
# remote: Enumerating objects: 1059, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 1059 (delta 20), reused 31 (delta 11), pack-reused 1015
# Receiving objects: 100% (1059/1059), 61.99 MiB | 18.31 MiB/s, done.
# Resolving deltas: 100% (701/701), done.
# Updating files: 100% (141/141), done.

# %%
cd recipe
# Out:
# /content/drive/MyDrive/원/recipe

# %%
# !git config --global user.email 'julipup1122@gmail.com'
# !git config --global user.name 'JYL009'

# %%
cd models
# Out:
# /content/drive/MyDrive/원/recipe/models

# %% [markdown]
# ## 데이터 불러오기

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import recipe
import db
import svd

# %%
data = pd.read_csv('recipe.csv') #recipe raw 데이터 불러옴
data2 =  recipe.recipe_preprocessing(data) #레시피 전처리
data3 = recipe.split_ingredient(data2) #레시피 식재료 쪼개기
data4 = recipe.process_ingredient(data3) #레시피 식재료 패턴 처리
# Out:
# ...
#   0%|          | 0/74 [00:00<?, ?it/s]/content/drive/MyDrive/원/recipe/models/recipe.py:137: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dataframe[unit_col_name] = np.where(dataframe[col_name].notna() & dataframe[col_name].str.contains(pattern, regex=True), replacement, dataframe[unit_col_name])
# ...
# 100%|██████████| 74/74 [05:30<00:00,  4.47s/it]

# %%
data4
# Out:
#                               recipe_title  \
# 0                        호박 새우젓찌개 만드는 방법~★
# 1                             바글바글 전복 된장찌개
# 2        순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!
# 3                            정통 바지락 순두부 찌개
# 4                              크림토마토 비프 스튜
# ...                                    ...
# 166506  진리의 땅콩버터+바나나 조합! 살짝 구워 노릇노릇~바나나토스트
# 166507                      간단한 머쉬마루버섯 매운탕
# 166508                    우도주막 독일식 굴라쉬 도전♡
# 166509          우도주막 단호박 & 당근 스프 도전♡ (유태오)
# 166510                  고소하고 부드러운 감자스프 만들기
#
#                                        recipe_ingredients ingredient1  \
# 0       {'재료': ['둥근호박1개', '청양고추3개', '당근약간', '실파약간', '새...        둥근호박
# 1       {'재료': ['된장1스푼', '전복'], '부재료와 양념': ['양파1/2개', ...          된장
# 2       {'재료': ['순두부(연두부)', '바지락30g', '미더덕30g', '멸치육수(...         순두부
# 3       {'주재료': ['순두부1봉', '바지락100g', '양파50g', '애호박10g'...         순두부
# 4       {'주재료': ['쇠고기등심250g', '파프리카1개', '양파1/3개', '마늘2...       쇠고기등심
# ...

# %% [markdown]
# ## unit24까지만 뽑아서 써도 되는 이유

# %%
column_names = [f'ingredient{i}' for i in range(1, 75)]
num_ingre = data4[column_names].count(axis = 1)
plt.boxplot(num_ingre)
np.quantile(num_ingre, 0.995)
#식재료의 개수를 세보았을 때, 24개 정도만 추출을 해도 99.5%의 레시피가 남음 > 그래서 원데이터에서 식재료/양/단위 칼럼을 24까지만 뽑아서 사용할 것
# Out:
# 24.0

# %% [markdown]
# ## unit24까지만 사용하기 위해 뽑기

# %%
#패턴을 가진 열만 선택하는 함수 (여러 개의 패턴 입력 가능)
def extract_columns_with_patterns(dataframe, patterns, num_columns):
    selected_columns = [f"{pattern}{i}" for i in range(1, num_columns) for pattern in patterns]
    result_df = dataframe[selected_columns]
    return result_df

#'ingredient', 'quantity', 'unit' 패턴의 열만 추출 (총 25개씩)
result_df = extract_columns_with_patterns(data4, ['ingredient', 'quantity', 'unit'], 25)
#'recipe_title'도 뽑아서 합치기
title = data4['recipe_title']
last = pd.concat([title, result_df], axis=1)
last
# Out:
#                               recipe_title ingredient1 quantity1 unit1  \
# 0                        호박 새우젓찌개 만드는 방법~★        둥근호박         1     개
# 1                             바글바글 전복 된장찌개          된장         1    스푼
# 2        순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!         순두부            None
# 3                            정통 바지락 순두부 찌개         순두부         1     봉
# 4                              크림토마토 비프 스튜       쇠고기등심       250     g
# ...                                    ...         ...       ...   ...
# 166506  진리의 땅콩버터+바나나 조합! 살짝 구워 노릇노릇~바나나토스트         바나나         1     개
# 166507                      간단한 머쉬마루버섯 매운탕      광어서더리탕         1     팩
# 166508                    우도주막 독일식 굴라쉬 도전♡     한우소고기사태       250     g
# 166509          우도주막 단호박 & 당근 스프 도전♡ (유태오)         단호박       1/2     개
# 166510                  고소하고 부드러운 감자스프 만들기        삶은감자         4     개
#
#        ingredient2 quantity2 unit2 ingredient3 quantity3 unit3  ... unit21  \
# ...

# %%
#DataFrame 형태로 식재료만 뽑기
column_names = [f'ingredient{i}' for i in range(1, 25)]
use = last[column_names]
use
# Out:
#        ingredient1 ingredient2 ingredient3 ingredient4 ingredient5  \
# 0             둥근호박        청양고추          당근          실파         새우젓
# 1               된장          전복          양파        둥근호박          감자
# 2              순두부         바지락         미더덕        멸치육수        고추기름
# 3              순두부         바지락          양파         애호박      굵은고춧가루
# 4            쇠고기등심        파프리카          양파          마늘       새송이버섯
# ...            ...         ...         ...         ...         ...
# 166506         바나나          식빵        땅콩버터         NaN         NaN
# 166507      광어서더리탕      머쉬마루버섯          양파           무          대파
# 166508     한우소고기사태        올리브유        파프리카          양파        다진마늘
# 166509         단호박        제주당근          양파          버터       볶은천일염
# 166510        삶은감자          양파          우유           물        체다치즈
#
#        ingredient6 ingredient7 ingredient8 ingredient9 ingredient10  ...  \
# 0                물          연두          소금         NaN          NaN  ...
# ...

# %% [markdown]
# ## 식재료 뽑기

# %%
#list 형태로 ingredient만 뽑아내기
ingre = []
for i in range(1, 25):
    ingre_lis = use[f'ingredient{i}'].to_list()
    ingre.extend(ingre_lis)
ingre
# Out:
# ['둥근호박',
#  '된장',
#  '순두부',
#  '순두부',
#  '쇠고기등심',
#  '돼지고기',
#  '알래스카연어',
#  '간돼지고기',
#  '두부',
#  '돼지고기',
#  '돼지고기목살',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '닭안심살',
#  '물',
#  '돼지고기목살',
#  '돼지고기목살',
#  '양파',
#  '배추우거지',
#  '애호박',
#  '열무김치',
#  '오징어',
#  '생물주꾸미',
#  '소고기다짐',
#  '두부',
#  '닭가슴살',
#  '돼지고기앞다리',
#  '두부',
#  '돼지갈비',
#  '청국장',
#  '된장',
#  '닭가슴살',
#  '꾸미',
#  '훈제오리고기',
#  '감자',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '청정원멸치국물내기티백',
#  '햄',
#  '콩나물',
#  '조랭이떡',
#  '돼지갈비',
#  '감자큰거',
#  '삼겹살',
#  '호박',
#  '돼지고기목살',
#  '돼지고기',
#  '순두부',
#  '순두부',
#  '청국장',
#  '표고버섯',
#  '통조림햄',
#  '건표고버섯',
#  '돼지고기잡채용',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '고기불고기감',
#  '돼지고기',
#  '닭안심살',
#  '양파',
#  '돼지고기',
#  '돼지고기',
#  '파김치',
#  '호박오가리',
#  '소라',
#  '돼지고기',
#  '소고기',
#  '돼지고기',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '간돼지고기',
#  '크래미',
#  '두부',
#  '돼지고기',
#  '당면',
#  '쌀뜨물',
#  '신김치',
#  '목살돼지고기',
#  '닭',
#  '찐찰옥수수',
#  '파김치',
#  '돼지고기안심',
#  '두부',
#  '콩국물',
#  '아몬드',
#  '양배추',
#  '밥',
# ...

# %%
len(ingre)#156918 * 24
# Out:
# 3766032

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre)
df = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df[df['index'].isnull()].index
df.drop(nan_idx, inplace=True)
df.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#               index  count
# 698              소금  52521
# 13               양파  48906
# 305              설탕  48280
# 744            다진마늘  45994
# 1033            참기름  37997
# ...             ...    ...
# 23136      cj닭볶음탕양념      1
# 23137          무흰부분      1
# 23138        통조림햄스팸      1
# 23139       보일링크랩소스      1
# 51222  Darksoysauce      1
#
# [51222 rows x 2 columns]

# %%
#식재료 nan값 검사
df[df['index'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
#식재료 비어있는 값 검사 > 있긴 하지만 11번 나와서 50번 미만 날릴 때 어차피 날아감. 처리 당장 안 해도 괜찮다고 봄.
df[df['index']=='']
# Out:
#       index  count
# 22199           11

# %% [markdown]
# ## 50번 미만 나온 식재료들이 포함된 행을 제거하기 위한 작업

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx_50u = df[df['count'] < 50].sort_values(by='count', ascending=False)
find = idx_50u['index'].to_list()
len(find)
# Out:
# 49872

# %%
#성능 개선된 코드
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# find를 집합으로 변환
find_set = set(find)

# 10000개씩 그룹으로 나누어 처리
group_size = 10000
for i in tqdm(range(0, len(find), group_size)):
    subset_find = find[i:i + group_size]

    # 각 값을 하나씩 꺼내서 DataFrame과 비교 (벡터화된 연산 사용)
    matching_rows = use[use.isin(subset_find).any(axis=1)].index

    # 결과가 있다면 집합에 추가
    if not matching_rows.empty:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #79771 나옴!! 엄청 빠르네,,
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.63it/s]
# 79771

# %%
row_idx = list(set(last.index) - set(all_matching_rows)) #최종 리스트에 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(row_idx) #last - result (156918 - 79771)
# Out:
# 77147

# %%
minus50 = last.loc[row_idx].reset_index(drop=True) #삭제되어 77147개의 데이터만 남은 레시피 dataframe index 재설정
minus50
# Out:
#                             recipe_title ingredient1 quantity1 unit1  \
# 0                      호박 새우젓찌개 만드는 방법~★        둥근호박         1     개
# 1                      깊은맛 나는 미역국 끓이는 방법          미역         1     줌
# 2      순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!         순두부            None
# 3                           잡채 쉽게 만드는 방법          당면        10    인분
# 4                                   동래파전        부침가루       200     g
# ...                                  ...         ...       ...   ...
# 77142        검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵
# 77143             수요미식회 일본 쿠지라이식라면 만들기!!          라면         1    봉지
# 77144                   총각김치,배추김치볶음(신김치)         신김치         1    그릇
# 77145                          꽈리고추삼겹살볶음         삼겹살       300     g
# 77146               커피젤리 탱글탱글 향기로운 커피향~♥      인스턴트커피         2   숟가락
#
#       ingredient2 quantity2 unit2 ingredient3 quantity3 unit3  ... unit21  \
# ...

# %% [markdown]
# ## 식재료가 3개 이하인 애들은 날림

# %%
minus50[minus50['ingredient3'].isnull()] #식재료가 2개까지만 있는 레시피들
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 66        마손질법 ☆ 이것이 바로 산에서 나는 장어!           마            None         NaN
# 101                    옥수수 찜기에 찌는법         옥수수         3     개         NaN
# 102              단호박 담백하고 맛있게 찌는방법         단호박         1     개        종이호일
# 119           에어프라이어 요리 단호박 찌는법 굽기         단호박         1     개        종이호일
# 259            딸기와 토마토가 만났어요 생과일주스         토마토         1     개        냉동딸기
# ...                            ...         ...       ...   ...         ...
# 77080           북어포보관법 이렇게 보관하면 끝!         북어포            None         NaN
# 77081            제철주꾸미는 요렇게♡주꾸미손질법         주꾸미            None         밀가루
# 77137              프랑크소시지로 만든 동물농장      프랑크소시지            None         NaN
# 77138  늙은호박 오래오래 보관하고 먹어요! 늙은호박보관법        늙은호박         1     개         NaN
# 77143       수요미식회 일본 쿠지라이식라면 만들기!!          라면         1    봉지          계란
#
# ...

# %%
recipe_3 = minus50[minus50['ingredient4'].isnull()] #식재료가 3개까지만 있는 레시피들
recipe_3
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 20                 별미 중에 별미 열무김치찌개        열무김치       300     g          멸치
# 33                   바나나롤샌드위치 레시피!          식빵         2     장         바나나
# 66        마손질법 ☆ 이것이 바로 산에서 나는 장어!           마            None         NaN
# 88              미세먼지 나가!!♡방풍나물 손질법        방풍나물            None           물
# 101                    옥수수 찜기에 찌는법         옥수수         3     개         NaN
# ...                            ...         ...       ...   ...         ...
# 77134   [달걀요리대전] 호박으로 만든 호박계란말이!!!          달걀         8     개          호박
# 77137              프랑크소시지로 만든 동물농장      프랑크소시지            None         NaN
# 77138  늙은호박 오래오래 보관하고 먹어요! 늙은호박보관법        늙은호박         1     개         NaN
# 77143       수요미식회 일본 쿠지라이식라면 만들기!!          라면         1    봉지          계란
# 77144             총각김치,배추김치볶음(신김치)         신김치         1    그릇          설탕
#
# ...

# %%
del_idx = list(set(minus50.index) - set(recipe_3.index)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(del_idx) #minus50 - recipe_3 (77147 - 5495)
# Out:
# 71652

# %%
final = minus50.loc[del_idx].reset_index(drop=True) #71652개의 데이터만 남은 레시피 dataframe index 재설정
final
# Out:
#                             recipe_title ingredient1 quantity1 unit1  \
# 0                      호박 새우젓찌개 만드는 방법~★        둥근호박         1     개
# 1                      깊은맛 나는 미역국 끓이는 방법          미역         1     줌
# 2      순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!         순두부            None
# 3                           잡채 쉽게 만드는 방법          당면        10    인분
# 4                                   동래파전        부침가루       200     g
# ...                                  ...         ...       ...   ...
# 71647                          도토리묵사발!!!        도토리묵         1     팩
# 71648                            새우계란볶음밥          당근         1    조각
# 71649        검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵
# 71650                          꽈리고추삼겹살볶음         삼겹살       300     g
# 71651               커피젤리 탱글탱글 향기로운 커피향~♥      인스턴트커피         2   숟가락
#
#       ingredient2 quantity2 unit2 ingredient3 quantity3 unit3  ... unit21  \
# ...

# %% [markdown]
# ## dataframe 'final' 생성
# #### 식재료 50번 이상만 나온 걸로 구성되고, 레시피별 식재료가 4개 이상인 것만 뽑은 dataframe (final.csv 생성 성공!!!)

# %%
final
# Out:
#                             recipe_title ingredient1 quantity1 unit1  \
# 0                      호박 새우젓찌개 만드는 방법~★        둥근호박         1     개
# 1                      깊은맛 나는 미역국 끓이는 방법          미역         1     줌
# 2      순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!         순두부            None
# 3                           잡채 쉽게 만드는 방법          당면        10    인분
# 4                                   동래파전        부침가루       200     g
# ...                                  ...         ...       ...   ...
# 71647                          도토리묵사발!!!        도토리묵         1     팩
# 71648                            새우계란볶음밥          당근         1    조각
# 71649        검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵
# 71650                          꽈리고추삼겹살볶음         삼겹살       300     g
# 71651               커피젤리 탱글탱글 향기로운 커피향~♥      인스턴트커피         2   숟가락
#
#       ingredient2 quantity2 unit2 ingredient3 quantity3 unit3  ... unit21  \
# ...

# %%
#list 형태로 final df의 ingredient만 뽑아내기
ingre1 = []
for i in range(1, 25):
    ingre_lis = final[f'ingredient{i}'].to_list()
    ingre1.extend(ingre_lis)

#count해서 df화
from collections import Counter
cnt = Counter(ingre1)
df1 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df1[df1['index'].isnull()].index
df1.drop(nan_idx, inplace=True)
df1.sort_values(by='count', ascending=False) #내림차순 정렬

down50 = df1[df1['count'] < 50].sort_values(by='count', ascending=False)

idx50d = down50['index'].to_list()
len(idx50d)

import pandas as pd
from tqdm import tqdm
# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()
# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = final[final[col_name].isin(idx50d)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)
# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수

fin_idx = list(set(final.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(fin_idx) #minus50 - recipe_3 (71652 - 13869)

ffinal = final.loc[fin_idx].reset_index(drop=True) #57783개의 데이터만 남은 레시피 dataframe index 재설정
ffinal

# %%
#list 형태로 final df의 ingredient만 뽑아내기
ingre1 = []
for i in range(1, 25):
    ingre_lis = final[f'ingredient{i}'].to_list()
    ingre1.extend(ingre_lis)
ingre1
# Out:
# ['둥근호박',
#  '미역',
#  '순두부',
#  '당면',
#  '부침가루',
#  '삼겹살',
#  '두부',
#  '돼지고기',
#  '렌틸콩',
#  '꽁치통조림',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '닭안심살',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '레몬',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '돼지갈비',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '다짐육',
#  '소고기',
#  '삼겹살',
#  '삼겹살',
#  '햄',
#  '콩나물',
#  '조랭이떡',
#  '돼지갈비',
#  '감자큰거',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '양파',
#  '냉동만두',
#  '순두부',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '돼지고기잡채용',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '무',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '파김치',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '당면',
#  '돼지고기',
#  '신김치',
#  '오리훈제',
#  '불린쌀',
#  '잔멸치',
#  '파김치',
#  '애호박',
#  '두부',
#  '콩국물',
#  '아몬드',
#  '오징어',
#  '밥',
#  '당면',
#  '부추',
#  '달걀',
#  '계란',
#  '쇠고기',
#  '문어',
#  '마늘종',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre1)
df1 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df1[df1['index'].isnull()].index
df1.drop(nan_idx, inplace=True)
df1.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#              index  count
# 430             소금  25991
# 32              양파  25027
# 423             설탕  24987
# 422           다진마늘  24449
# 505            참기름  20444
# ...            ...    ...
# 1309         백설참기름      5
# 679             수수      4
# 979       다오네장아찌원액      4
# 1350           초코펜      4
# 1344  백설안달루시아산올리브유      2
#
# [1350 rows x 2 columns]

# %%
down50 = df1[df1['count'] < 50].sort_values(by='count', ascending=False)
down50
# 50번 미만인 애들이 생각보다 많음.. >> 일단 다 제거
# Out:
#              index  count
# 579          건크랜베리     49
# 293          소고기사태     49
# 1190         홍청양고추     49
# 715              청     49
# 349            가리비     49
# ...            ...    ...
# 1309         백설참기름      5
# 679             수수      4
# 979       다오네장아찌원액      4
# 1350           초코펜      4
# 1344  백설안달루시아산올리브유      2
#
# [563 rows x 2 columns]

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx50d = down50['index'].to_list()
len(idx50d)
# Out:
# 563

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = final[final[col_name].isin(idx50d)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 13869

# %%
fin_idx = list(set(final.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(fin_idx) #minus50 - recipe_3 (71652 - 13869)
# Out:
# 57783

# %%
ffinal = final.loc[fin_idx].reset_index(drop=True) #57783개의 데이터만 남은 레시피 dataframe index 재설정
ffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 57778                     사골 배추된장국          배추         1    포기        사골육수
# 57779                    도토리묵사발!!!        도토리묵         1     팩          계란
# 57780                      새우계란볶음밥          당근         1    조각          양파
# 57781  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 57782                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre2 = []
for i in range(1, 25):
    ingre_lis = ffinal[f'ingredient{i}'].to_list()
    ingre2.extend(ingre_lis)
ingre2
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '레몬',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '조랭이떡',
#  '돼지갈비',
#  '감자큰거',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '두부',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '양파',
#  '당근',
#  '감자',
#  '조기',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre2)
df2 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df2[df2['index'].isnull()].index
df2.drop(nan_idx, inplace=True)
df2.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#       index  count
# 328      소금  20724
# 354      설탕  20474
# 34       양파  20450
# 322    다진마늘  20378
# 370     참기름  17132
# ..      ...    ...
# 559  데친브로콜리     32
# 539  아몬드파우더     30
# 634    채썬양파     29
# 761     당근채     28
# 83     애플민트     23
#
# [787 rows x 2 columns]

# %%
down5050 = df2[df2['count'] < 50].sort_values(by='count', ascending=False)
down5050
# 50번 미만인 애들
# Out:
#       index  count
# 385     새송이     49
# 724      녹말     49
# 723   해바라기유     49
# 620      적채     48
# 750    들깻가루     48
# ..      ...    ...
# 559  데친브로콜리     32
# 539  아몬드파우더     30
# 634    채썬양파     29
# 761     당근채     28
# 83     애플민트     23
#
# [101 rows x 2 columns]

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx50 = down5050['index'].to_list()
len(idx50)
# Out:
# 101

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = ffinal[ffinal[col_name].isin(idx50)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 3988

# %%
ffin_idx = list(set(ffinal.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(ffin_idx) #minus50 - recipe_3 (57783 - 3988)
# Out:
# 53795

# %%
fffinal = ffinal.loc[ffin_idx].reset_index(drop=True) #53795개의 데이터만 남은 레시피 dataframe index 재설정
fffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 53790                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 53791                     사골 배추된장국          배추         1    포기        사골육수
# 53792                      새우계란볶음밥          당근         1    조각          양파
# 53793  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 53794                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre3 = []
for i in range(1, 25):
    ingre_lis = fffinal[f'ingredient{i}'].to_list()
    ingre3.extend(ingre_lis)
ingre3
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '두부',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre3)
df3 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df3[df3['index'].isnull()].index
df3.drop(nan_idx, inplace=True)
df3.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#       index  count
# 297    다진마늘  19308
# 31       양파  19171
# 303      소금  19140
# 412      설탕  19083
# 340     참기름  16165
# ..      ...    ...
# 560    크랜베리     42
# 453    강황가루     42
# 660  시나몬파우더     41
# 617    레드와인     40
# 411      흰자     35
#
# [686 rows x 2 columns]

# %%
down505050 = df3[df3['count'] < 50].sort_values(by='count', ascending=False)
down505050
# 50번 미만인 애들
# Out:
#       index  count
# 460  머쉬마루버섯     49
# 209   감자작은것     49
# 373      장어     49
# 377      죽순     49
# 383    갑오징어     49
# 672    소금살짝     48
# 247      콜라     48
# 272      단감     48
# 311     누룽지     48
# 611    후추살짝     48
# 400     김자반     48
# 589     이스트     48
# 492    시판된장     47
# 670    볶은소금     47
# 605     백설탕     47
# 501     깐마늘     47
# 78     메밀가루     47
# 327   홍파프리카     47
# 491  인스턴트커피     46
# 571   블랙올리브     46
# 355   생표고버섯     46
# 669   토마토케찹     46
# 478   만가닥버섯     45
# 191    찐고구마     45
# 362     불고기     45
# 678     올리브     45
# 235      게살     43
# 453    강황가루     42
# 560    크랜베리     42
# 660  시나몬파우더     41
# 617    레드와인     40
# 411      흰자     35

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx5050 = down505050['index'].to_list()
len(idx5050)
# Out:
# 32

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = fffinal[fffinal[col_name].isin(idx5050)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 1419

# %%
fffin_idx = list(set(fffinal.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(fffin_idx) #minus50 - recipe_3 (53795 - 1419)
# Out:
# 52376

# %%
ffffinal = fffinal.loc[fffin_idx].reset_index(drop=True) #53795개의 데이터만 남은 레시피 dataframe index 재설정
ffffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 52371                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 52372                     사골 배추된장국          배추         1    포기        사골육수
# 52373                      새우계란볶음밥          당근         1    조각          양파
# 52374  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 52375                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre4 = []
for i in range(1, 25):
    ingre_lis = ffffinal[f'ingredient{i}'].to_list()
    ingre4.extend(ingre_lis)
ingre4
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '두부',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre4)
df4 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df4[df4['index'].isnull()].index
df4.drop(nan_idx, inplace=True)
df4.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#       index  count
# 290    다진마늘  18953
# 31       양파  18676
# 296      소금  18568
# 394      설탕  18566
# 327     참기름  15829
# ..      ...    ...
# 591  허니머스터드     46
# 509    녹차가루     45
# 439       귤     45
# 388       빵     45
# 610    따뜻한물     41
#
# [654 rows x 2 columns]

# %%
down50505050 = df4[df4['count'] < 50].sort_values(by='count', ascending=False)
down50505050
# 50번 미만인 애들
# Out:
#           index  count
# 269         구운김     49
# 278          참외     49
# 403      애느타리버섯     49
# 499        차가운물     49
# 628        2배식초     49
# 137        마카로니     48
# 372       소고기등심     48
# 500       해바라기씨     48
# 634       메이플시럽     48
# 601  인스턴트드라이이스트     47
# 591      허니머스터드     46
# 388           빵     45
# 439           귤     45
# 509        녹차가루     45
# 610        따뜻한물     41

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx505050 = down50505050['index'].to_list()
len(idx505050)
# Out:
# 15

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = ffffinal[ffffinal[col_name].isin(idx505050)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 689

# %%
ffffin_idx = list(set(ffffinal.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(ffffin_idx) #minus50 - recipe_3 (52376 - 689)
# Out:
# 51687

# %%
fffffinal = ffffinal.loc[ffffin_idx].reset_index(drop=True) #53795개의 데이터만 남은 레시피 dataframe index 재설정
fffffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51682                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 51683                     사골 배추된장국          배추         1    포기        사골육수
# 51684                      새우계란볶음밥          당근         1    조각          양파
# 51685  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 51686                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre5 = []
for i in range(1, 25):
    ingre_lis = fffffinal[f'ingredient{i}'].to_list()
    ingre5.extend(ingre_lis)
ingre5
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
#  '남은치킨',
#  '닭',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre5)
df5 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df5[df5['index'].isnull()].index
df5.drop(nan_idx, inplace=True)
df5.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#         index  count
# 284      다진마늘  18832
# 31         양파  18498
# 389        설탕  18243
# 290        소금  18239
# 322       참기름  15703
# ..        ...    ...
# 439       육수팩     50
# 505      휘핑크림     50
# 319       메밀면     50
# 358       칼국수     49
# 613  홀그레인머스타드     49
#
# [639 rows x 2 columns]

# %%
down5050505050 = df5[df5['count'] < 50].sort_values(by='count', ascending=False)
down5050505050
# 50번 미만인 애들
# Out:
#         index  count
# 358       칼국수     49
# 613  홀그레인머스타드     49

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx50505050 = down5050505050['index'].to_list()
len(idx50505050)
# Out:
# 2

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = fffffinal[fffffinal[col_name].isin(idx50505050)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 98

# %%
fffffin_idx = list(set(fffffinal.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(fffffin_idx) #minus50 - recipe_3 (51687 - 98)
# Out:
# 51589

# %%
ffffffinal = fffffinal.loc[fffffin_idx].reset_index(drop=True) #53795개의 데이터만 남은 레시피 dataframe index 재설정
ffffffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51584                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 51585                     사골 배추된장국          배추         1    포기        사골육수
# 51586                      새우계란볶음밥          당근         1    조각          양파
# 51587  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 51588                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre6 = []
for i in range(1, 25):
    ingre_lis = ffffffinal[f'ingredient{i}'].to_list()
    ingre6.extend(ingre_lis)
ingre6
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
#  '남은치킨',
#  '닭',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre6)
df6 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df6[df6['index'].isnull()].index
df6.drop(nan_idx, inplace=True)
df6.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#      index  count
# 284   다진마늘  18800
# 31      양파  18451
# 387     설탕  18213
# 290     소금  18187
# 321    참기름  15692
# ..     ...    ...
# 626  마늘다진것     50
# 188    물만두     50
# 318    메밀면     50
# 438    육수팩     49
# 504   휘핑크림     49
#
# [637 rows x 2 columns]

# %%
down505050505050 = df6[df6['count'] < 50].sort_values(by='count', ascending=False)
down505050505050
# 50번 미만인 애들
# Out:
#     index  count
# 438   육수팩     49
# 504  휘핑크림     49

# %%
#50 미만인 식재료들의 index(식재료명)만 뽑아내기
idx5050505050 = down505050505050['index'].to_list()
len(idx5050505050)
# Out:
# 2

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'ingredient{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'ingredient{i}'
    matching_rows = ffffffinal[ffffffinal[col_name].isin(idx5050505050)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 96

# %%
ffffffin_idx = list(set(ffffffinal.index) - set(all_matching_rows)) #식재료가 3개까지만 있는 행 인덱스들을 레시피 데이터의 행 인덱스 리스트에서 삭제
len(ffffffin_idx) #minus50 - recipe_3 (51589 - 96)
# Out:
# 51493

# %%
fffffffinal = ffffffinal.loc[ffffffin_idx].reset_index(drop=True) #53795개의 데이터만 남은 레시피 dataframe index 재설정
fffffffinal
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51488                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 51489                     사골 배추된장국          배추         1    포기        사골육수
# 51490                      새우계란볶음밥          당근         1    조각          양파
# 51491  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 51492                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre7 = []
for i in range(1, 25):
    ingre_lis = fffffffinal[f'ingredient{i}'].to_list()
    ingre7.extend(ingre_lis)
ingre7
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
#  '남은치킨',
#  '닭',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre7)
df7 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df7[df7['index'].isnull()].index
df7.drop(nan_idx, inplace=True)
df7.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#      index  count
# 284   다진마늘  18764
# 31      양파  18406
# 387     설탕  18187
# 290     소금  18138
# 321    참기름  15687
# ..     ...    ...
# 379    백오이     50
# 624  마늘다진것     50
# 471    요거트     50
# 318    메밀면     50
# 188    물만두     50
#
# [635 rows x 2 columns]

# %%
down50505050505050 = df7[df7['count'] < 50].sort_values(by='count', ascending=False)
down50505050505050
# 50번 미만인 애들
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
import pandas as pd
from collections import Counter
from tqdm import tqdm

def process_data(final):
    i = 1
    while True:
        #'ingredient{i}' 열에서 식재료 추출 및 카운트
        ingre_list = []
        for j in tqdm(range(1, 25)):
            ingre_col = f'ingredient{j}'
            ingre_lis = final[ingre_col].to_list()
            ingre_list.extend(ingre_lis)

        #식재료 카운트 및 DataFrame 생성
        cnt = Counter(ingre_list)
        df = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()

        #NaN값 제거
        nan_idx = df[df['index'].isnull()].index
        df.drop(nan_idx, inplace=True)

        #카운트 기준으로 내림차순 정렬
        df = df.sort_values(by='count', ascending=False)

        #카운트가 50 미만인 식재료 추출
        down_50 = df[df['count'] < 50].sort_values(by='count', ascending=False)

        #카운트가 50 미만인 식재료가 없으면 반복문 종료
        if len(down_50) == 0:
            break

        #카운트가 50 미만인 식재료의 리스트 가져오기
        idx_50d = down_50['index'].to_list()

        #일치하는 행 찾아서 집합 업데이트
        all_matching_rows_set = set()
        for j in tqdm(range(1, 25)):
            col_name = f'ingredient{j}'
            matching_rows = final[final[col_name].isin(idx_50d)].index.tolist()
            if matching_rows:
                all_matching_rows_set.update(matching_rows)

        #일치하는 행의 리스트 가져오기
        all_matching_rows = list(all_matching_rows_set)

        #일치하는 행을 제외한 인덱스 업데이트
        final_idx = list(set(final.index) - set(all_matching_rows))

        #최종 DataFrame 업데이트
        final = final.loc[final_idx].reset_index(drop=True)

        #다음 반복을 위해 i 증가
        i += 1

    return final

final_result = process_data(final)
final_result
#실제로 직접 반복작업을 해보았을 때 7번 정도 이 반복해야 모든 식재료들이 50번 이상 나온 것들로만 구성되게 됨 > 이걸 함수형으로 간략화한 것
# Out:
# ...
# 100%|██████████| 24/24 [00:00<00:00, 521.00it/s]
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51488                    국물떡볶이 만들기        떡볶이떡            None          어묵
# 51489                     사골 배추된장국          배추         1    포기        사골육수
# 51490                      새우계란볶음밥          당근         1    조각          양파
# 51491  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 51492                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#list 형태로 ffinal df의 ingredient만 뽑아내기
ingre8 = []
for i in range(1, 25):
    ingre_lis = final_result[f'ingredient{i}'].to_list()
    ingre8.extend(ingre_lis)
ingre8
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
#  '남은치킨',
#  '닭',
# ...

# %%
#count해서 df화
from collections import Counter
cnt = Counter(ingre8)
df8 = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()
#NaN값 날리기
nan_idx = df8[df8['index'].isnull()].index
df8.drop(nan_idx, inplace=True)
df8.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#      index  count
# 284   다진마늘  18764
# 31      양파  18406
# 387     설탕  18187
# 290     소금  18138
# 321    참기름  15687
# ..     ...    ...
# 379    백오이     50
# 624  마늘다진것     50
# 471    요거트     50
# 318    메밀면     50
# 188    물만두     50
#
# [635 rows x 2 columns]

# %%
down5050505050505050 = df8[df8['count'] < 50].sort_values(by='count', ascending=False)
down5050505050505050
# 50번 미만인 애들
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
final_result.to_csv("final.csv", index=False) #식재료 50번 이상만 나온 걸로 구성되고, 레시피별 식재료가 4개 이상인 것만 뽑은 dataframe

# %% [markdown]
# ## unit(단위) 1번만 나온 거 처리 >> 아직 진행중

# %%
#unit만 뽑아내기
unit = []
for i in range(1, 25):
    data_u = final_result[f'unit{i}'].to_list()
    unit.extend(data_u)
unit
# Out:
# ['개',
#  '줌',
#  '인분',
#  'g',
#  '근',
#  None,
#  '마리',
#  None,
#  '봉지',
#  'g',
#  'g',
#  'g',
#  'g',
#  '마리',
#  'g',
#  'g',
#  'g',
#  'g',
#  '줌',
#  '모',
#  'g',
#  'T',
#  'Kg',
#  '마리',
#  'g',
#  None,
#  'g',
#  'g',
#  None,
#  'g',
#  '개',
#  '개',
#  None,
#  '개',
#  '팩',
#  '뿌리',
#  'g',
#  '인분',
#  None,
#  'g',
#  None,
#  '개',
#  None,
#  'g',
#  '쪽',
#  '개',
#  'g',
#  '줌',
#  '약간',
#  'g',
#  '장',
#  'g',
#  '조금',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  '줌',
#  '봉지',
#  'g',
#  'g',
#  None,
#  '컵',
#  'g정도',
#  '개',
#  '마리',
#  '공기',
#  'g',
#  '개',
#  '마리',
#  None,
#  'g',
#  '장',
#  '장',
#  '공기',
#  '개',
#  '개',
#  None,
#  None,
#  '공기',
#  '컵',
#  'g',
#  '적당량',
#  None,
#  'g',
#  'g',
#  'g',
#  'g',
#  '종이컵',
#  '줌',
#  None,
#  'g',
#  'g',
#  '컵',
#  '장',
#  'g',
#  None,
#  None,
#  '마리',
#  'T',
#  '조금',
#  '개',
#  'g',
#  '개',
#  None,
#  'kg',
#  None,
#  'g',
#  'g',
#  'T',
#  '마리',
#  None,
#  'g',
#  '알',
#  None,
#  '개',
#  '개',
#  '개',
# ...

# %%
from collections import Counter
import pandas as pd
unit_cnt = Counter(unit) #unit 종류 및 등장 횟수 계산
unit_df = pd.DataFrame.from_dict(unit_cnt, orient='index', columns=['count']).reset_index()
unit_df
# Out:
#      index  count
# 0        개  69608
# 1        줌   6499
# 2       인분   1241
# 3        g  30163
# 4        근    207
# ...    ...    ...
# 1252   개계란      1
# 1253  T소복히      1
# 1254     세      1
# 1255   양파즙      1
# 1256  g굴소스      1
#
# [1257 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = unit_df[unit_df['index'].isnull()].index
unit_df.drop(nan_idx, inplace=True)
unit_df
# Out:
#      index  count
# 0        개  69608
# 1        줌   6499
# 2       인분   1241
# 3        g  30163
# 4        근    207
# ...    ...    ...
# 1252   개계란      1
# 1253  T소복히      1
# 1254     세      1
# 1255   양파즙      1
# 1256  g굴소스      1
#
# [1255 rows x 2 columns]

# %%
unit_df.sort_values(by='count', ascending=False)
# Out:
#       index  count
# 0         개  69608
# 33       큰술  57303
# 9         T  49191
# 3         g  30163
# 14       약간  27107
# ...     ...    ...
# 747      춤큼      1
# 748     통마늘      1
# 284    ml감자      1
# 282   캔밥한공기      1
# 1256   g굴소스      1
#
# [1255 rows x 2 columns]

# %%
unit_df[unit_df['count'] == 1]
# Out:
#          index  count
# 38       장분량정도      1
# 40    모또는원하는만큼      1
# 42        호한마리      1
# 57        큰국그릇      1
# 60        덩이정도      1
# ...        ...    ...
# 1252       개계란      1
# 1253      T소복히      1
# 1254         세      1
# 1255       양파즙      1
# 1256      g굴소스      1
#
# [743 rows x 2 columns]

# %%
uni = unit_df[unit_df['count'] >= 2].sort_values(by='count', ascending=False)
uni
# Out:
#          index  count
# 0            개  69608
# 33          큰술  57303
# 9            T  49191
# 3            g  30163
# 14          약간  27107
# ..         ...    ...
# 395         동전      2
# 389          틈      2
# 374       Cm정도      2
# 767          양      2
# 408  원짜리동전크기만큼      2
#
# [512 rows x 2 columns]

# %%
uni['count'].sum() / unit_df['count'].sum()
# Out:
# 0.9981546378694139

# %%
#1번만 나온 단위들의 index만 뽑아내기
idx_1 = unit_df[unit_df['count'] == 1].sort_values(by='count', ascending=False)
uni_del = idx_1['index'].to_list()
len(uni_del)
# Out:
# 743

# %%
import pandas as pd
from tqdm import tqdm

# 일치하는 값을 저장할 집합 초기화
all_matching_rows_set = set()

# 'unit{i}' 열에서만 일치하는 값을 찾기
for i in range(1, 25):
    col_name = f'unit{i}'
    matching_rows = final[final[col_name].isin(uni_del)].index.tolist()
    if matching_rows:
        all_matching_rows_set.update(matching_rows)

# 결과를 리스트로 변환
all_matching_rows = list(all_matching_rows_set)
len(all_matching_rows) #1번만 나온 단위들이 포함된 행들의 개수
# Out:
# 834

# %%
# 특정 행 인덱스에 해당하는 행들의 값을 NaN으로 변경 >> 실패 >> 나중에 다시 작업할 예정
final_ex = final.loc[all_matching_rows, :] = np.nan
final_ex
# Out:
# nan

# %% [markdown]
# ## Ingredient 분석 (~unit24)

# %%
#ingredient만 뽑아내기
ingred = []
for i in range(1, 25):
    ingre_lis = last[f'ingredient{i}'].to_list()
    ingred.extend(ingre_lis)
ingred
# Out:
# ['둥근호박',
#  '된장',
#  '순두부',
#  '순두부',
#  '쇠고기등심',
#  '돼지고기',
#  '알래스카연어',
#  '간돼지고기',
#  '두부',
#  '돼지고기',
#  '돼지고기목살',
#  '낙지',
#  '닭가슴살',
#  '낙지',
#  '닭안심살',
#  '물',
#  '돼지고기목살',
#  '돼지고기목살',
#  '양파',
#  '배추우거지',
#  '애호박',
#  '열무김치',
#  '오징어',
#  '생물주꾸미',
#  '소고기다짐',
#  '두부',
#  '닭가슴살',
#  '돼지고기앞다리',
#  '두부',
#  '돼지갈비',
#  '청국장',
#  '된장',
#  '닭가슴살',
#  '꾸미',
#  '훈제오리고기',
#  '감자',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '청정원멸치국물내기티백',
#  '햄',
#  '콩나물',
#  '조랭이떡',
#  '돼지갈비',
#  '감자큰거',
#  '삼겹살',
#  '호박',
#  '돼지고기목살',
#  '돼지고기',
#  '순두부',
#  '순두부',
#  '청국장',
#  '표고버섯',
#  '통조림햄',
#  '건표고버섯',
#  '돼지고기잡채용',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '고기불고기감',
#  '돼지고기',
#  '닭안심살',
#  '양파',
#  '돼지고기',
#  '돼지고기',
#  '파김치',
#  '호박오가리',
#  '소라',
#  '돼지고기',
#  '소고기',
#  '돼지고기',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '간돼지고기',
#  '크래미',
#  '두부',
#  '돼지고기',
#  '당면',
#  '쌀뜨물',
#  '신김치',
#  '목살돼지고기',
#  '닭',
#  '찐찰옥수수',
#  '파김치',
#  '돼지고기안심',
#  '두부',
#  '콩국물',
#  '아몬드',
#  '양배추',
#  '밥',
# ...

# %%
len(ingred) #156918*24
# Out:
# 3766032

# %%
#count해서 df화 + NaN값 날리기
from collections import Counter
cnt = Counter(ingred)
df_ingred = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()

nan_idx = df_ingred[df_ingred['index'].isnull()].index
df_ingred.drop(nan_idx, inplace=True)
df_ingred.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#               index  count
# 698              소금  52521
# 13               양파  48906
# 305              설탕  48280
# 744            다진마늘  45994
# 1033            참기름  37997
# ...             ...    ...
# 23136      cj닭볶음탕양념      1
# 23137          무흰부분      1
# 23138        통조림햄스팸      1
# 23139       보일링크랩소스      1
# 51222  Darksoysauce      1
#
# [51222 rows x 2 columns]

# %%
df_ingred[df_ingred['index'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
df_ingred[df_ingred['count'] == 1]
# Out:
#               index  count
# 18            생물주꾸미      1
# 23               꾸미      1
# 28      청정원멸치국물내기티백      1
# 50           목살돼지고기      1
# 58          흙애서꿀고구마      1
# ...             ...    ...
# 51218      딸기쨈이나다른쨈      1
# 51219    포도씨유or올리브유      1
# 51220        레몬껍질소량      1
# 51221         갈릭드레싱      1
# 51222  Darksoysauce      1
#
# [34526 rows x 2 columns]

# %%
df_ingred[df_ingred['count'] >= 50]
#40: 1560개, 30: 1858개, 20: 2422개, 10: 3956개, 5: 6749개, 4: 8224개, 3: 10778개, 2: 16696개
# Out:
#          index  count
# 0         둥근호박    126
# 1           된장   7445
# 2          순두부    888
# 4         돼지고기   3312
# 6        간돼지고기    237
# ...        ...    ...
# 29001    다시마가루     63
# 29479  소금기호에맞게     57
# 29516      부침유     82
# 29844      깻가루     64
# 30994   후추가루아주     50
#
# [1350 rows x 2 columns]

# %%
df_ingred['count'].sum()
# Out:
# 1440172

# %%
#                            SUM 값           비율
df1 = df_ingred[df_ingred['count'] >= 50] #1308552   0.9086081384723491
df2 = df_ingred[df_ingred['count'] >= 40] #1317884   0.9150879200539935
df3 = df_ingred[df_ingred['count'] >= 30] #1327953   0.9220794460661643
df4 = df_ingred[df_ingred['count'] >= 20] #1341556   0.9315248456434371
df5 = df_ingred[df_ingred['count'] >= 10] #1362192   0.945853689698175
df6 = df_ingred[df_ingred['count'] >= 5] #1380248    0.9583910810653172
df7 = df_ingred[df_ingred['count'] >= 4] #1386148    0.9624878139555553
df8 = df_ingred[df_ingred['count'] >= 3] #1393810    0.9678080118208103
df9 = df_ingred[df_ingred['count'] >= 2] #1405646    0.976026474615532
df10 = df_ingred[df_ingred['count'] >= 1] #1440172   1.0

# %%
df10['count'].sum() / df_ingred['count'].sum()
# Out:
# 1.0

# %% [markdown]
# ## Ingredient 분석 (final.csv)

# %%
load = pd.read_csv('final.csv') #최종 데이터 불러옴
# Out:
# <ipython-input-9-f109271b3455>:1: DtypeWarning: Columns (62,65,68,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   load = pd.read_csv('final.csv') #최종 데이터 불러옴

# %%
load
# Out:
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51488                    국물떡볶이 만들기        떡볶이떡       NaN   NaN          어묵
# 51489                     사골 배추된장국          배추         1    포기        사골육수
# 51490                      새우계란볶음밥          당근         1    조각          양파
# 51491  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩         2     컵          소면
# 51492                    꽈리고추삼겹살볶음         삼겹살       300     g        꽈리고추
#
# ...

# %%
#ingredient만 뽑아내기
ing = []
for i in range(1, 25):
    ing_lis = load[f'ingredient{i}'].to_list()
    ing.extend(ing_lis)
ing
# Out:
# ['둥근호박',
#  '미역',
#  '당면',
#  '부침가루',
#  '돼지고기',
#  '꽁치통조림',
#  '낙지',
#  '낙지',
#  '꽈리고추',
#  '돼지고기목살',
#  '돼지고기목살',
#  '돼지고기',
#  '감자',
#  '오징어',
#  '소고기',
#  '소고기국거리',
#  '고구마',
#  '닭가슴살',
#  '시금치',
#  '두부',
#  '떡',
#  '된장',
#  '닭가슴살',
#  '오징어',
#  '스팸',
#  '두부',
#  '소고기',
#  '삼겹살',
#  '햄',
#  '돼지갈비',
#  '감자',
#  '호박',
#  '돼지고기목살',
#  '냉동만두',
#  '청국장',
#  '우엉',
#  '소고기',
#  '대패삼겹살',
#  '떡국떡',
#  '당면',
#  '동태',
#  '감자',
#  '된장',
#  '돼지고기',
#  '김치',
#  '양파',
#  '돼지고기',
#  '베이컨',
#  '베이컨',
#  '돼지고기',
#  '돈까스',
#  '어묵',
#  '다시마',
#  '돼지고기다짐육',
#  '콩나물',
#  '멸치',
#  '소고기',
#  '쇠고기',
#  '쑥',
#  '순두부',
#  '돼지고기',
#  '돼지고기',
#  '신김치',
#  '불린쌀',
#  '잔멸치',
#  '애호박',
#  '오징어',
#  '밥',
#  '당면',
#  '달걀',
#  '문어',
#  '마늘종',
#  '연근',
#  '묵은지',
#  '김밥용김',
#  '밥',
#  '애호박',
#  '바나나',
#  '깻잎',
#  '감자',
#  '밥',
#  '찹쌀가루',
#  '꽈리고추',
#  '당근',
#  '감자',
#  '매생이',
#  '밀떡',
#  '묵은지',
#  '아욱',
#  '김치',
#  '당면',
#  '파래',
#  '느타리버섯',
#  '김치',
#  '떡볶이떡',
#  '베이컨',
#  '닭다리살',
#  '김치',
#  '남은치킨',
#  '닭',
# ...

# %%
len(ing)
# Out:
# 1235832

# %%
#count해서 df화 + NaN값 날리기
from collections import Counter
cnt = Counter(ing)
df_ing = pd.DataFrame.from_dict(cnt, orient='index', columns=['count']).reset_index()

nan_idx = df_ing[df_ing['index'].isnull()].index
df_ing.drop(nan_idx, inplace=True)
df_ing.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#      index  count
# 284   다진마늘  18764
# 31      양파  18406
# 387     설탕  18187
# 290     소금  18138
# 321    참기름  15687
# ..     ...    ...
# 379    백오이     50
# 624  마늘다진것     50
# 471    요거트     50
# 318    메밀면     50
# 188    물만두     50
#
# [635 rows x 2 columns]

# %%
df_ing[df_ing['index'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
df_ing[df_ing['count'] < 50]
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
df_ing['count'].sum()
# Out:
# 459334

# %%
df_ingred['count'].sum()
# Out:
# 1440172

# %%
df_ing['count'].sum() / df_ingred['count'].sum()
# Out:
# 0.31894384837366646

# %% [markdown]
# ## Quantity 분석 (~unit24)

# %%
#quantity만 뽑아내기
quant = []
for i in range(1, 25):
    data_q = last[f'quantity{i}'].to_list()
    quant.extend(data_q)
quant
# Out:
# ['1',
#  '1',
#  '',
#  '1',
#  '250',
#  '100',
#  '1',
#  '1',
#  '2',
#  '1',
#  '',
#  '1',
#  '3',
#  '',
#  '5-6',
#  '500',
#  '600',
#  '700',
#  '1/4',
#  '2',
#  '1/3',
#  '300',
#  '2',
#  '20',
#  '1',
#  '340',
#  '300',
#  '1',
#  '1/2',
#  '600',
#  '1',
#  '1+1/2',
#  '1',
#  '8',
#  '300',
#  '1',
#  '',
#  '100',
#  '1+1/2',
#  '1',
#  '',
#  '300',
#  '350',
#  '600',
#  '1',
#  '500',
#  '1/3',
#  '',
#  '200',
#  '',
#  '1',
#  '1',
#  '7',
#  '1/2',
#  '1/4',
#  '150',
#  '500',
#  '',
#  '1',
#  '',
#  '300',
#  '270',
#  '3-4',
#  '1',
#  '600',
#  '400',
#  '',
#  '100',
#  '1',
#  '150',
#  '200',
#  '',
#  '',
#  '150',
#  '300',
#  '400',
#  '400',
#  '200',
#  '1',
#  '1',
#  '250',
#  '250',
#  '2.5',
#  '',
#  '250',
#  '1',
#  '2',
#  '',
#  '300',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '200',
#  '2',
#  '8',
#  '5',
#  '3',
#  '1',
#  '1',
#  '2',
#  '1/5',
#  '1',
#  '100',
#  '1',
#  '1',
#  '1',
#  '2',
#  '',
#  '',
#  '2',
#  '170',
# ...

# %%
from collections import Counter
import pandas as pd
quant_cnt = Counter(quant) #quantity 종류 및 등장 횟수 계산
quant_df = pd.DataFrame.from_dict(quant_cnt, orient='index', columns=['count']).reset_index()
quant_df
# Out:
#          index   count
# 0            1  394376
# 1               309360
# 2          250    4142
# 3          100   18756
# 4            2  174648
# ...        ...     ...
# 1570      -1~2       1
# 1571      1680       1
# 1572  800-1000       1
# 1573     19-20       1
# 1574      14.6       1
#
# [1575 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = quant_df[quant_df['index'].isnull()].index
quant_df.drop(nan_idx, inplace=True)
quant_df
# Out:
#          index   count
# 0            1  394376
# 1               309360
# 2          250    4142
# 3          100   18756
# 4            2  174648
# ...        ...     ...
# 1570      -1~2       1
# 1571      1680       1
# 1572  800-1000       1
# 1573     19-20       1
# 1574      14.6       1
#
# [1574 rows x 2 columns]

# %%
quant_df.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#         index   count
# 0           1  394376
# 1              309360
# 4           2  174648
# 15        1/2  115093
# 5           3   71652
# ...       ...     ...
# 1119    133.6       1
# 613       1~5       1
# 612     22-23       1
# 608   500~800       1
# 1574     14.6       1
#
# [1574 rows x 2 columns]

# %%
blank = quant_df[quant_df['index'] == ''] #인덱스가 빈칸인 경우
blank
# Out:
#   index   count
# 1        309360

# %% [markdown]
# ## Quantity 분석 (final.csv)

# %%
#quantity만 뽑아내기
qua = []
for i in range(1, 25):
    data_q = load[f'quantity{i}'].to_list()
    qua.extend(data_q)
qua
# Out:
# ['1',
#  '1',
#  '10',
#  '200',
#  '1',
#  nan,
#  '1',
#  nan,
#  '2',
#  '600',
#  '700',
#  '300',
#  '300',
#  '2',
#  '300',
#  '300',
#  '300',
#  '300',
#  '1',
#  '1/2',
#  '400',
#  '1+1/2',
#  '1',
#  '1',
#  '200',
#  nan,
#  '100',
#  '600',
#  nan,
#  '600',
#  '6',
#  '1/3',
#  nan,
#  '8',
#  '1',
#  '2',
#  '250',
#  '4',
#  nan,
#  '500',
#  nan,
#  '1',
#  nan,
#  '270',
#  '1',
#  '1',
#  '600',
#  '1',
#  nan,
#  '150',
#  '1',
#  '200',
#  nan,
#  '150',
#  '300',
#  '400',
#  '400',
#  '200',
#  '2',
#  '1',
#  '250',
#  '300',
#  nan,
#  '1',
#  '300',
#  '1',
#  '1',
#  '1',
#  '50',
#  '2',
#  '1',
#  nan,
#  '320',
#  '8',
#  '3',
#  '1',
#  '1',
#  '2',
#  nan,
#  nan,
#  '2',
#  '1',
#  '100',
#  nan,
#  nan,
#  '200',
#  '300',
#  '100',
#  '50',
#  '1/2',
#  '1',
#  nan,
#  '200',
#  '250',
#  '2',
#  '9',
#  '500',
#  nan,
#  nan,
#  '1',
#  '7',
#  '1',
#  '3',
#  '200',
#  '1/2',
#  nan,
#  '1',
#  nan,
#  '250',
#  '30',
#  '2',
#  '5',
#  nan,
# ...

# %%
from collections import Counter
import pandas as pd
qua_cnt = Counter(qua) #quantity 종류 및 등장 횟수 계산
qua_df = pd.DataFrame.from_dict(qua_cnt, orient='index', columns=['count']).reset_index()
qua_df
# Out:
#       index   count
# 0         1  135768
# 1        10    3892
# 2       200    4490
# 3       NaN  848119
# 4         2   57702
# ...     ...     ...
# 24172   NaN       1
# 24173   NaN       1
# 24174   NaN       1
# 24175   NaN       1
# 24176   NaN       1
#
# [24177 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = qua_df[qua_df['index'].isnull()].index
qua_df.drop(nan_idx, inplace=True)
qua_df.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
#        index   count
# 0          1  135768
# 4          2   57702
# 8        1/2   41176
# 22         3   23434
# 16         4   10426
# ...      ...     ...
# 489      930       1
# 486     1560       1
# 483      406       1
# 481    2.2/3       1
# 15217   50.0       1
#
# [818 rows x 2 columns]

# %%
blaank = qua_df[qua_df['index'] == ''] #인덱스가 빈칸인 경우
blaank
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %% [markdown]
# ## Unit 분석 (~unit24)

# %%
#unit만 뽑아내기
unit = []
for i in range(1, 25):
    data_u = last[f'unit{i}'].to_list()
    unit.extend(data_u)
unit
# Out:
# ['개',
#  '스푼',
#  None,
#  '봉',
#  'g',
#  'g',
#  '개',
#  '컵',
#  '모',
#  '근',
#  None,
#  '마리',
#  '쪽',
#  None,
#  '쪽',
#  'ml',
#  'g',
#  'g',
#  '개',
#  '컵',
#  '개',
#  'g',
#  '마리',
#  '마리',
#  '쪽',
#  'g',
#  'g',
#  'kg',
#  '모',
#  'g',
#  '덩어리',
#  'T',
#  'Kg',
#  '마리',
#  'g',
#  '개',
#  None,
#  'g',
#  '근',
#  '봉',
#  None,
#  'g',
#  'g',
#  'g',
#  '개',
#  '그램',
#  '개',
#  None,
#  'g',
#  None,
#  '봉지',
#  '팩',
#  '개',
#  '통',
#  '컵',
#  'g',
#  'g',
#  None,
#  '개',
#  None,
#  'g',
#  'g',
#  '쪽',
#  '개',
#  'g',
#  'g',
#  None,
#  'g',
#  '웅큼',
#  'g',
#  'g',
#  None,
#  '조금',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  '줄',
#  '모',
#  'g',
#  'g',
#  '종이컵',
#  None,
#  'g',
#  '마리',
#  '개',
#  None,
#  'g',
#  '모',
#  '가지적당량',
#  '줌',
#  '조각',
#  '공기',
#  '개',
#  'g',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '마리',
#  '줌',
#  '단',
#  '줌',
#  'g',
#  '개',
#  '공기',
#  '개',
#  '개',
#  None,
#  None,
#  '공기',
#  'g',
#  '공기',
#  '컵',
#  '모',
#  '개',
#  '개',
# ...

# %%
from collections import Counter
import pandas as pd
unit_cnt = Counter(unit) #unit 종류 및 등장 횟수 계산
unit_df = pd.DataFrame.from_dict(unit_cnt, orient='index', columns=['count']).reset_index()
unit_df
# Out:
#           index   count
# 0             개  218468
# 1            스푼   51590
# 2          None  188589
# 3             봉    3338
# 4             g  135843
# ...         ...     ...
# 3838  t넣어체에걸러두기       1
# 3839       g굴소스       1
# 3840       센치한줌       1
# 3841       정도이상       1
# 3842      큰술물약간       1
#
# [3843 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = unit_df[unit_df['index'].isnull()].index
unit_df.drop(nan_idx, inplace=True)
unit_df
# Out:
#           index   count
# 0             개  218468
# 1            스푼   51590
# 3             봉    3338
# 4             g  135843
# 5             컵   54723
# ...         ...     ...
# 3838  t넣어체에걸러두기       1
# 3839       g굴소스       1
# 3840       센치한줌       1
# 3841       정도이상       1
# 3842      큰술물약간       1
#
# [3841 rows x 2 columns]

# %%
unit_df.sort_values(by='count', ascending=False)
# Out:
#        index   count
# 0          개  218468
# 42        큰술  169521
# 4          g  135843
# 13         T  121518
# 94        약간   82732
# ...      ...     ...
# 1871     g대략       1
# 1873  큰술이안되게       1
# 1874      개의       1
# 1877    g섞은것       1
# 3842   큰술물약간       1
#
# [3841 rows x 2 columns]

# %%
unit_df[unit_df['count'] == 1]
# Out:
#           index  count
# 23        가지적당량      1
# 44          중력분      1
# 47     모또는원하는만큼      1
# 50       호사이즈한판      1
# 69       아몬드브리즈      1
# ...         ...    ...
# 3838  t넣어체에걸러두기      1
# 3839       g굴소스      1
# 3840       센치한줌      1
# 3841       정도이상      1
# 3842      큰술물약간      1
#
# [2496 rows x 2 columns]

# %%
unit_df[unit_df['count'] >= 2].sort_values(by='count', ascending=False)
# Out:
#      index   count
# 0        개  218468
# 42      큰술  169521
# 4        g  135843
# 13       T  121518
# 94      약간   82732
# ...    ...     ...
# 1498   노랑각       2
# 1496   진만큼       2
# 1495  인분가량       2
# 1485  뿌리이상       2
# 3833   개썬것       2
#
# [1345 rows x 2 columns]

# %%
uni = unit_df[unit_df['count'] >= 2]
uni['count'].sum() / unit_df['count'].sum()
# Out:
# 0.9980057255491646

# %% [markdown]
# ## Unit 분석 (final.csv)

# %%
#unit만 뽑아내기
un = []
for i in range(1, 25):
    data_u = load[f'unit{i}'].to_list()
    un.extend(data_u)
un
# Out:
# ['개',
#  '줌',
#  '인분',
#  'g',
#  '근',
#  nan,
#  '마리',
#  nan,
#  '봉지',
#  'g',
#  'g',
#  'g',
#  'g',
#  '마리',
#  'g',
#  'g',
#  'g',
#  'g',
#  '줌',
#  '모',
#  'g',
#  'T',
#  'Kg',
#  '마리',
#  'g',
#  nan,
#  'g',
#  'g',
#  nan,
#  'g',
#  '개',
#  '개',
#  nan,
#  '개',
#  '팩',
#  '뿌리',
#  'g',
#  '인분',
#  nan,
#  'g',
#  nan,
#  '개',
#  nan,
#  'g',
#  '쪽',
#  '개',
#  'g',
#  '줌',
#  '약간',
#  'g',
#  '장',
#  'g',
#  '조금',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  '줌',
#  '봉지',
#  'g',
#  'g',
#  nan,
#  '컵',
#  'g정도',
#  '개',
#  '마리',
#  '공기',
#  'g',
#  '개',
#  '마리',
#  nan,
#  'g',
#  '장',
#  '장',
#  '공기',
#  '개',
#  '개',
#  nan,
#  nan,
#  '공기',
#  '컵',
#  'g',
#  '적당량',
#  nan,
#  'g',
#  'g',
#  'g',
#  'g',
#  '종이컵',
#  '줌',
#  nan,
#  'g',
#  'g',
#  '컵',
#  '장',
#  'g',
#  nan,
#  nan,
#  '마리',
#  'T',
#  '조금',
#  '개',
#  'g',
#  '개',
#  nan,
#  'kg',
#  nan,
#  'g',
#  'g',
#  'T',
#  '마리',
#  nan,
#  'g',
#  '알',
#  nan,
#  '개',
#  '개',
#  '개',
#  '캔',
#  'g',
# ...

# %%
from collections import Counter
import pandas as pd
un_cnt = Counter(un) #unit 종류 및 등장 횟수 계산
un_df = pd.DataFrame.from_dict(un_cnt, orient='index', columns=['count']).reset_index()
un_df
# Out:
#      index  count
# 0        개  69608
# 1        줌   6499
# 2       인분   1241
# 3        g  30163
# 4        근    207
# ...    ...    ...
# 1251   개계란      1
# 1252  T소복히      1
# 1253     세      1
# 1254   양파즙      1
# 1255  g굴소스      1
#
# [1256 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = un_df[un_df['index'].isnull()].index
un_df.drop(nan_idx, inplace=True)
un_df.sort_values(by='count', ascending=False)
# Out:
#       index  count
# 0         개  69608
# 33       큰술  57303
# 9         T  49191
# 3         g  30163
# 14       약간  27107
# ...     ...    ...
# 747      춤큼      1
# 748     통마늘      1
# 284    ml감자      1
# 282   캔밥한공기      1
# 1255   g굴소스      1
#
# [1255 rows x 2 columns]

# %%
un_df[un_df['count'] <= 2]
# Out:
#          index  count
# 38       장분량정도      1
# 40    모또는원하는만큼      1
# 42        호한마리      1
# 53          인치      2
# 57        큰국그릇      1
# ...        ...    ...
# 1251       개계란      1
# 1252      T소복히      1
# 1253         세      1
# 1254       양파즙      1
# 1255      g굴소스      1
#
# [878 rows x 2 columns]

# %%
un_df[un_df['count'] >= 5].sort_values(by='count', ascending=False)
# Out:
#      index  count
# 0        개  69608
# 33      큰술  57303
# 9        T  49191
# 3        g  30163
# 14      약간  27107
# ..     ...    ...
# 865     고집      5
# 811    ml등      5
# 796   번톡톡톡      5
# 803     우유      5
# 460  cm한토막      5
#
# [269 rows x 2 columns]

# %%
uni = un_df[un_df['count'] >= 4]
uni['count'].sum() / un_df['count'].sum()
# Out:
# 0.9969773812746658

# %% [markdown]
# ## 유사한 식재료 합치기

# %%
from collections import Counter

def merge_strings(strings):
    result = []

    for s1 in strings:
        merged = False

        for group in result:
            for s2 in group:
                if s1 in s2 or s2 in s1:
                    group.add(s1)
                    group.add(s2)
                    merged = True
                    break

            if merged:
                break

        if not merged:
            result.append({s1})

    # Convert sets to lists for further processing
    result_lists = [list(group) for group in result]

    # Extract most common words and create a dictionary
    result_dict = {}
    for group in result_lists:
        merged_string = ' '.join(group)
        words = merged_string.split()
        word_counts = Counter(words)
        most_common_word = word_counts.most_common(1)
        if most_common_word:
            result_dict[most_common_word[0][0]] = group

    return result_dict

# 문자열을 묶고 가장 자주 등장한 단어를 key로 하는 딕셔너리를 얻음
result_dict = merge_strings(ing)

# 결과 출력
for key, value in result_dict.items():
    print(f"{key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-aeac053c2fd9> in <cell line: 39>()
#      37
#      38 # 문자열을 묶고 가장 자주 등장한 단어를 key로 하는 딕셔너리를 얻음
# ---> 39 result_dict = merge_strings(ing)
#      40
#      41 # 결과 출력
#
# <ipython-input-51-aeac053c2fd9> in merge_strings(strings)
#       9         for group in result:
#      10             for s2 in group:
# ---> 11                 if s1 in s2 or s2 in s1:
#      12                     group.add(s1)
#      13                     group.add(s2)
#
# TypeError: 'in <string>' requires string as left operand, not float

# %%
from collections import Counter

def merge_strings(strings):
    result = []

    for s1 in strings:
        merged = False

        for group in result:
            for s2 in group:
                if s1 in s2 or s2 in s1:
                    group.add(s1)
                    group.add(s2)
                    merged = True
                    break

            if merged:
                break

        if not merged:
            result.append({s1})

    # Convert sets to lists for further processing
    result_lists = [list(group) for group in result]

    # Extract all common words and create a dictionary
    result_dict = {}
    for group in result_lists:
        merged_string = ' '.join(group)
        words = merged_string.split()
        word_counts = Counter(words)
        most_common_words = [word[0] for word in word_counts.items() if word[1] == max(word_counts.values())]
        for common_word in most_common_words:
            if common_word in result_dict:
                result_dict[common_word].extend(group)
            else:
                result_dict[common_word] = group

    return result_dict

# 문자열을 묶고 가장 자주 등장한 단어를 key로 하는 딕셔너리를 얻음
result_dict = merge_strings(ddf)

# 결과 출력
for key, value in result_dict.items():
    print(f"{key}: {value}")
# Out:
# 단호박: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 호박고구마: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 호박: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 둥근호박: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 늙은호박: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 된장: ['된장']
# 순두부: ['순두부', '두부']
# 두부: ['순두부', '두부']
# 간돼지고기: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기잡채용: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기다짐육: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기안심: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기목살: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 돼지고기앞다리: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 낙지: ['낙지']
# 닭봉: ['닭봉', '닭', '닭가슴살']
# 닭: ['닭봉', '닭', '닭가슴살']
# 닭가슴살: ['닭봉', '닭', '닭가슴살']
# 닭안심살: ['닭안심살']
# 물: ['물', '콩국물', '쌀뜨물', '콩나물']
# ...

# %%
def merge_strings(strings):
    result = []

    for s1 in strings:
        merged = False

        for group in result:
            for s2 in group:
                if s1 in s2 or s2 in s1:
                    group.add(s1)
                    group.add(s2)
                    merged = True
                    break

            if merged:
                break

        if not merged:
            result.append({s1})

    # Convert sets to lists for further processing
    result_lists = [list(group) for group in result]

    # Extract all common words and create a dictionary
    result_dict = {}
    for group in result_lists:
        merged_string = ' '.join(group)
        words = merged_string.split()
        word_counts = Counter(words)
        min_length_word = min(word_counts, key=lambda x: (len(x), x))
        result_dict[min_length_word] = group

    return result_dict

# 문자열을 묶고 가장 자주 등장한 단어를 key로 하는 딕셔너리를 얻음
result_dict = merge_strings(ddf)

# 결과 출력
for key, value in result_dict.items():
    print(f"{key}: {value}")
# Out:
# 호박: ['단호박', '호박고구마', '호박', '둥근호박', '늙은호박']
# 된장: ['된장']
# 두부: ['순두부', '두부']
# 돼지고기: ['간돼지고기', '돼지고기잡채용', '돼지고기다짐육', '돼지고기안심', '돼지고기', '돼지고기목살', '돼지고기앞다리']
# 낙지: ['낙지']
# 닭: ['닭봉', '닭', '닭가슴살']
# 닭안심살: ['닭안심살']
# 물: ['물', '콩국물', '쌀뜨물', '콩나물']
# 양파: ['양파']
# 배추우거지: ['배추우거지']
# 애호박: ['애호박']
# 김치: ['김치', '배추김치', '열무김치']
# 오징어: ['오징어']
# 돼지갈비: ['돼지갈비']
# 청국장: ['청국장']
# 훈제오리고기: ['훈제오리고기']
# 감자: ['감자큰거', '감자']
# 소고기: ['소고기']
# 삼겹살: ['삼겹살', '대패삼겹살']
# 햄: ['통조림햄', '햄']
# 떡: ['가래떡', '떡', '조랭이떡']
# 표고버섯: ['건표고버섯', '표고버섯']
# 당면: ['당면']
# 동태: ['동태']
# 파김치: ['파김치']
# 소라: ['소라']
# 다시마: ['다시마']
# 멸치: ['멸치']
# 크래미: ['크래미']
# 신김치: ['신김치']
# 아몬드: ['아몬드']
# 양배추: ['양배추']
# 밥: ['흰밥', '찬밥', '밥']
# 고구마: ['고구마']
# 달걀: ['달걀']
# 계란: ['계란']
# 옥수수: ['옥수수통조림', '캔옥수수', '옥수수', '콘옥수수']
# 문어: ['문어']
# 떡볶이떡: ['떡볶이떡']
# 부추: ['부추']
# 바나나: ['바나나']
# 깻잎: ['깻잎']
# 파래: ['파래']
# 찹쌀: ['찹쌀', '찹쌀가루']
# 굴: ['굴']
# 묵은지: ['묵은지']
# 아욱: ['아욱']
# 남은치킨: ['남은치킨']
# 피자치즈: ['피자치즈']
# 후추: ['후추']
# 복숭아: ['복숭아']
# 밤: ['알밤', '밤']
# ...

# %%
val = df1['index'].values
val
# Out:
# array(['둥근호박', '된장', '순두부', ..., '부침유', '깻가루', '후추가루아주'], dtype=object)

# %%
def merge_strings(strings):
    result = []

    for s1 in strings:
        merged = False

        for group in result:
            for s2 in group:
                if s1 in s2 or s2 in s1:
                    group.add(s1)
                    group.add(s2)
                    merged = True
                    break

            if merged:
                break

        if not merged:
            result.append({s1})

    # 더 작업하기 위해 set을 list로 변환
    result_lists = [list(group) for group in result]

    # 자주 등장하는 용어들을 딕셔너리에 넣고 가장 짧은 단어를 뽑아서 key에 넣기
    result_dict = {}
    for group in result_lists:
        merged_string = ' '.join(group)
        words = merged_string.split()
        word_counts = Counter(words)
        min_length_word = min(word_counts, key=lambda x: (len(x), x))
        result_dict[min_length_word] = group

    return result_dict

# 문자열을 묶고 가장 자주 등장한 단어를 key로 하는 딕셔너리를 얻음
result_dict = merge_strings(val)

# 결과 출력
for key, value in result_dict.items():
    print(f"{key}: {value}")

#밀가루는 구분 되어 있음 (영양소에서)
#합치는 거 자체는 좋은 생각..
# Out:
# 마: ['파스타소스', '쥬키니호박', '소스', '허니머스터드', '핫소스', '바베큐소스', '머스타드', '피쉬소스', '마른홍고추', '찐단호박', '마스코바도설탕', '마늘즙', '오리엔탈소스', '미니단호박', '마늘가루', '홀토마토', '머스터드소스', '표고버섯기둥', '표고', '단호박', '마른표고버섯', '호박', '다시마물', '아마씨', '마늘허브소금', '로즈마리', '스위트칠리소스', '칠리소스', '토마토케첩', '다시마육수', '단호박가루', '마른고추', '편마늘', '시판토마토소스', '다시마가루', '슬라이스마늘', '토마토스파게티소스', '토마토케찹', '발사믹소스', '크림소스', '표고버섯가루', '다시마멸치육수', '깐마늘', '토마토파스타소스', '마른표고', '주키니호박', '마른김', '마늘다진것', '머쉬마루버섯', '파마산치즈', '호박씨', '마', '치즈가루', '허니머스타드소스', '피자소스', '마른다시마', '호박고구마', '호박잎', '다시마우린물', '건표고', '파마산치즈가루', '둥근호박', '허니머스터드소스', '우스타소스', '마라소스', '늙은호박', '꼬마새송이버섯']
# 된장: ['시판된장', '미소된장', '집된장', '된장']
# 두부: ['두부면', '연두', '부침용두부', '요리에센스연두', '연두부', '두부', '순두부']
# 고기: ['돼지등심', '소고기등심', '돼지고기', '갈은돼지고기', '돼지고기뒷다리살', '고기', '돼지고기간것', '간돼지고기', '잡채', '소고기샤브샤브', '돼지목살', '돼지고기등심', '다짐육', '돼지고기앞다리', '돼지고기사태', '돼지고기삼겹살', '잡채용돼지고기', '돼지고기안심', '목살', '다진고기', '다진돼지고기', '돼지고기목살', '돼지고기앞다리살', '돼지고기잡채용', '돼지고기다짐육', '등심', '돼지고기갈은것', '소고기다시다']
# 낙지: ['낙지']
# ...

# %% [markdown]
# ## final.csv 양/단위 처리

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import recipe
#import db
import svd

# %%
load = pd.read_csv('final.csv') #최종 데이터 불러옴
load
# Out:
# <ipython-input-6-6faff534323e>:1: DtypeWarning: Columns (62,65,68,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   load = pd.read_csv('final.csv') #최종 데이터 불러옴
#                       recipe_title ingredient1 quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박         1     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역         1     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면        10    인분       느타리버섯
# 3                             동래파전        부침가루       200     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기         1     근          양파
# ...                            ...         ...       ...   ...         ...
# 51488                    국물떡볶이 만들기        떡볶이떡       NaN   NaN          어묵
# 51489                     사골 배추된장국          배추         1    포기        사골육수
# 51490                      새우계란볶음밥          당근         1    조각          양파
# ...

# %%
quantity = recipe.parse_quantity(load)
quantity
# Out:
#                       recipe_title ingredient1  quantity1 unit1 ingredient2  \
# 0                호박 새우젓찌개 만드는 방법~★        둥근호박        1.0     개        청양고추
# 1                깊은맛 나는 미역국 끓이는 방법          미역        1.0     줌      소고기국거리
# 2                     잡채 쉽게 만드는 방법          당면       10.0    인분       느타리버섯
# 3                             동래파전        부침가루      200.0     g          새우
# 4                   제육볶음 맛있게 만드는 법        돼지고기        1.0     근          양파
# ...                            ...         ...        ...   ...         ...
# 51488                    국물떡볶이 만들기        떡볶이떡        1.0   NaN          어묵
# 51489                     사골 배추된장국          배추        1.0    포기        사골육수
# 51490                      새우계란볶음밥          당근        1.0    조각          양파
# 51491  검은콩 콩국수, 여름별미 시원한 콩국수 만드는 법         검은콩        2.0     컵          소면
# 51492                    꽈리고추삼겹살볶음         삼겹살      300.0     g        꽈리고추
#
# ...

# %%
#quantity만 뽑아내기
qu = []
for i in range(1, 25):
    data_q = quantity[f'quantity{i}'].to_list()
    qu.extend(data_q)
qu
# Out:
# [1.0,
#  1.0,
#  10.0,
#  200.0,
#  1.0,
#  1.0,
#  1.0,
#  1.0,
#  2.0,
#  600.0,
#  700.0,
#  300.0,
#  300.0,
#  2.0,
#  300.0,
#  300.0,
#  300.0,
#  300.0,
#  1.0,
#  1.0,
#  400.0,
#  1.0,
#  1.0,
#  1.0,
#  200.0,
#  1.0,
#  100.0,
#  600.0,
#  1.0,
#  600.0,
#  6.0,
#  1.0,
#  1.0,
#  8.0,
#  1.0,
#  2.0,
#  250.0,
#  4.0,
#  1.0,
#  500.0,
#  1.0,
#  1.0,
#  1.0,
#  270.0,
#  1.0,
#  1.0,
#  600.0,
#  1.0,
#  1.0,
#  150.0,
#  1.0,
#  200.0,
#  1.0,
#  150.0,
#  300.0,
#  400.0,
#  400.0,
#  200.0,
#  2.0,
#  1.0,
#  250.0,
#  300.0,
#  1.0,
#  1.0,
#  300.0,
#  1.0,
#  1.0,
#  1.0,
#  50.0,
#  2.0,
#  1.0,
#  1.0,
#  320.0,
#  8.0,
#  3.0,
#  1.0,
#  1.0,
#  2.0,
#  1.0,
#  1.0,
#  2.0,
#  1.0,
#  100.0,
#  1.0,
#  1.0,
#  200.0,
#  300.0,
#  100.0,
#  50.0,
#  1.0,
#  1.0,
#  1.0,
#  200.0,
#  250.0,
#  2.0,
#  9.0,
#  500.0,
#  1.0,
#  1.0,
#  1.0,
#  7.0,
#  1.0,
#  3.0,
#  200.0,
#  1.0,
#  1.0,
#  1.0,
#  1.0,
#  250.0,
#  30.0,
#  2.0,
#  5.0,
#  1.0,
#  120.0,
# ...

# %%
from collections import Counter
import pandas as pd
qu_cnt = Counter(qu) #quantity 종류 및 등장 횟수 계산
qu_df = pd.DataFrame.from_dict(qu_cnt, orient='index', columns=['count']).reset_index()
qu_df
# Out:
#        index    count
# 0      1.000  1071348
# 1     10.000     3894
# 2    200.000     4490
# 3      2.000    57755
# 4    600.000     1080
# ..       ...      ...
# 463    0.850        1
# 464  177.000        1
# 465    6.250        1
# 466  960.000        1
# 467    1.125        1
#
# [468 rows x 2 columns]

# %%
#NaN값 처리
nan_idx = qu_df[qu_df['index'].isnull()].index
nan_idx
#qu_df.drop(nan_idx, inplace=True)
#qu_df.sort_values(by='count', ascending=False) #내림차순 정렬
# Out:
# Int64Index([], dtype='int64')

# %%
blaank = qua_df[qua_df['index'] == ''] #인덱스가 빈칸인 경우
blaank
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []
