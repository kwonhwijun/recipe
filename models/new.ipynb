# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\HwijunKwon\Downloads\RecipeData (1).csv')
recipe = data[['recipe_title', 'recipe_step', 'recipe_ingredients']] # 3가지 칼럼만 일단 사용

# %% [markdown]
# ### 데이터 전처리

# %%
def combined_filter(data):
    def clean_ingredients(ingredient):
        return ingredient.replace('\\ufeff', '').replace('\\u200b', '')
    
    data['recipe_ingredients'] = clean_ingredients(data['recipe_ingredients']) #

    def not_empty_steps(data):
        return data['recipe_step'].strip() != '[]' # recipe_step의 결측치 제거
    def not_empty_ingredients(row):
        return data['recipe_ingredients'].strip() != '{}' # recipe_ingredients의 결측치 제거

    return not_empty_steps(data) & not_empty_ingredients(data)

recipe = recipe[recipe.apply(combined_filter, axis=1)]

# %% [markdown]
# ### 레시피 STEP의 길이

# %%
import pandas as pd

bins = [0, 50, 10, 150, 20, 25, 30]
labels = [f'{i}자 이상' for i in bins[:-1]]

recipe['title_len'] = recipe['recipe_title'].astype(str).apply(len)

# %%
import pandas as pd
# 타이틀 길이 분포
bins = [0, 5, 10, 15, 20, 25, 30]
labels = [f'{i}자 이상' for i in bins[:-1]]

recipe['title_len'] = recipe['recipe_title'].astype(str).apply(len)
recipe['title_category'] = pd.cut(recipe['title_len'], bins = bins, labels = labels)

length_distribution = recipe['title_category'].value_counts().sort_index()
print(length_distribution)
# Out:
# 0자 이상      7344
# 5자 이상     29371
# 10자 이상    30651
# 15자 이상    32758
# 20자 이상    27521
# 25자 이상    18446
# Name: title_category, dtype: int64

# %%
# 레시피 길이 분포
bins = [0, 200, 400, 600, 800, 1000, 2000, 2500, 3000]
labels = [f'{i}자 이상' for i in bins[:-1]]

recipe['step_len'] = recipe['recipe_step'].astype(str).apply(len)
recipe['recipe_category'] = pd.cut(recipe['step_len'], bins = bins, labels = labels)

length_distribution = recipe['recipe_category'].value_counts().sort_index()
print(length_distribution)
# Out:
# 0자 이상       32613
# 200자 이상     64095
# 400자 이상     39675
# 600자 이상     18092
# 800자 이상      7652
# 1000자 이상     6434
# 2000자 이상      212
# 2500자 이상       46
# Name: recipe_category, dtype: int64

# %% [markdown]
# ### 식재료 꺼내서 분류하기

# %%
from tqdm import tqdm
import ast
import re
import json

# 식재료 넣을 칼럼 생성하기 : 식재료, 양, 단위
for i in range(1, 25):
    recipe.loc[:, f'ingredient{i}'] = None
    recipe.loc[:, f'quantity{i}'] = None
    recipe.loc[:, f'unit{i}'] = None

# %%
non_matching_items = {}

for idx, row in tqdm(recipe.iterrows(), total = recipe.shape[0]):
    ingredient_count = 1
    if idx < 2000:
        ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) # SyntaxError: unterminated string literal (detected at line 1)
        for items in ingredients_dict.values():
            for item in items :
                match = re.match(r'([가-힣]+(\([가-힣]+\))?)([\d.+/~-]*)([가-힣a-zA-Z]+|약간|조금)?', item)
                if match:
                    ingredient, _, quantity, unit = match.groups()
                    
                    recipe.loc[idx, f'ingredient{ingredient_count}'] = ingredient
                    recipe.loc[idx, f'quantity{ingredient_count}'] = quantity
                    recipe.loc[idx, f'unit{ingredient_count}'] = unit

                    ingredient_count += 1
                else:
                    non_matching_items[idx] = item

for idx, item in non_matching_items.items():
    print(f'Row {idx}: {item}')
# Out:
#   0%|          | 0/156701 [00:00<?, ?it/s]
# 100%|██████████| 156701/156701 [00:17<00:00, 9127.74it/s]
# Row 258: (소주or맛술)1큰술
# Row 367: 18배멸치육수2T
# Row 598:
# Row 837:
# Row 892:
# Row 1007: (볶을때)들기름약간
# Row 1186:
# Row 1289:
# Row 1390: (머리와내장손질한)국물용멸치1줌
# Row 1460:
# Row 1464:
# Row 1801:

# %% [markdown]
# ### 단위의 종류 찾기

# %%
units = [recipe[f'unit{i}'] for i in range(1, 25)]

# %%
combined_units = []
for unit_tuple in zip(*units):
    for unit in unit_tuple:
        if unit:  # 빈 값이 아닌 경우에만 추가
            combined_units.append(unit)

# 중복 제거
unique_units = list(set(combined_units))

from collections import Counter

unit_counts = Counter(combined_units)
for unit, count in unit_counts.items():
    print(f"{unit}: {count}번")
# Out:
# 개: 1103번
# 큰술: 1609번
# g: 421번
# 컵: 110번
# 줌: 86번
# 공기: 11번
# 줄: 16번
# t: 153번
# T: 1211번
# 쪽: 29번
# 통: 6번
# 팩: 33번
# 대: 75번
# 수저: 70번
# 작은수저: 2번
# 밥숟가락: 24번
# 봉지: 33번
# 모: 7번
# 그람: 7번
# 스푼: 692번
# Ts: 77번
# 주먹: 20번
# 티스푼: 51번
# 대접: 5번
# 숟가락: 192번
# 캔: 14번
# 톨: 17번
# 접시: 2번
# 개정도: 8번
# g정도: 3번
# 송이: 15번
# 알: 26번
# 작은술: 165번
# 뿌리: 19번
# TS: 30번
# 조각: 7번
# 꼬집: 62번
# 수저씩: 2번
# ml: 28번
# g가량: 1번
# 테이블스푼: 4번
# 줄기: 9번
# 장: 118번
# 그램: 9번
# 웅큼: 3번
# cc: 3번
# 종이컵: 11번
# 마리: 11번
# 방울: 3번
# 숟갈: 88번
# 봉: 17번
# 바구니: 1번
# or부추적당량: 1번
# 움큼: 5번
# 스픈: 3번
# 소주잔: 8번
# 천원어치: 1번
# 덩이: 1번
# 조금: 3번
# 큰술반: 6번
# 근: 2번
# ts: 20번
# 약간: 3번
# 사발: 1번
# 소주컵: 7번
# 단: 9번
# 번: 1번
# 개씩: 2번
# 술: 5번
# 스푼정도: 1번
# cm: 9번
# 번톡톡: 3번
# or물: 1번
# 큰술듬뿍: 1번
# T듬뿍: 1번
# 통약간더: 1번
# 토막: 6번
# tea스푼: 2번
# 센티: 1번
# or연두: 1번
# 큰솔: 1번
# 묶음: 3번
# 개반: 2번
# 밥숟갈: 9번
# cm정도: 1번
# 과: 2번
# 뼘: 3번
# 줌정도: 2번
# 알정도: 1번
# 장분량정도: 1번
# 국자: 3번
# 미리: 1번
# 포기: 10번
# 등분: 1번
# 와: 1번
# 분의: 5번
# 개또는반대: 1번
# 넉넉히: 1번
# 크술: 1번
# 잔: 1번
# 바퀴: 8번
# or들기름: 1번
# 설탕: 1번
# T정도: 2번
# 스푼반: 1번
# 타래: 1번
# T스푼: 1번
# g간장: 1번
# 머그컵: 1번
# or물엿: 1번
# 대접정도: 1번
# 봉or: 1번
# 티스푼김치염도에따라조절: 1번
# 컵갈은깨: 1번
# 개작으면: 1번
# 없으면안넣어도무방: 1번
# 두꼬집: 1번
# 작은숟가락: 1번
# 소고기: 1번
# 청청양고추각: 1번
# 개작은것은: 1번
# 커피스푼: 1번
# 소주잔정도: 1번
# g한봉지: 1번
# or매실청: 1번
# 찻스푼: 1번
# 덩어리: 1번
# 큰수: 1번
# 기름: 1번
# kg: 1번
# 적당량: 1번
# G: 1번
# ML: 1번
# 큰슬: 1번
# 주먹정도: 1번
# C: 1번
# 줌반: 1번
# 그릇: 3번
# 키로: 2번
# 두스푼: 1번
# 바뀌: 1번
# 식용유: 1번
# 큰국그릇: 1번
# 스푼씩: 1번
# 뿍: 1번
# 큰컵: 1번
# cm길이: 1번
# 큰술등: 1번
# 작은스푼: 2번

# %% [markdown]
# ### 식재료 종류 찾기

# %%
ingreds = [recipe[f'ingredient{i}'] for i in range(1, 25)]

# %%
combined_ingred = []
for ingred_tuple in zip(*ingreds):
    for ingred in ingred_tuple:
        if ingred:  # 빈 값이 아닌 경우에만 추가
            combined_ingred.append(ingred)

# 중복 제거
unique_ingred = list(set(combined_ingred))

from collections import Counter

ingred_counts = Counter(combined_ingred)
for ingred, count in ingred_counts.items():
    print(f"{ingred}: {count}번")
# Out:
# 애호박: 123번
# 다진마늘: 1012번
# 소금: 321번
# 참기름: 779번
# 식용유또는들기름: 1번
# 건새우: 43번
# 물: 368번
# 마늘종: 13번
# 설탕: 567번
# 간장: 789번
# 식용유: 475번
# 물엿: 166번
# 통깨: 405번
# 부추: 11번
# 달걀: 13번
# 밥: 2번
# 굴소스: 335번
# 베이컨: 31번
# 양파: 669번
# 미니새송이버섯: 7번
# 깻잎: 9번
# 대파: 303번
# 국간장: 76번
# 들깨가루: 61번
# 깨: 127번
# 꽈리고추: 94번
# 햄: 18번
# 진간장: 240번
# 마늘: 248번
# 올리고당: 614번
# 감자(중간사이즈): 3번
# 스팸: 14번
# 비엔나소세지: 41번
# 견과류약간: 2번
# 식용유약간: 75번
# 케찹: 42번
# 파프리카빨강이: 1번
# 파프리카노랑이: 1번
# 느타리버섯: 68번
# 올리브유: 65번
# 새우: 12번
# 마요네즈: 159번
# 버터: 17번
# 후추약간: 131번
# 소금약간: 84번
# 파슬리가루약간: 2번
# 우엉: 7번
# 당근: 203번
# 오일: 26번
# 미림: 64번
# 가지: 95번
# 청양고추: 237번
# 홍고추: 137번
# 굵은소금: 35번
# 고춧가루: 279번
# 메추리알: 2번
# 고추장: 284번
# 케첩: 27번
# 두부: 17번
# 다진소고기: 5번
# 맛술: 347번
# 다진파: 64번
# 후추톡톡톡: 9번
# 들기름: 304번
# 숙주: 17번
# 후추톡톡: 40번
# 참기름조금: 27번
# 다진쪽파: 5번
# 매실청: 72번
# 감자: 121번
# 맛간장(진간장): 1번
# 카놀라유: 39번
# 통깨조금: 51번
# 미니돈까스: 1번
# 단단한두부: 1번
# 고추장(평평하게깎아서계량): 1번
# 브로콜리: 24번
# 다시마물: 1번
# 액젓: 20번
# 쪽파: 37번
# 고추가루: 116번
# 깨소금약간: 72번
# 채썬햄: 1번
# 후추조금: 20번
# 깨조금: 25번
# 소고기: 7번
# 통깨툭툭: 1번
# 진미채: 99번
# 통깨적당량: 31번
# 새송이버섯: 58번
# 오일약간: 2번
# 참치: 13번
# 소금조금: 19번
# 시금치: 7번
# 양배추: 24번
# 통깨팍팍: 6번
# 참치캔: 9번
# 대파송송송: 2번
# 식초: 20번
# 오이: 23번
# 소고기다짐육: 5번
# 생강술: 10번
# 배즙: 2번
# 후춧가루적당량: 8번
# 전분가루적당량: 1번
# 후춧가루톡톡: 3번
# 통깨약간: 214번
# 무: 41번
# 대파약간: 39번
# 맛소금: 19번
# 돼지고기다짐육: 8번
# 카놀라유약간: 7번
# 쥐포: 8번
# 후춧가루약간: 51번
# 닭고기정육: 1번
# 통마늘: 31번
# 붉은고추: 3번
# 후추: 97번
# 청경채: 18번
# 갈은소고기: 1번
# 물엿(생략가능): 1번
# 브로콜리작은거: 2번
# 양송이버섯: 7번
# 맛살: 7번
# 깨소금: 110번
# 소고기(갈은것): 1번
# 청주: 64번
# 후춧가루: 29번
# 세멸치: 1번
# 매실액: 64번
# 술: 3번
# 생강청: 7번
# 쥬키니호박: 2번
# 들깻가루: 2번
# 닭가슴살: 10번
# 마늘쫑: 43번
# 마른청양고추: 1번
# 다진마늘조금: 11번
# 어묵: 159번
# 파: 57번
# 파약간: 13번
# 맛타리버섯: 2번
# 불고기맛햄: 1번
# 청피망: 6번
# 후추적당량: 4번
# 무우: 5번
# 꽃소금취향껏: 1번
# 표고버섯: 38번
# 양파기름: 2번
# 참기름약간: 62번
# 콩나물: 30번
# 볶은통깨: 1번
# 간마늘: 55번
# 조청쌀엿: 2번
# 사각어묵: 83번
# 둥근긴어묵: 1번
# 올리브오일: 21번
# 검은깨약간: 2번
# 황태채: 16번
# 황태: 1번
# 고기버섯: 1번
# 파마산치즈가루약간: 1번
# 당근약간: 49번
# 참깨: 34번
# 방울양배추: 2번
# 소세지: 17번
# 깨약간: 59번
# 양조간장: 41번
# 고추: 15번
# 파조금: 7번
# 생강: 7번
# 버섯: 4번
# 소금톡톡: 1번
# 사가어묵: 1번
# 통깨솔솔: 24번
# 올리브유적당량: 4번
# 파프리카: 44번
# 흑설탕: 2번
# 명엽채: 8번
# 중멸치: 14번
# 호두: 17번
# 고추장듬뿍: 3번
# 맛간장(시판용가능): 1번
# 생수: 9번
# 매실엑기스: 2번
# 계란: 11번
# 김치: 18번
# 다시다: 7번
# 납작어묵: 6번
# 맛살(선택): 1번
# 비엔나소시지(선택): 1번
# 오징어채: 28번
# 팽이버섯: 13번
# 다진돼지고기: 3번
# 육수: 1번
# 후추가루톡톡톡: 2번
# 들기름적당량: 2번
# 김장김치: 1번
# 집간장: 11번
# 미니파프리카: 1번
# 진미채한줌약: 1번
# 마늘취향껏: 1번
# 청양고추취향껏: 1번
# 전분: 10번
# 소시지: 4번
# 마른새우(꽃새우): 1번
# 조림간장: 4번
# 꿀: 51번
# 방울토마토: 3번
# 황설탕: 12번
# 염장미역줄기: 12번
# 양파(중): 9번
# 햄(천원짜리사각햄): 1번
# 후춧가루톡톡톡: 2번
# 밀가루소량: 1번
# 당근약간(색감을위해): 2번
# 데친브로콜리: 1번
# 미역줄기: 37번
# 청양고춧가루: 1번
# 다시마우린물감자잠기게: 1번
# 호박: 13번
# 식용유적당량: 30번
# 새우젓: 91번
# 볼어묵: 3번
# 곤약: 2번
# 대파푸른부분: 2번
# 참치액: 29번
# 쪽파조금: 4번
# 당근조금: 38번
# 야채어묵: 1번
# 실채: 1번
# 포도씨유: 36번
# 검은깨: 8번
# 파래김: 1번
# 깨소금(생략가능): 1번
# 부추적당량: 1번
# 양파적당량: 5번
# 소주: 15번
# 파프리카조금: 6번
# 기름조금: 3번
# 신열무: 1번
# 국물용멸치: 1번
# 된장: 8번
# 깨소금조금: 11번
# 스모크햄: 2번
# 참기름적당량: 7번
# 밥새우: 4번
# 진미채오징어: 1번
# 카레가루: 17번
# 김가루약간: 1번
# 오리고기적당히: 1번
# 후추가루조금: 2번
# 다진대파약간: 1번
# 통깨적당히: 8번
# 카놀라유적당량: 13번
# 타바스코핫소스취향껏: 1번
# 감자(중): 7번
# 카놀라이유약간: 1번
# 햇양파: 2번
# 들기름약간: 8번
# 멸치: 77번
# 견과류: 22번
# 정종: 2번
# 당근적당량: 9번
# 대파적당량: 14번
# 캔참치: 6번
# 풋고추: 16번
# 캔옥수수: 1번
# 생강소스: 1번
# 마일드스팸: 1번
# 홍청양고추: 3번
# 스리라차소스: 1번
# 간깨: 2번
# 오이절일때소금: 1번
# 깻잎(깨순): 1번
# 양파중: 2번
# 송손썬대파: 1번
# 청주나미림: 1번
# 닭가슴살(무항생제): 1번
# 굴소스(유기농): 1번
# 한식간장: 1번
# 비정제설탕: 1번
# 기름(현미): 1번
# 흑후추조금: 1번
# 소금(죽염): 1번
# 깻잎순: 6번
# 다진대파: 23번
# 기름: 36번
# 떡국떡: 2번
# 반건조오징어: 1번
# 참기름살짝: 6번
# 동글어묵: 1번
# 맛간장: 29번
# 다시마우린물: 4번
# 새우젓(건더기만): 1번
# 멸치다시마육수(종이컵): 1번
# 토마토케첩: 3번
# 북어채: 3번
# 돼지고기다짐육크게: 1번
# 카놀라유적당히: 1번
# 슬라이스아몬드: 13번
# 칵테일새우: 6번
# 허브솔트조금: 2번
# 파슬리가루조금: 1번
# 버터조금: 1번
# 맛소금약간: 2번
# 생표고버섯: 5번
# 빨강파프리카약간: 2번
# 주황파프리카약간: 1번
# 노랑파프리카약간: 2번
# 재료: 2번
# 배추: 4번
# 구운김조금: 1번
# 무채: 1번
# 쌀뜨물: 6번
# 마늘종(마늘속대): 1번
# 마른새우: 12번
# 후춧가루조금: 7번
# 파흰부분: 1번
# 마른꽃새우: 1번
# 양파조금: 5번
# 청양홍고추: 2번
# 지리멸치: 19번
# 소금적당량: 6번
# 냉장햄: 1번
# 잔멸치: 85번
# 아몬드: 21번
# 식용유(두르기): 1번
# 느타리버섯적당량: 1번
# 식용유넉넉히: 3번
# 감자중간크기: 5번
# 삼색파프리카: 1번
# 페퍼치노고추: 1번
# 허브솔트약간: 2번
# 미니새송이: 2번
# 브로콜리약간: 1번
# 참깨약간: 11번
# 마른김또는눅눅해진김: 1번
# 대파조금: 19번
# 마른고추: 1번
# 두반장소스(고춧가루와간장으로대체가능): 1번
# 묵은지: 13번
# 아몬드슬라이스약간: 1번
# 파슬리가루: 1번
# 후추적당히: 3번
# 식용유적당히: 2번
# 사각오뎅: 1번
# 오징어: 4번
# 꽃새우: 2번
# 물약간: 2번
# 진미오징어채: 3번
# 채썬당근: 2번
# 굵은고춧가루: 2번
# 피망: 22번
# 익은김치: 1번
# 김칫국물: 2번
# 대파(흰부분): 4번
# 송송썬파: 2번
# 식용류: 15번
# 햄조금: 2번
# 해바라기유조금: 1번
# 부순깨: 4번
# 마늘약간: 2번
# 양파반개: 2번
# 남은치킨: 1번
# 땡초: 10번
# 깨적당히: 3번
# 요리당: 28번
# 청양초: 17번
# 갈색설탕: 8번
# 전분가루: 5번
# 통조림햄: 1번
# 대파초록부분: 4번
# 후춧가루적당히: 3번
# 양파작은것: 9번
# 땅콩적당량: 1번
# 아몬드적당량: 2번
# 해바라기씨적당량: 1번
# 호박씨적당량: 1번
# 소금(부족하간): 1번
# 건새우소복하게: 1번
# 묵은갓김치: 1번
# 비엔나: 1번
# 깨소금톡톡: 2번
# 꽃소금: 12번
# 다진생강약간: 1번
# 파프리카각각: 1번
# 국산들깨가루: 1번
# 죽염조금: 1번
# 냉압착올리브유조금: 1번
# 저온압착들기름조금: 1번
# 판어묵: 4번
# 부추조금: 2번
# 까나리액젓: 11번
# 다시마육수또는물: 1번
# 원당: 3번
# 올리브유적당히두르기: 1번
# 멸치액젓: 20번
# 올리브유적당히: 4번
# 깨소금(참기름): 1번
# 둥근호박: 5번
# 매실액약간: 1번
# 감자큰것: 2번
# 노랑파프리카: 14번
# 빨강파프리카: 14번
# 청피망작은거: 1번
# 양파작은거: 8번
# 신김치: 8번
# 고구마줄기: 7번
# 양송이큰거: 1번
# 후추톡: 2번
# 청양고추(생략가능): 2번
# 치즈가루(생략가능): 1번
# 돈까스소스: 2번
# 올리브오일약간: 2번
# 매실액기스: 9번
# 숟가락계량입니다: 1번
# 간돼지고기: 4번
# 대파흰부분: 11번
# 건새우한봉지: 1번
# 캐첩: 1번
# 핫소스: 3번
# 건미역: 1번
# 통깨넉넉히: 3번
# 멸치(멸치볶음): 3번
# 편마늘: 7번
# 햄길게: 1번
# 대파송송: 1번
# 맛술(소주): 1번
# 다진생강: 3번
# 다진파조금: 4번
# 들기름조금: 2번
# 통깨톡톡: 8번
# 마요네즈약간: 2번
# 양파(소): 4번
# 당근(소): 1번
# 물오뎅이잠길만큼: 1번
# 짜장가루: 2번
# 후추가루: 8번
# 불린고사리: 4번
# 갈은깨: 8번
# 감자작은것: 3번
# 명란: 2번
# 미원: 2번
# 자리멸치: 1번
# 보리새우: 4번
# 쪽파(대파): 1번
# 통조림참치: 2번
# 파프리카색깔별로: 2번
# 케챱: 3번
# 간장소주잔: 1번
# 미림소주잔: 1번
# 양배추약간: 3번
# 청고추: 16번
# 들깨: 4번
# 가는북어채: 1번
# 아보카도오일또는각각올리브오일: 1번
# 가는고춧가루: 1번
# 고구마순: 6번
# 코코넛오일: 1번
# 소금살짝: 4번
# 깨소금살짝: 1번
# 홍피망: 2번
# 사각햄: 1번
# 고추기름: 20번
# 풋마늘: 1번
# 빅비엔나소세지: 1번
# 파프리카적당량: 1번
# 메실청: 1번
# 아보카도오일: 1번
# 구운소금: 3번
# 빨간파프리카: 9번
# 노란파프리카: 8번
# 물살짝: 1번
# 애호박약간: 1번
# 빨강파프리카조금: 1번
# 분홍소세지적당량: 1번
# 북어채또는황태채: 1번
# 청량고추또는대파: 1번
# 맛술또는생강술: 2번
# 생강또는생강가루: 1번
# 손가락어묵: 1번
# 대파밑부분: 1번
# 비엔나소시지: 10번
# 파프리카작은것: 1번
# 홍진미(백진미도좋음): 1번
# 깨넉넉히: 1번
# 오징어실채: 13번
# 레몬즙: 3번
# 두반장: 12번
# 멸치육수: 9번
# 식용유조금: 6번
# 만가닥버섯: 1번
# 숙주어묵과동량: 1번
# 절임소금: 1번
# 기름약간: 6번
# 새송이: 4번
# 부추나쪽파조금: 1번
# 당근적당히: 1번
# 당근(선택재료): 1번
# 진미채양껏: 1번
# 잣적당량: 1번
# 네모어묵: 2번
# 현미유: 4번
# 숙주나물: 3번
# 실파: 7번
# 흑임자: 2번
# 뜨거운물: 1번
# 케쳡: 4번
# 작은양파: 2번
# 볶음용멸치: 6번
# 건표고버섯: 2번
# 올리브고당: 1번
# 연근: 2번
# 고춧가루취향껏: 1번
# 냉동새우: 2번
# 페페로치노: 1번
# 돼지고기: 6번
# 미소된장: 2번
# 조미료적당히: 1번
# 간생강적당히: 1번
# 썬대파: 4번
# 청량고추: 9번
# 고운고추가루: 7번
# 볶은참깨약간: 1번
# 고구마줄기다듬은후: 1번
# 오뎅: 10번
# 해바라기씨: 10번
# 호박씨: 5번
# 식용유넉넉하게: 1번
# 올리고당큰바퀴: 1번
# 둥근애호박: 3번
# 해바라기유: 4번
# 실고추(생략가능): 1번
# 참기름(들기름): 3번
# 중간사이즈양파: 1번
# 파흰부분다져서: 1번
# 파초록부분은크게어슷썰어서: 1번
# 깨살짝: 2번
# 고수: 1번
# 라임즙: 1번
# 꼬마새송이버섯: 2번
# 통깨가루조금: 2번
# 후추살짝: 4번
# 스팸햄: 3번
# 다진양파: 2번
# 느타리: 1번
# 다용도맛간장: 1번
# 완두콩: 1번
# 통마늘원하는만큼: 1번
# 송송썬대파약간: 2번
# 통깨톡톡톡: 2번
# 전분물: 1번
# 토마토: 5번
# 파슬리약간: 1번
# 손질된칵테일생새우: 1번
# 홍고추적당량: 1번
# 파프리카약간: 3번
# 굵은소금약간: 5번
# 아스파라거스: 3번
# 가지작은거: 1번
# 절이는소금: 1번
# 깨적당량: 4번
# 깻가루: 1번
# 대파손가락: 1번
# 후춧가루소량: 2번
# 당근작은것: 1번
# 조청: 17번
# 마른꼴뚜기: 2번
# 양배추반통의잎: 1번
# 땅콩: 7번
# 무청: 1번
# 통들깨약간: 1번
# 다시마육수: 5번
# 콩나물한봉지: 1번
# 썰어놓은양파: 1번
# 썰어놓은대파: 1번
# 묵은지(배추김치): 1번
# 양배추적당히: 1번
# 파채적당히: 1번
# 소시지긴거: 1번
# 허브소금: 1번
# 작은대파: 2번
# 후추참깨: 2번
# 천일염약간: 2번
# 고운소금: 5번
# 볶은참깨: 8번
# 양파약간: 6번
# 가지절임소금: 1번
# 머쉬마루버섯: 1번
# 무작은: 1번
# 게맛살: 2번
# 브로콜리소량(없어도무관): 1번
# 아몬드슬라이스: 8번
# 설탕약간: 4번
# 쪽파약간: 1번
# 통그릴비엔나: 1번
# 올리고당약간: 2번
# 후추가루약간: 15번
# 양파작: 1번
# 다시다약간: 1번
# 청파프리카: 2번
# 떡: 1번
# 파적당히: 1번
# 가시오이: 1번
# 손질다시멸치: 1번
# 생강매실맛술: 1번
# 취나물: 1번
# 삶은계란: 1번
# 양파채: 1번
# 유부: 2번
# 기름적당량: 3번
# 죽봉어묵: 1번
# 감자작은거: 1번
# 발사믹식초: 1번
# 매운고추: 2번
# 홍고추약간: 4번
# 깐마늘: 3번
# 참치액젓: 4번
# 통깨또는다진땅콩적당량: 1번
# 스리차소스: 1번
# 황태껍질손질후: 1번
# 표고버섯큰것: 1번
# 포도씨유약간: 3번
# 진미채(오징어채): 2번
# 다진파약간: 3번
# 볶음용잔멸치: 2번
# 쥐포(손바닥크기): 1번
# 다시마멸치육수: 2번
# 카레: 1번
# 가지큰사이즈면: 1번
# 홍고추아주조금: 1번
# 깨소금(깨으깬것): 2번
# 파다진것: 1번
# 마늘다진것: 3번
# 아귀포: 1번
# 매운고추장: 1번
# 실파약간: 3번
# 미역줄기볶음: 1번
# 국간장적당히: 1번
# 팽이: 1번
# 파프리카조금씩(선택): 1번
# 백만송이버섯: 1번
# 한우(살치살): 1번
# 건곤드레나물: 1번
# 홍당무조금: 1번
# 홍: 1번
# 공심채: 3번
# 무중: 1번
# 건고추: 2번
# 감자크것은: 1번
# 요리유: 3번
# 멸치(지리멸): 1번
# 마늘(편썰기): 1번
# 생강가루: 9번
# 대파흰대: 2번
# 물반컵: 1번
# 고추약간: 1번
# 감자중간사이즈: 1번
# 소고기(다짐육): 1번
# 생강가루약간: 5번
# 두반장소스: 1번
# 유자청: 2번
# 콩가루: 1번
# 참깨가루: 1번
# 배추잎: 2번
# 저염액젓: 3번
# 검은깨적당량: 2번
# 당근소량: 6번
# 깨약간씩: 2번
# 진간장혹은양조간장: 1번
# 청량초: 5번
# 통깨솔솔솔: 2번
# 양파다진것: 1번
# 통들깨: 3번
# 잔파: 2번
# 마무리볶음들기름: 1번
# 무지름: 1번
# 천일염: 9번
# 작은무: 2번
# 공기밥: 1번
# 햄약간: 1번
# 볶음소금: 1번
# 백후추약간: 2번
# 오뎅한봉지: 1번
# 소금필요시소량: 1번
# 조미도시락김: 1번
# 마늘쫑약: 1번
# 오이(대): 1번
# 애기새송이버섯: 1번
# 송송썬대파: 1번
# 볶음깨약간: 2번
# 식용류약간: 1번
# 건호박: 1번
# 마늘조금씩: 1번
# 파프리카노랑: 2번
# 파프리카빨강: 1번
# 삼겹살: 1번
# 미림(청주): 1번
# 꽃새우또는건새우: 1번
# 청주또는맛술: 1번
# 고구마순삶는데넣는소금: 1번
# 슬라이스햄: 3번
# 들(참): 1번
# 익은총각김치: 1번
# 손질한가지: 1번
# 썬파: 2번
# 깨듬뿍: 1번
# 크래미소포장: 1번
# 마른멸치: 1번
# 후춧가루살짝: 3번
# 멸치(중간사이즈): 2번
# 올리고당(가늘게): 1번
# 깨소량: 2번
# 켄터키소시지: 1번
# 물소주컵: 1번
# 중간크기감자: 1번
# 작은멸치: 1번
# 미림(맛술): 1번
# 감자대: 1번
# 샐러리: 1번
# 올리고당적당량: 3번
# 물(상황에따라): 1번
# 다진마늘약간: 10번
# 건새우적당량: 1번
# 녹차유: 1번
# 돈가스소스: 1번
# 설탕(올리고당): 1번
# 하루견과류: 1번
# 두절건새우: 1번
# 파프리카노랑적당량: 1번
# 파프리카빨강적당량: 1번
# 고추기름(또는식용유): 1번
# 송송썬대파듬뿍: 1번
# 꿀이나올리고당: 1번
# 통깨적당: 1번
# 어묵넙적한거: 1번
# 참깨톡톡: 2번
# 후랑크소세지: 3번
# 토마토소스: 1번
# 호박중간크기: 1번
# 새우젓국물없이: 1번
# 시판스테이크(햄): 1번
# 고구마순데친것: 1번
# 고운고춧가루: 4번
# 시래기: 3번
# 납작오뎅: 1번
# 자일로스설탕: 1번
# 천연조미료: 2번
# 불고기용소고기: 1번
# 네모어묵약간: 1번
# 오징어진미채: 2번
# 고추잎: 1번
# 소금소량: 3번
# 청양고추옵션: 1번
# 돼지고기목살슬라이스: 1번
# 깨취향껏: 1번
# 다진만르: 1번
# 잘게썬청양고추: 1번
# 멸치(내장제거): 1번
# 참기름주르륵: 1번
# 참깨솔솔: 2번
# 물약: 1번
# 양파(어묵부피와비슷하게): 1번
# 대파(어묵부피와비슷하게): 1번
# 당근(어묵부피의반정도): 1번
# 다시마채천원분량: 1번
# 대파(송송썬것): 1번
# 마늘슬라이스: 1번
# 포도씨유또는카놀라유: 1번
# 햄프씨드: 2번
# 고춧기름: 1번
# 쥐똥고추: 1번
# 설탕조금: 3번
# 황태포: 1번
# 물(소주컵): 2번
# 올리브유약간: 3번
# 통깨양념: 1번
# 콜라비: 1번
# 실치: 3번
# 굵은고추가루: 1번
# 볶음멸치: 4번
# 작은송이로손질한브로콜리: 1번
# 적양파(작): 1번
# 다진홍고추: 2번
# 미니빨강파프리카: 1번
# 미니노랑파프리카: 1번
# 페페로치노또는베트남고추: 1번
# 깐밤: 1번
# 치킨스톡: 2번
# 새우젓적당량: 1번
# 만능간장또는국간장약간: 1번
# 적파프리카: 1번
# 오뎅(사각): 1번
# 잣: 3번
# 삶은토란대: 1번
# 물종이컵: 2번
# 총각김치: 1번
# 새우젓국물: 2번
# 들기름또는참기름: 1번
# 다짐육소고기: 1번
# 무김치: 1번
# 고추(청양고추): 1번
# 설탕(또는물엿): 1번
# 지리멸치적당량: 1번
# 크랜베리: 4번
# 마른잔멸치: 3번
# 양파청(매실청): 1번
# 조랭이떡: 1번
# 진간장또는만능간장: 1번
# 파프리카빨간색조금: 1번
# 파프리카노란색조금: 1번
# 후추(취향에따라): 1번
# 묵은김치: 3번
# 올리브유(또는식용유): 1번
# 양파작은: 1번
# 김치국물: 3번
# 지가멸치: 1번
# 생굴: 1번
# 자숙문어: 2번
# 양파큰거: 1번
# 페퍼론치노: 2번
# 로스팜: 1번
# 카놀라유조금: 2번
# 어묵볼: 1번
# 다진청양고추: 7번
# 다진홍청양고추: 1번
# 케챂: 2번
# 칠리소스: 3번
# 고구마: 1번
# 노란색파프리카: 1번
# 빨간색파프리카: 1번
# 천일염적당량: 1번
# 감자(대): 1번
# 마늘소금: 1번
# 바질페스토: 1번
# 이탈리안시즈닝: 1번
# 볶은소금약간: 1번
# 김자반: 1번
# 설탕수북히: 1번
# 통깨듬: 1번
# 비트: 1번
# 종합어묵: 1번
# 삶은꼬막: 1번
# 다시마: 1번
# 볶은소금: 2번
# 홈메이드맛술(생강술): 1번
# 참치캔작은거: 1번
# 다시마간장: 1번
# 미향: 1번
# 파기름: 1번
# 올리고당(물엿): 1번
# 깐도라지: 3번
# 설탕아주조금: 2번
# 고추씨기름: 1번
# 자투리채소: 1번
# 슬라이드아몬드: 1번
# 새우살: 2번
# 올리고당조금: 2번
# 깨소금적당량: 2번
# 양념불고기(시판용가능): 1번
# 식용유적당양: 1번
# 목이버섯: 2번
# 옥수수콘: 1번
# 마요네즈수북히: 1번
# 스테이크소스: 5번
# 쪽파및대파약간: 1번
# 멸치(중): 3번
# 크랜베리약간: 1번
# 잣약간: 1번
# 왕쥐포: 1번
# 올리브오일충분히: 1번
# 볶은통깨솔솔: 1번
# 꿀(또는올리고당): 2번
# 볶음용멸치(잔지리): 1번
# 참깨적당히: 2번
# 당근채: 1번
# 삶은고사리: 2번
# 산나물건고추잎: 1번
# 건새우밥그릇: 1번
# 마른홍고추조금: 1번
# 양파(작은거): 1번
# 볶음참깨: 1번
# 꽈리고추기호에따라: 1번
# 물엿대체가능: 1번
# 양파대: 1번
# 겨울무: 1번
# 소금이나간장약간: 1번
# 반건조바지락살: 1번
# 어간장: 3번
# 새송이버섯(대): 1번
# 들깨순: 1번
# 국간장이나액젓: 1번
# 배추김치: 1번
# 돼지고기앞다리살: 1번
# 땅콩버터: 1번
# 설탕기호에맞게: 1번
# 끝물청양고추: 1번
# 파프리카두가지색조금: 1번
# 무청적당량: 1번
# 밴댕이(디포리): 1번
# 볶음깨: 5번
# 일미: 2번
# 마늘적당히: 1번
# 돼지고기안심: 1번
# 조선간장: 2번
# 연두: 2번
# 아몬드(다른견과류): 1번
# 미역줄기염장소금포함: 1번
# 고운소금약간: 3번
# 조선호박: 1번
# 식용유약간씩: 3번
# 염장미역: 2번
# 대하: 1번
# 설탕(꿀): 1번
# 조청이나올리고당: 1번
# 소멸치: 1번
# 대파초록부분조금: 1번
# 다용도매콤양념장: 1번
# 생강매실청맛술: 1번
# 머위대크게: 1번
# 해바라기씨유: 1번
# 고추장(듬뿍): 1번
# 요리엿: 1번
# 표고버섯불린것: 1번
# 죽염약간: 1번
# 사각어묵등: 1번
# 국간장조금: 2번
# 깨소금약간씩: 1번
# 빨강피망: 3번
# 노랑피망: 1번
# 통깨살짝: 1번
# 견과류(생략가능): 1번
# 송송썬파약간: 2번
# 가지작은것: 1번
# 들깨가루수북히: 1번
# 간장약간: 2번
# 고기느타리버섯또는느타리버섯: 1번
# 물조금: 3번
# 무중자: 1번
# 명태껍질: 1번
# 야채소세지: 1번
# 옛느타리버섯: 1번
# 후추가루아주조금: 1번
# 물생수병으로: 1번
# 대파조금또는청양고추: 1번
# 올리고당(설탕): 1번
# 칵테일냉동새우: 1번
# 사이다: 1번
# 볶음김: 1번
# 잔멸치대략: 1번
# 건목이버섯: 1번
# 감자중: 3번
# 쪽파단으로: 1번
# 납작사각어묵: 1번
# 초록피망: 2번
# 검은깨조금: 2번
# 미나리: 1번
# 손질멸치: 1번
# 호두크게: 1번
# 멸치크게(큰것): 1번
# 통깨참기름: 1번
# 고추장크게: 2번
# 삶은고구마순: 2번
# 양파(작은사이즈): 1번
# 머위대삶은것: 1번
# 새우가루: 2번
# 어묵(사각어묵기준): 1번
# 물엿취향껏: 1번
# 어슷썬대파약간: 1번
# 마늘조금: 2번
# 식요유: 1번
# 흰후추: 1번
# 다시물: 2번
# 올리브유(두큰술정도): 1번
# 마카다미아: 1번
# 캐슈너: 1번
# 자색양파: 1번
# 브로콜리기둥: 1번
# 길쭉어묵: 1번
# 오일적당량: 2번
# 미정: 1번
# 구멍난어묵: 1번
# 부침가루: 1번
# 매운고춧가루: 1번
# 생강즙: 4번
# 건홍고추: 1번
# 조청(올리고당꿀사용가능): 1번
# 올리고당이나물엿: 1번
# 참깨조금: 5번
# 올리브유(식용유): 2번
# 실파(고명용): 1번
# 중간멸치: 1번
# 양조간장이나굴소스: 1번
# 소금적당: 1번
# 저염간장: 1번
# 물엿또는올리고당: 1번
# 둥근애호박큰것: 1번
# 물종이컵기준: 1번
# 절임용소금: 1번
# 돼지고기잡채용: 1번
# 다진대파조금: 1번
# 표고버섯밑간물: 1번
# 표고버섯밑간맛술: 1번
# 표고버섯액젓: 1번
# 포도씨오일: 1번
# 돼지고기간것: 1번
# 연두적당량: 1번
# 신김치국그릇: 1번
# 양념소금: 1번
# 후추톡톡톡톡: 1번
# 육수용멸치: 1번
# 청양고추(취향껏조절): 1번
# 소고기우둔: 1번
# 대파(다진것): 1번
# 맛늘: 1번
# 소금부족한간추가시: 1번
# 마른새우약간: 1번
# 식용유충분히: 1번
# 아몬드약간: 2번
# 땅콩약간: 1번
# 포도씨유적당량: 2번
# 명태살채: 1번
# 참깨적당량: 1번
# 미역: 1번
# 올리고당또는물엿: 1번
# 마른표고버섯: 1번
# 크래미: 1번
# 식용유또는올리브유적당량: 1번
# 우유또는생크림: 1번
# 청양고추작은크기: 1번
# 톳: 1번
# 프랑크소시지: 1번
# 홍파프리카: 1번
# 황파프리카: 1번
# 파프리카주황: 1번
# 씨리얼: 1번
# 연유: 1번
# 큰둥근애호박: 1번
# 큰양파: 1번
# 부드러운진미채: 1번
# 연두순: 2번
# 삶은시래기나물: 1번
# 파프리카각: 1번
# 훈제오리슬라이스: 1번
# 손질된멸치: 3번
# 생목이버섯: 1번
# 푹익어버린총각무: 1번
# 쌀뜨물적당량: 1번
# 유자: 1번
# 쇠고기: 1번
# 굴: 1번
# 소스: 1번
# 오이고추: 1번
# 사과청: 1번
# 소금(애호박절임용): 1번
# 맛소금살짝: 1번
# 들기름듬뿍: 1번
# 새우젓약간: 2번
# 미역줄기한팩기준: 1번
# 참치액젓또는국간장적당량: 1번
# 머위대삶아논거: 1번
# 마른멸치중간사이즈: 1번
# 마늘편: 1번
# 생강편: 1번
# 마른홍고추: 1번
# 노추: 1번
# 송송썬쪽파: 4번
# 매실: 2번
# 참치통조림: 1번
# 애호박큰거: 1번
# 실고추약간: 3번
# 밀가루: 1번
# 편생강: 1번
# 대파송송썬것: 1번
# 깨(부순것): 1번
# 새우젓국: 1번
# 조림맛간장: 1번
# 버터약간: 1번
# 양파소자: 1번
# 아기새송이버섯: 1번
# 참기름한방울: 1번
# 멸치가루: 1번
# 볶음땅콩: 1번
# 소금(천일염): 1번
# 감자(큰거): 1번
# 깨소금소량: 2번
# 부순참깨: 1번
# 그린빈: 1번
# 간생강: 1번
# 작은양배추: 1번
# 굴소스약간: 1번
# 당근작은거: 1번
# 파슬리: 1번
# 양지살: 1번
# 솔트솔솔: 1번
# 대파흰부분약간: 1번
# 고추가루듬뿍: 1번
# 채썬무: 1번
# 통깨갈은것: 1번
# 매실원액: 4번
# 대파(초록부분): 2번
# 프랑크소세지: 1번
# 묵은지(큰것): 1번
# 잘익은신김치: 1번
# 생강가루살짝: 1번
# 다진고추: 1번
# 잘익은김장김치: 1번
# 멸치다시마육수: 1번
# 여리고추: 1번
# 비엔나햄: 1번
# 둥근호박한개: 1번
# 대파푸른줄기: 1번
# 소고기감치미: 1번
# 모닝글로리: 1번
# 흰대파: 2번
# 당근자투리: 1번
# 조림멸치: 1번
# 햄적당량: 2번
# 녹차쌀유적당량: 1번
# 양파큰것: 1번
# 데리야끼소스: 1번
# 햇감자대: 1번
# 다시다(시판쇠고기다시다): 1번
# 감자큰거: 1번
# 영양부추: 2번
# 새송이버섯(작은새송이): 1번
# 물엿(올리고당): 1번
# 쯔유: 1번
# 작은새송이버섯: 1번
# 참깨후추: 1번
# 작은당근: 1번
# 후추취향것: 1번
# 청양고추조금: 2번
# 홍고추조금: 1번
# 햇감자: 1번
# 김밥용햄: 1번
# 실오징어채: 1번
# 오이지: 1번
# 김치큰: 1번
# 깻가루조금: 1번
# 베트남고추: 1번
# 대패삼겹살먹고싶은만큼: 1번
# 겉껍질제거한수박속껍질: 1번
# 절일소금: 1번
# 거피들깨가루: 1번
# 송송실파: 1번
# 부추약간: 2번
# 페페론치노: 1번
# 물녹말: 1번
# 진미채양념재료: 1번
# 멸치(소): 1번
# 새송이버섯큰것: 1번
# 백진미채: 2번
# 식용유소량: 1번
# 깨소금소스: 1번
# 돼지고기앞다리: 1번
# 미강유: 1번
# 고추장수북히: 1번
# 카레용돼지고기: 1번
# 통후추약간: 1번
# 실파조금: 1번
# 기름간장: 1번
# 건대하: 1번
# 소고기간것: 1번
# 말리표고: 1번
# 참기름또는들기름약간: 1번
# 식물성기름: 1번
# 아가베시럽: 2번
# 절단오징어: 1번
# 동원어묵: 2번
# 동원미앤미소시지: 1번
# 일미채: 1번
# 고사리: 1번
# 양파중간사이즈: 1번
# 연겨자: 1번
# 물적당히: 1번
# 돼지고기(다짐육): 1번
# 얇은어묵: 1번
# 고춧가루반: 1번
# 홍고추(생략가능): 1번
# 고추가루조금: 1번
# 설탕(물엿): 1번
# 양념장: 1번
# 양파청: 1번
# 소고기(채끝살): 1번
# 단호박: 1번
# 홍삼가루: 1번
# 애기고추: 1번
# 청양고추와홍고추약간: 1번
# 식용유(현미유): 1번
# 파적당량: 2번
# 작년김장김치: 1번
# 도라지: 2번
# 청: 2번
# 데친깻잎순크게: 1번
# 매실액조금: 1번
# 땅콩소스: 1번
# 올리브적당량: 1번
# 손질된콩나물: 1번
# 물조주컵으로: 1번
# 소고기불고기감: 1번
# 국간장(조선간장): 1번
# 후추가루취향대로: 1번
# 물적당량: 1번
# 데리소스: 1번
# 식용유나포도씨유: 1번
# 견과류나고추: 1번
# 장흥유기농건표고채: 1번
# 친환경애호박: 1번
# 까나리액젓조금: 1번
# 둥근어묵: 1번
# 표고버섯가루: 1번
# 불린시래기: 1번
# 멸치다시육수: 1번
# 마늘쫑썬것: 1번
# 샘표맛간장: 1번
# 채썬파: 2번
# 참기름적당: 2번
# 바지락살: 1번
# 청홍고추각: 1번
# 주황파프리카: 1번
# 참깨취향껏: 1번
# 아주매운고추: 1번
# 올리고당(또는물엿): 2번
# 피망(고추가없으면): 1번
# 후춧가루(또는백후추): 1번
# 새우젓취향껏: 1번
# 조림용멸치: 1번
# 청정원포도씨유: 1번
# 가는소금: 2번
# 참기름(선택): 1번
# 빨간고추: 1번
# 진간장밥수저기준: 1번
# 올리고당밥수저기준: 1번
# 고춧가루밥수저: 1번
# 참기름밥수저: 1번
# 깨소금적당히: 2번
# 미원조금: 1번
# 진미채크게: 1번
# 간장(생략가능): 1번
# 당근채썬것: 1번
# 양파채썬것: 1번
# 김: 2번
# 깨순: 1번
# 어묵둥글고긴모양: 1번
# 굴소스(간장대체가능): 1번
# 건크랜베리: 1번
# 호두약간: 1번
# 청경채적당량: 1번
# 쪽파적당량: 1번
# 다시마물(또는물): 1번
# 우유: 1번
# 홍청양고추조금: 1번
# 당근조금씩: 1번
# 손질시래기: 1번
# 채썬고추: 1번
# 파프리카(노랑초록빨강): 1번
# 작은스팸: 1번
# 세멸: 1번
# 흑임자조금: 1번
# 마늘쫑작은: 1번
# 콩가루약간: 1번
# 올리브유조금: 1번
# 믹스견과류원하는만큼: 1번
# 다시멸치(모아둔것): 1번
# 소금적당히: 1번
# 아보카도오일또는오일: 1번
# 미원아주약간: 1번
# 들깨가루(옵션): 1번
# 쑥갓: 1번
# 홍초: 1번
# 청초: 1번
# 견과류골고루: 1번
# 딸기잼: 1번
# 들기름(볶을때): 1번
# 통마늘슬라이스: 1번
# 건고추조금: 1번
# 콩기름약간: 2번
# 데칠때소금: 1번
# 만능간장(새우젓없으면): 1번
# 맛소금조금: 1번
# 멸치크게: 1번
# 후랑크소시지: 1번
# 으깬통들깨: 1번
# 죽순: 1번
# 볶은검은깨: 1번
# 묵은지김치: 1번
# 북어포: 1번
# 소주또는청주: 1번
# 통깨취향껏: 1번
# 녹말가루: 1번
# 간장(소주컵): 1번
# 물엿(소주컵): 1번
# 올리브: 1번
# 버섯(느타리버섯): 1번
# 냉장고속야채: 1번
# 깻잎다듬은양: 1번
# 고운천일염약간: 1번
# 잔파조금: 1번
# 묵말랭이: 1번
# 물감자가잠길정도: 1번
# 말린표고버섯나물: 1번
# 칼칼한굴소스: 2번
# 생강가루톡톡: 1번
# 후추가루톡톡: 1번
# 풋고추나청량고추: 1번
# 양념: 2번
# 양파즙: 1번
# 매실진액: 1번
# 솔치: 1번
# 당근효소: 1번
# 멸치두줌가득: 1번
# 볶음용오일약간: 1번
# 식용유(고추오일대체가능): 1번
# 굴소스(간장으로대체가능): 1번
# 삶은고사리국그릇으로: 1번
# 목이버섯조금: 1번
# 대구채: 1번
# 부추봉어묵: 1번
# 잔멸치크게: 1번
# 건포도: 1번
# 통깨(참깨): 1번
# 캐슈너트: 1번
# 애느타리버섯: 1번
# 생강맛술: 1번
# 구운김: 1번
# 파흰대부분: 1번
# 마늘적당양: 1번
# 청홍고추(생략가능): 1번
# 뒤포리육수: 1번
# 향신기름: 1번
# 양파(작은것): 1번
# 건조표고버섯: 1번
# 조미료소량: 1번
# 신김치(묵은지): 1번
# 당근조금(생략가능): 1번
# 현미유또는식용유: 1번
# 고구마줄기(껍질벗긴것): 1번
# 깻잎(삶은것): 1번
# 홍진미채: 1번
# 호두반태: 1번
# 삶은고구마줄기: 1번
# 다시육수: 1번
# 궁채나물: 1번
# 청홍고추각각: 1번
# 쪽파혹은대파: 1번
# 물종이컵반컵: 1번
# 호박(주먹크기): 1번
# 마늘쫑한단: 1번
# 자반용김: 1번

# %%
ingred_counts.most_common
# Out:
# <bound method Counter.most_common of Counter({'다진마늘': 1012, '간장': 789, '참기름': 779, '양파': 669, '올리고당': 614, '설탕': 567, '식용유': 475, '통깨': 405, '물': 368, '맛술': 347, '굴소스': 335, '소금': 321, '들기름': 304, '대파': 303, '고추장': 284, '고춧가루': 279, '마늘': 248, '진간장': 240, '청양고추': 237, '통깨약간': 214, '당근': 203, '물엿': 166, '마요네즈': 159, '어묵': 159, '홍고추': 137, '후추약간': 131, '깨': 127, '애호박': 123, '감자': 121, '고추가루': 116, '깨소금': 110, '진미채': 99, '후추': 97, '가지': 95, '꽈리고추': 94, '새우젓': 91, '잔멸치': 85, '소금약간': 84, '사각어묵': 83, '멸치': 77, '국간장': 76, '식용유약간': 75, '매실청': 72, '깨소금약간': 72, '느타리버섯': 68, '올리브유': 65, '미림': 64, '다진파': 64, '청주': 64, '매실액': 64, '참기름약간': 62, '들깨가루': 61, '깨약간': 59, '새송이버섯': 58, '파': 57, '간마늘': 55, '통깨조금': 51, '후춧가루약간': 51, '꿀': 51, '당근약간': 49, '파프리카': 44, '건새우': 43, '마늘쫑': 43, '케찹': 42, '비엔나소세지': 41, '무': 41, '양조간장': 41, '후추톡톡': 40, '카놀라유': 39, '대파약간': 39, '표고버섯': 38, '당근조금': 38, '쪽파': 37, '미역줄기': 37, '포도씨유': 36, '기름': 36, '굵은소금': 35, '참깨': 34, '베이컨': 31, '통깨적당량': 31, '통마늘': 31, '콩나물': 30, '식용유적당량': 30, '후춧가루': 29, '참치액': 29, '맛간장': 29, '오징어채': 28, '요리당': 28, '케첩': 27, '참기름조금': 27, '오일': 26, '깨조금': 25, '브로콜리': 24, '양배추': 24, '통깨솔솔': 24, '오이': 23, '다진대파': 23, '견과류': 22, '피망': 22, '올리브오일': 21, '아몬드': 21, '액젓': 20, '후추조금': 20, '식초': 20, '멸치액젓': 20, '고추기름': 20, '소금조금': 19, '맛소금': 19, '지리멸치': 19, '대파조금': 19, '햄': 18, '청경채': 18, '김치': 18, '버터': 17, '두부': 17, '숙주': 17, '소세지': 17, '호두': 17, '카레가루': 17, '청양초': 17, '조청': 17, '황태채': 16, '풋고추': 16, '청고추': 16, '고추': 15, '소주': 15, '식용류': 15, '후추가루약간': 15, '스팸': 14, '중멸치': 14, '대파적당량': 14, '노랑파프리카': 14, '빨강파프리카': 14, '마늘종': 13, '달걀': 13, '참치': 13, '파약간': 13, '팽이버섯': 13, '호박': 13, '카놀라유적당량': 13, '슬라이스아몬드': 13, '묵은지': 13, '오징어실채': 13, '새우': 12, '황설탕': 12, '염장미역줄기': 12, '마른새우': 12, '꽃소금': 12, '두반장': 12, '부추': 11, '다진마늘조금': 11, '계란': 11, '집간장': 11, '깨소금조금': 11, '참깨약간': 11, '까나리액젓': 11, '대파흰부분': 11, '생강술': 10, '닭가슴살': 10, '전분': 10, '땡초': 10, '비엔나소시지': 10, '오뎅': 10, '해바라기씨': 10, '다진마늘약간': 10, '깻잎': 9, '후추톡톡톡': 9, '참치캔': 9, '생수': 9, '양파(중)': 9, '당근적당량': 9, '양파작은것': 9, '매실액기스': 9, '빨간파프리카': 9, '멸치육수': 9, '청량고추': 9, '생강가루': 9, '천일염': 9, '후춧가루적당량': 8, '돼지고기다짐육': 8, '쥐포': 8, '명엽채': 8, '검은깨': 8, '된장': 8, '통깨적당히': 8, '들기름약간': 8, '갈색설탕': 8, '양파작은거': 8, '신김치': 8, '통깨톡톡': 8, '후추가루': 8, '갈은깨': 8, '노란파프리카': 8, '볶은참깨': 8, '아몬드슬라이스': 8, '미니새송이버섯': 7, '우엉': 7, '소고기': 7, '시금치': 7, '카놀라유약간': 7, '양송이버섯': 7, '맛살': 7, '생강청': 7, '파조금': 7, '생강': 7, '다시다': 7, '참기름적당량': 7, '감자(중)': 7, '후춧가루조금': 7, '고구마줄기': 7, '편마늘': 7, '실파': 7, '고운고추가루': 7, '땅콩': 7, '다진청양고추': 7, '통깨팍팍': 6, '청피망': 6, '납작어묵': 6, '파프리카조금': 6, '캔참치': 6, '깻잎순': 6, '참기름살짝': 6, '칵테일새우': 6, '쌀뜨물': 6, '소금적당량': 6, '고구마순': 6, '식용유조금': 6, '기름약간': 6, '볶음용멸치': 6, '돼지고기': 6, '양파약간': 6, '당근소량': 6, '다진소고기': 5, '다진쪽파': 5, '소고기다짐육': 5, '무우': 5, '양파적당량': 5, '생표고버섯': 5, '양파조금': 5, '감자중간크기': 5, '전분가루': 5, '둥근호박': 5, '호박씨': 5, '토마토': 5, '굵은소금약간': 5, '다시마육수': 5, '고운소금': 5, '생강가루약간': 5, '청량초': 5, '스테이크소스': 5, '볶음깨': 5, '참깨조금': 5, '후추적당량': 4, '버섯': 4, '올리브유적당량': 4, '소시지': 4, '조림간장': 4, '쪽파조금': 4, '밥새우': 4, '다시마우린물': 4, '배추': 4, '오징어': 4, '대파(흰부분)': 4, '부순깨': 4, '대파초록부분': 4, '판어묵': 4, '올리브유적당히': 4, '간돼지고기': 4, '다진파조금': 4, '양파(소)': 4, '불린고사리': 4, '보리새우': 4, '들깨': 4, '소금살짝': 4, '새송이': 4, '현미유': 4, '케쳡': 4, '썬대파': 4, '해바라기유': 4, '후추살짝': 4, '깨적당량': 4, '설탕약간': 4, '홍고추약간': 4, '참치액젓': 4, '고운고춧가루': 4, '볶음멸치': 4, '크랜베리': 4, '생강즙': 4, '송송썬쪽파': 4, '매실원액': 4, '감자(중간사이즈)': 3, '후춧가루톡톡': 3, '붉은고추': 3, '술': 3, '고추장듬뿍': 3, '다진돼지고기': 3, '방울토마토': 3, '볼어묵': 3, '기름조금': 3, '홍청양고추': 3, '토마토케첩': 3, '북어채': 3, '식용유넉넉히': 3, '후추적당히': 3, '진미오징어채': 3, '깨적당히': 3, '후춧가루적당히': 3, '원당': 3, '핫소스': 3, '통깨넉넉히': 3, '멸치(멸치볶음)': 3, '다진생강': 3, '감자작은것': 3, '케챱': 3, '양배추약간': 3, '구운소금': 3, '레몬즙': 3, '숙주나물': 3, '둥근애호박': 3, '참기름(들기름)': 3, '스팸햄': 3, '파프리카약간': 3, '아스파라거스': 3, '기름적당량': 3, '깐마늘': 3, '포도씨유약간': 3, '다진파약간': 3, '마늘다진것': 3, '실파약간': 3, '공심채': 3, '요리유': 3, '저염액젓': 3, '통들깨': 3, '슬라이스햄': 3, '후춧가루살짝': 3, '올리고당적당량': 3, '후랑크소세지': 3, '시래기': 3, '소금소량': 3, '설탕조금': 3, '올리브유약간': 3, '실치': 3, '잣': 3, '마른잔멸치': 3, '묵은김치': 3, '김치국물': 3, '칠리소스': 3,  ...

# %%
[recipe[f'ingredient{i}'] for i in range(1, 25)]
# Out:
# [0          애호박
#  1          건새우
#  2           부추
#  3          베이컨
#  4           깻잎
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient1, Length: 156701, dtype: object,
#  0         다진마늘
#  1            물
#  2           달걀
#  3           양파
#  4           대파
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient2, Length: 156701, dtype: object,
#  0              소금
#  1             마늘종
#  2             식용유
#  3         미니새송이버섯
#  4            다진마늘
#             ...
#  168819       None
#  168820       None
#  168821       None
#  168822       None
#  168824       None
#  Name: ingredient3, Length: 156701, dtype: object,
#  0          참기름
#  1           소금
#  2            밥
#  3         다진마늘
#  4          국간장
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient4, Length: 156701, dtype: object,
#  0         식용유또는들기름
#  1               설탕
#  2              굴소스
#  3              굴소스
#  4              참기름
#              ...
#  168819        None
#  168820        None
#  168821        None
#  168822        None
#  168824        None
#  Name: ingredient5, Length: 156701, dtype: object,
#  0         None
#  1           간장
#  2          참기름
#  3         None
#  4         들깨가루
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient6, Length: 156701, dtype: object,
#  0         None
#  1          식용유
#  2         None
#  3         None
#  4            깨
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient7, Length: 156701, dtype: object,
#  0         None
#  1          참기름
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient8, Length: 156701, dtype: object,
#  0         None
#  1           물엿
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient9, Length: 156701, dtype: object,
#  0         None
#  1           통깨
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient10, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient11, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient12, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient13, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient14, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient15, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient16, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient17, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient18, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient19, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient20, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient21, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient22, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient23, Length: 156701, dtype: object,
#  0         None
#  1         None
#  2         None
#  3         None
#  4         None
#            ...
#  168819    None
#  168820    None
#  168821    None
#  168822    None
#  168824    None
#  Name: ingredient24, Length: 156701, dtype: object]

# %%
from embedding import convert_fraction_to_float, convert_unit_to_number

ingredient_columns = recipe.filter(like='ingredient').drop(columns=['recipe_ingredients']) # 'ingredient'가 포함된 모든 열 선택
all_ingredients = [item for sublist in ingredient_columns.values for item in sublist if pd.notna(item)] # 각 행의 ingredient 값을 하나의 리스트로 결합

# %%
unique_ingred = list(set(all_ingredients))

# %%
unique_ingred
# Out:
# ['참깨톡톡',
#  '물(소주컵)',
#  '맛간장',
#  '볶음용멸치',
#  '황설탕',
#  '진미오징어채',
#  '양배추약간',
#  '구운소금',
#  '다진마늘약간',
#  '슬라이드아몬드',
#  '비엔나소세지',
#  '오징어',
#  '굵은소금',
#  '미니파프리카',
#  '꽃소금',
#  '식용류',
#  '절이는소금',
#  '실파약간',
#  '불고기용소고기',
#  '고추잎',
#  '케찹',
#  '양조간장',
#  '고추기름',
#  '갈은깨',
#  '양파작',
#  '다진청양고추',
#  '납작오뎅',
#  '대파송송',
#  '깨소금(참기름)',
#  '깨소금약간',
#  '진미채오징어',
#  '감자',
#  '숙주나물',
#  '후춧가루소량',
#  '술',
#  '브로콜리',
#  '요리유',
#  '홍청양고추',
#  '부추나쪽파조금',
#  '치즈가루(생략가능)',
#  '통들깨약간',
#  '맛술',
#  '쪽파(대파)',
#  '다시마우린물',
#  '북어채또는황태채',
#  '파약간',
#  '파프리카각각',
#  '김치',
#  '묵은김치',
#  '물종이컵',
#  '통마늘원하는만큼',
#  '마늘종(마늘속대)',
#  '양파작은거',
#  '올리고당',
#  '대파손가락',
#  '샐러리',
#  '홍고추약간',
#  '케첩',
#  '쌀뜨물',
#  '들깨',
#  '공심채',
#  '버터',
#  '새송이버섯',
#  '양파채',
#  '파프리카색깔별로',
#  '가지작은거',
#  '쪽파약간',
#  '느타리버섯적당량',
#  '채썬햄',
#  '소금톡톡',
#  '밀가루소량',
#  '맛소금약간',
#  '팽이버섯',
#  '시판스테이크(햄)',
#  '깐마늘',
#  '건곤드레나물',
#  '무중',
#  '묵은갓김치',
#  '미니돈까스',
#  '설탕(또는물엿)',
#  '청양고추(생략가능)',
#  '오이',
#  '다시마',
#  '물약간',
#  '염장미역줄기',
#  '참깨',
#  '깨살짝',
#  '후추(취향에따라)',
#  '통깨또는다진땅콩적당량',
#  '삼색파프리카',
#  '고구마줄기',
#  '마늘쫑약',
#  '호박',
#  '재료',
#  '지리멸치적당량',
#  '청주나미림',
#  '고춧가루',
#  '빅비엔나소세지',
#  '식용유조금',
#  '멸치(지리멸)',
#  '깨적당량',
#  '식용유(두르기)',
#  '파슬리가루약간',
#  '숙주',
#  '두반장',
#  '콩나물',
#  '기름(현미)',
#  '후추톡',
#  '깻잎',
#  '마일드스팸',
#  '땅콩',
#  '설탕',
#  '물살짝',
#  '피망',
#  '올리고당큰바퀴',
#  '달걀',
#  '둥근애호박',
#  '깨소금(깨으깬것)',
#  '양파다진것',
#  '작은무',
#  '다진마늘조금',
#  '자리멸치',
#  '고구마순삶는데넣는소금',
#  '돼지고기다짐육크게',
#  '식초',
#  '밥',
#  '종합어묵',
#  '깨넉넉히',
#  '숙주어묵과동량',
#  '진간장혹은양조간장',
#  '깐도라지',
#  '맛술또는생강술',
#  '굴소스(유기농)',
#  '올리고당약간',
#  '다시마멸치육수',
#  '카놀라유조금',
#  '감자작은거',
#  '사각햄',
#  '매실청',
#  '황태포',
#  '파프리카빨간색조금',
#  '깨소금(생략가능)',
#  '깨소금조금',
#  '마른새우',
#  '노란색파프리카',
#  '청양고추옵션',
#  '파적당히',
#  '소시지긴거',
#  '청고추',
#  '황태',
#  '고운소금',
#  '물소주컵',
#  '방울양배추',
#  '건미역',
#  '파프리카약간',
#  '식용유약간',
#  '미향',
#  '표고버섯',
#  '만가닥버섯',
#  '마늘종',
#  '감자(중간사이즈)',
#  '콩가루',
#  '고추가루',
#  '대파(어묵부피와비슷하게)',
#  '마늘(편썰기)',
#  '파프리카조금씩(선택)',
#  '소금적당량',
#  '양송이버섯',
#  '멸치(내장제거)',
#  '메실청',
#  '실고추(생략가능)',
#  '통깨약간',
#  '감자크것은',
#  '파흰부분다져서',
#  '검은깨약간',
#  '참깨가루',
#  '원당',
#  '깨약간씩',
#  '물엿(생략가능)',
#  '빨강파프리카약간',
#  '볶은참깨약간',
#  '파슬리약간',
#  '갈은소고기',
#  '물오뎅이잠길만큼',
#  '크래미소포장',
#  '소세지',
#  '건새우',
#  '오리고기적당히',
#  '조림간장',
#  '아몬드슬라이스약간',
#  '파채적당히',
#  '새우젓적당량',
#  '홍당무조금',
#  '둥근긴어묵',
#  '썰어놓은대파',
#  '흑후추조금',
#  '고구마순',
#  '명란',
#  '통깨적당량',
#  '닭가슴살',
#  '대파',
#  '배즙',
#  '파프리카적당량',
#  '햄약간',
#  '포도씨유또는카놀라유',
#  '천일염약간',
#  '설탕수북히',
#  '땡초',
#  '통통한게맛살',
#  '오이(대)',
#  '소금(부족하간)',
#  '손질다시멸치',
#  '송송썬대파듬뿍',
#  '고운고춧가루',
#  '굴소스',
#  '미림',
#  '들기름',
#  '작은양파',
#  '납작어묵',
#  '맛타리버섯',
#  '삶은꼬막',
#  '청주',
#  '홍고추',
#  '마늘약간',
#  '진미채',
#  '브로콜리작은거',
#  '둥근호박',
#  '올리고당(가늘게)',
#  '김장김치',
#  '식용유적당히',
#  '맛살(선택)',
#  '검은깨',
#  '절임소금',
#  '통들깨',
#  '다진소고기',
#  '감자(대)',
#  '고추장',
#  '요리당',
#  '감자중간사이즈',
#  '김칫국물',
#  '기름',
#  '카놀라유적당히',
#  '중간사이즈양파',
#  '들깻가루',
#  '황태껍질손질후',
#  '들깨가루',
#  '풋마늘',
#  '양파통깨',
#  '식용유넉넉하게',
#  '빨간파프리카',
#  '파조금',
#  '마른고추',
#  '볶은참깨',
#  '양파약간',
#  '햄프씨드',
#  '편마늘',
#  '대파초록부분',
#  '소고기다짐육',
#  '파프리카작은것',
#  '우유한컵(소주잔)',
#  '총각김치',
#  '팽이',
#  '다진마늘',
#  '흑임자',
#  '다시마육수또는물',
#  '올리브유적당히두르기',
#  '파프리카빨강',
#  '통깨조금',
#  '양파작은',
#  '마요네즈약간',
#  '두부',
#  '고구마',
#  '버터조금',
#  '당근적당량',
#  '불린고사리',
#  '홍진미(백진미도좋음)',
#  '참치캔작은거',
#  '미니빨강파프리카',
#  '후추가루톡톡톡',
#  '자투리채소',
#  '송송썬대파',
#  '양배추적당히',
#  '무채',
#  '잣',
#  '레몬즙',
#  '당근적당히',
#  '완두콩',
#  '올리브유약간',
#  '고추씨기름',
#  '자일로스설탕',
#  '실채',
#  '고추기름(또는식용유)',
#  '후추적당량',
#  '칠리소스',
#  '오일약간',
#  '햄(천원짜리사각햄)',
#  '느타리버섯',
#  '냉장햄',
#  '통깨',
#  '오징어채',
#  '생강술',
#  '닭가슴살(무항생제)',
#  '감자작은것',
#  '참기름살짝',
#  '카레',
#  '파프리카빨강적당량',
#  '백만송이버섯',
#  '해바라기씨적당량',
#  '카놀라유약간',
#  '명엽채',
#  '유자청',
#  '황태채',
#  '녹차유',
#  '고추',
#  '청양초',
#  '양파(어묵부피와비슷하게)',
#  '이탈리안시즈닝',
#  '대파약간',
#  '포도씨유약간',
#  '설탕아주조금',
#  '참기름약간',
#  '파프리카노랑이',
#  '느타리',
#  '아몬드슬라이스',
#  '네모어묵약간',
#  '후추톡톡톡',
#  '다시마우린물감자잠기게',
#  '고수',
#  '볶음소금',
#  '마늘슬라이스',
#  '미소된장',
#  '깨조금',
#  '양파(소)',
#  '멸치육수',
#  '조랭이떡',
#  '고운고추가루',
#  '떡국떡',
#  '페페로치노',
#  '매운고추',
#  '고구마순데친것',
#  '다진파조금',
#  '마무리볶음들기름',
#  '식용류약간',
#  '통깨톡톡톡',
#  '조청',
#  '발사믹식초',
#  '후춧가루톡톡',
#  '소금살짝',
#  '후추약간',
#  '삶은계란',
#  '허브솔트약간',
#  '동글어묵',
#  '애호박약간',
#  '감자(중)',
#  '고추약간',
#  '생강또는생강가루',
#  '청파프리카',
#  '두반장소스(고춧가루와간장으로대체가능)',
#  '다진대파약간',
#  '검은깨적당량',
#  '소주',
#  '맛간장(시판용가능)',
#  '두반장소스',
#  '대파적당량',
#  '마늘쫑',
#  '양파고추장아찌물',
#  '대파조금',
#  '전분가루적당량',
#  '카놀라유',
#  '다진파약간',
#  '들기름적당량',
#  '쪽파',
#  '파기름',
#  '볶은통깨',
#  '무',
#  '오징어실채',
#  '부추적당량',
#  '통깨솔솔솔',
#  '묵은지(배추김치)',
#  '다진생강',
#  '마늘소금',
#  '청경채',
#  '흑설탕',
#  '진미채양껏',
#  '양파(중)',
#  '적양파(작)',
#  '맛소금',
#  '국물용멸치',
#  '사각오뎅',
#  '현미유',
#  '마늘다진것',
#  '후랑크소세지',
#  '생표고버섯',
#  '소고기',
#  '청양고추',
#  '깨약간',
#  '매실엑기스',
#  '파마산치즈가루약간',
#  '양파청(매실청)',
#  '후춧가루톡톡톡',
#  '양파작은것',
#  '후추',
#  '식용유적당량',
#  '비엔나소시지',
#  '새우젓국물',
#  '네모어묵',
#  '청양고추취향껏',
#  '송송썬파',
#  '감자대',
#  '다진홍고추',
#  '건새우소복하게',
#  '멸치액젓',
#  '깨소량',
#  '사각어묵',
#  '설탕조금',
#  '지리멸치',
#  '생강가루약간',
#  '청량초',
#  '생강소스',
#  '유부',
#  '국산들깨가루',
#  '건고추',
#  '만능간장또는국간장약간',
#  '생수',
#  '대파푸른부분',
#  '후춧가루살짝',
#  '꼬마새송이버섯',
#  '멸치',
#  '된장',
#  '참깨솔솔',
#  '잔멸치',
#  '돼지고기다짐육',
#  '하루견과류',
#  '파흰부분',
#  '파프리카빨강이',
#  '아귀포',
#  '청양고춧가루',
#  '국간장적당히',
#  '육수',
#  '통그릴비엔나',
#  '죽염조금',
#  '액젓',
#  '소금조금',
#  '멸치(멸치볶음)',
#  '무지름',
#  '매실액기스',
#  '오일',
#  '중멸치',
#  '아스파라거스',
#  '꿀',
#  '김가루약간',
#  '미역줄기볶음',
#  '생강가루',
#  '양파반개',
#  '청주또는맛술',
#  '까나리액젓',
#  '소금필요시소량',
#  '로스팜',
#  '한식간장',
#  '물반컵',
#  '당근약간(색감을위해)',
#  '슬라이스아몬드',
#  '가는고춧가루',
#  '통깨솔솔',
#  '단단한두부',
#  '건호박',
#  '후추가루조금',
#  '마른꼴뚜기',
#  '청피망',
#  '채썬당근',
#  '물(상황에따라)',
#  '야채어묵',
#  '통조림햄',
#  '깨',
#  '양배추반통의잎',
#  '오뎅한봉지',
#  '견과류',
#  '마른멸치',
#  '깨소금',
#  '통조림참치',
#  '켄터키소시지',
#  '분홍소세지적당량',
#  '작은대파',
#  '아몬드',
#  '볶음멸치',
#  '홍고추아주조금',
#  '쥐포',
#  '볼어묵',
#  '죽봉어묵',
#  '케챂',
#  '고추장(평평하게깎아서계량)',
#  '어묵볼',
#  '진미채한줌약',
#  '꽃새우또는건새우',
#  '소고기(갈은것)',
#  '홍피망',
#  '브로콜리소량(없어도무관)',
#  '물약',
#  '호박중간크기',
#  '송송썬대파약간',
#  '노랑파프리카',
#  '파프리카노란색조금',
#  '홈메이드맛술(생강술)',
#  '물엿',
#  '카놀라유적당량',
#  '사가어묵',
#  '삼겹살',
#  '다짐육소고기',
#  '양파큰거',
#  '올리브유(또는식용유)',
#  '국간장',
#  '참기름적당량',
#  '식용유',
#  '정종',
#  '손가락어묵',
#  '다진돼지고기',
#  '파프리카노랑적당량',
#  '떡',
#  '깻잎(깨순)',
#  '고춧기름',
#  '돼지고기목살슬라이스',
#  '대파밑부분',
#  '아몬드적당량',
#  '참기름주르륵',
#  '햄',
#  '후추톡톡',
#  '칵테일새우',
#  '취나물',
#  '주황파프리카약간',
#  '집간장',
#  '파슬리가루',
#  '볶음깨약간',
#  '다진만르',
#  '양배추',
#  '곤약',
#  '참기름(들기름)',
#  '스팸',
#  '데친브로콜리',
#  '후춧가루약간',
#  '냉압착올리브유조금',
#  '무김치',
#  '소금소량',
#  '참기름',
#  '대파(흰부분)',
#  '간생강적당히',
#  '적파프리카',
#  '굵은고추가루',
#  '당근조금',
#  '캔참치',
#  '참치',
#  '물',
#  '매운고추장',
#  '통깨가루조금',
#  '보리새우',
#  '생굴',
#  '볶은소금',
#  '간마늘',
#  '통깨적당히',
#  '볶은소금약간',
#  '견과류약간',
#  '올리브오일',
#  '식용유넉넉히',
#  '통마늘',
#  '감자중간크기',
#  '숟가락계량입니다',
#  '표고버섯큰것',
#  '캔옥수수',
#  '실치',
#  '페퍼론치노',
#  '파',
#  '무우',
#  '세멸치',
#  '다용도맛간장',
#  '썰어놓은양파',
#  '다진생강약간',
#  '케쳡',
#  '쥐똥고추',
#  '통깨듬',
#  '해바라기씨',
#  '마늘취향껏',
#  '파프리카',
#  '비엔나',
#  '통깨양념',
#  '대파송송송',
#  '쥬키니호박',
#  '통깨톡톡',
#  '스팸햄',
#  '올리브오일약간',
#  '대파흰부분',
#  '올리브유',
#  '깐밤',
#  '파프리카조금',
#  '홍고추적당량',
#  '당근작은것',
#  '오뎅(사각)',
#  '청피망작은거',
#  '천일염적당량',
#  '묵은지',
#  '미림(맛술)',
#  '익은총각김치',
#  '남은치킨',
#  '멸치(중간사이즈)',
#  '올리브유적당량',
#  '어묵넙적한거',
#  '토마토케첩',
#  '간돼지고기',
#  '당근',
#  '마른꽃새우',
#  '청량고추또는대파',
#  '통깨넉넉히',
#  '가지절임소금',
#  '가시오이',
#  '참치캔',
#  '부추조금',
#  '미원',
#  '건새우한봉지',
#  '맛간장(진간장)',
#  '햄길게',
#  '간깨',
#  '통깨적당',
#  '오징어진미채',
#  '토마토',
#  '썬파',
#  '배추',
#  '토마토소스',
#  '기름약간',
#  '소금(죽염)',
#  '파다진것',
#  '실파',
#  '새송이',
#  '베이컨',
#  '감자큰것',
#  '청양홍고추',
#  '식용유또는들기름',
#  '매실액약간',
#  '애호박',
#  '잔파',
#  '건새우적당량',
#  '새우젓국물없이',
#  '깨취향껏',
#  '콜라비',
#  '기름조금',
#  '양송이큰거',
#  '대파흰대',
#  '마늘',
#  '무청',
#  '미림(청주)',
#  '자숙문어',
#  '백후추약간',
#  '중간크기감자',
#  '다진양파',
#  '시래기',
#  '해바라기유',
#  '볶음용잔멸치',
#  '진간장',
#  '진간장또는만능간장',
#  '짜장가루',
#  '고추장듬뿍',
#  '닭고기정육',
#  '어묵',
#  '썬대파',
#  '천연조미료',
#  '깻잎순',
#  '파프리카노랑',
#  '돼지고기',
#  '스모크햄',
#  '시금치',
#  '굵은소금약간',
#  '저온압착들기름조금',
#  '돈까스소스',
#  '올리브고당',
#  '콩나물한봉지',
#  '미니새송이버섯',
#  '송손썬대파',
#  '미니새송이',
#  '설탕(올리고당)',
#  '마른잔멸치',
#  '다시다',
#  '청량고추',
#  '호두',
#  '풋고추',
#  '깨소금살짝',
#  '당근약간',
#  '꿀이나올리고당',
#  '브로콜리약간',
#  '참기름조금',
#  '다시마물',
#  '생강',
#  '라임즙',
#  '뜨거운물',
#  '냉동새우',
#  '부추',
#  '햇양파',
#  '참깨약간',
#  '건표고버섯',
#  '노랑파프리카약간',
#  '우엉',
#  '후춧가루',
#  '공기밥',
#  '깨소금톡톡',
#  '계란',
#  '양파적당량',
#  '진미채(오징어채)',
#  '매실액',
#  '배추잎',
#  '생강청',
#  '갈색설탕',
#  '해바라기유조금',
#  '비엔나소시지(선택)',
#  '크랜베리',
#  '땅콩적당량',
#  '볶은천일염',
#  '호박씨',
#  '빨간색파프리카',
#  '소금약간',
#  '올리고당적당량',
#  '올리고당(물엿)',
#  '소금',
#  '생강매실맛술',
#  '소고기(다짐육)',
#  '올리브유적당히',
#  '허브솔트조금',
#  '익은김치',
#  '전분가루',
#  '손질한가지',
#  '작은송이로손질한브로콜리',
#  '참치액',
#  '맛살',
#  '쥐포(손바닥크기)',
#  '무작은',
#  '오이절일때소금',
#  '들(참)',
#  '캐첩',
#  '지가멸치',
#  '방울토마토',
#  '메추리알',
#  '연근',
#  '소시지',
#  '부순깨',
#  '파래김',
#  '페퍼치노고추',
#  '작은멸치',
#  '간장',
#  '새우젓(건더기만)',
#  '비트',
#  '붉은고추',
#  '아보카도오일또는각각올리브오일',
#  '들기름또는참기름',
#  '핫소스',
#  '파슬리가루조금',
#  '반건조오징어',
#  '허브소금',
#  '빨강파프리카조금',
#  '다시마채천원분량',
#  '깻가루',
#  '조미료적당히',
#  '후추살짝',
#  '고추(청양고추)',
#  '후추가루약간',
#  '조청쌀엿',
#  '미니노랑파프리카',
#  '고구마줄기다듬은후',
#  '새우젓',
#  '페페로치노또는베트남고추',
#  '간장소주잔',
#  '마요네즈',
#  '슬라이스햄',
#  '돈가스소스',
#  '후추적당히',
#  '당근(어묵부피의반정도)',
#  '맛술(소주)',
#  '고기버섯',
#  '다진홍청양고추',
#  '마늘조금씩',
#  '조미도시락김',
#  '다진파',
#  '한우(살치살)',
#  '새우살',
#  '설탕약간',
#  '저염액젓',
#  '타바스코핫소스취향껏',
#  '불고기맛햄',
#  '전분',
#  '새우',
#  '마른새우(꽃새우)',
#  '카놀라이유약간',
#  '대파(송송썬것)',
#  '통깨팍팍',
#  '다시마육수',
#  '들기름조금',
#  '쪽파조금',
#  '꽃새우',
#  '호박씨적당량',
#  '참치액젓',
#  '두절건새우',
#  '후추가루',
#  '포도씨유',
#  '오뎅',
#  '가지큰사이즈면',
#  '고춧가루취향껏',
#  '다진대파',
#  '구운김조금',
#  '양파중',
#  '다시다약간',
#  '양파',
#  '판어묵',
#  '깨적당히',
#  '손질된칵테일생새우',
#  '코코넛오일',
#  '노란파프리카',
#  '바질페스토',
#  '다진쪽파',
#  '통깨툭툭',
#  '미역줄기',
#  '가지',
#  '후춧가루적당량',
#  '마른김또는눅눅해진김',
#  '기름적당량',
#  '미림소주잔',
#  '밥새우',
#  '후추조금',
#  '후춧가루조금',
#  '햄조금',
#  '전분물',
#  '잘게썬청양고추',
#  '당근(소)',
#  '꽃소금취향껏',
#  '후추참깨',
#  '애기새송이버섯',
#  '당근소량',
#  '빨강파프리카',
#  '후추(선택)',
#  '신김치',
#  '비정제설탕',
#  '들기름약간',
#  '천일염',
#  '스리라차소스',
#  '아보카도오일',
#  '양파기름',
#  '다시마간장',
#  '후춧가루적당히',
#  '꽈리고추',
#  '삶은토란대',
#  '카레가루',
#  '홍',
#  '버섯',
#  '멸치다시마육수(종이컵)',
#  '스리차소스',
#  '김치국물',
#  '깨듬뿍',
#  '신열무',
#  '굵은고춧가루',
#  '치킨스톡',
#  '케챱',
#  '김자반',
#  '머쉬마루버섯',
#  '가는북어채',
#  '잣적당량',
#  '양파조금',
#  '마른청양고추',
#  '북어채',
#  '당근(선택재료)',
#  '게맛살',
#  '파초록부분은크게어슷썰어서']
