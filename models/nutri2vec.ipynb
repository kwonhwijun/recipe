# %% [markdown]
# ### 영양소를 고려한 임베딩

# %%
import pandas as pd

toy = pd.read_csv("data/toy.csv")
ingred = pd.read_csv(r"C:\Users\HwijunKwon\Downloads\농촌진흥청_국립농업과학원_통합식품영양성분정보(원재료성식품)_20230626.csv", encoding='cp949')

# %%
ingred.head()
# Out:
#                   식품코드              식품명 데이터구분코드   데이터구분명  식품기원코드 식품기원명  \
# 0  R101-001010101-0000     귀리_겉귀리_도정_생것       R  원재료성 식품       1   식물성
# 1  R101-001020101-0000     귀리_쌀귀리_도정_생것       R  원재료성 식품       1   식물성
# 2  R101-001030101-0000  귀리_쌀귀리+대양_도정_생것       R  원재료성 식품       1   식물성
# 3  R101-001040101-0000  귀리_쌀귀리+조양_도정_생것       R  원재료성 식품       1   식물성
# 4  R101-003000101-0000         기장_도정_생것       R  원재료성 식품       1   식물성
#
#    식품대분류코드 식품대분류명  대표식품코드 대표식품명  ...               출처명 수입여부  원산지국코드 원산지국명  \
# 0        1     곡류    1001    귀리  ...  농촌진흥청(국가표준식품성분표)    N     NaN  해당없음
# 1        1     곡류    1001    귀리  ...  농촌진흥청(국가표준식품성분표)    N     NaN  해당없음
# 2        1     곡류    1001    귀리  ...  농촌진흥청(국가표준식품성분표)    N     NaN  해당없음
# 3        1     곡류    1001    귀리  ...  농촌진흥청(국가표준식품성분표)    N     NaN  해당없음
# 4        1     곡류    1003    기장  ...  농촌진흥청(국가표준식품성분표)    N     NaN  해당없음
#
#    원산지역명 생산·채취·포획월 데이터생성방법코드  데이터생성방법명     데이터생성일자     데이터기준일자
# 0   해당없음       NaN         1        분석  2016-12-31  2023-06-26
# 1   해당없음       NaN         1        분석  2020-04-01  2023-06-26
# 2   해당없음       NaN         1        분석  2020-04-01  2023-06-26
# 3   해당없음       NaN         1        분석  2020-04-01  2023-06-26
# 4   해당없음       NaN         1        분석  2006-12-31  2023-06-26
#
# [5 rows x 53 columns]
