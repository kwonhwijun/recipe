# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\glori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\glori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.11.3)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.2-cp312-cp312-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.1 MB 991.0 kB/s eta 0:00:10
#    -- ------------------------------------- 0.5/9.1 MB 3.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.1 MB 6.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/9.1 MB 7.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.1 MB 7.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.1 MB 8.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.1/9.1 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.6/9.1 MB 9.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.0/9.1 MB 9.3 MB/s eta 0:00:01
#    -------------------- ------------------- 4.6/9.1 MB 9.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.0/9.1 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.4/9.1 MB 9.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.7/9.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.4/9.1 MB 9.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.7/9.1 MB 9.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.1 MB 9.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.7/9.1 MB 9.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.0/9.1 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.5/9.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 8.7 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------- 302.2/302.2 kB 9.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#func.py
import oracledb as od
import pandas as pd
import numpy as np
import config
from tqdm import tqdm
import ast
import re
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
from scipy.linalg import svd

# %%
def load_recipe(n = 168840):
    od.init_oracle_client(lib_dir=r"C:\Program Files\Oracle\instantclient_21_12") # db connection
    conn = od.connect(user = config.DB_CONFIG['user'], password = config.DB_CONFIG['password'],  dsn = config.DB_CONFIG['dsn'])
    exe = conn.cursor()
    exe.execute(f'select * from recipe_table where rownum <= {n}')
    row = exe.fetchall() # row 불러오기
    column_name = exe.description # column 불러오기
    columns=[]
    for i in column_name:
        columns.append(i[0])
    result = pd.DataFrame(row, columns=columns) # row, column을 pandas DataFrame으로 나타내기
    result.rename(mapper=str.lower, axis='columns', inplace=True)
    conn.close()
    return result

func = load_recipe()

# %%
func
# Out:
#                                        recipe_url  \
# 0       http://www.10000recipe.com/recipe/6966796
# 1       http://www.10000recipe.com/recipe/6851649
# 2       http://www.10000recipe.com/recipe/6983118
# 3       http://www.10000recipe.com/recipe/6946145
# 4       http://www.10000recipe.com/recipe/6844953
# ...                                           ...
# 166506  http://www.10000recipe.com/recipe/6929107
# 166507  http://www.10000recipe.com/recipe/6961108
# 166508  http://www.10000recipe.com/recipe/6964170
# 166509  http://www.10000recipe.com/recipe/6964163
# 166510  http://www.10000recipe.com/recipe/6964154
#
#                         recipe_title recipe_summary1 recipe_summary2  \
# 0           나 순대라고 말 못해요! HACCP인증 제품             1인분          30분 이내
# 1                            시래기 된장국             4인분          30분 이내
# 2                         바질크림파스타만들기             3인분          20분 이내
# 3            돼지 수육 삶는법? 보쌈 삶지 말고 찌세요             3인분         120분 이내
# 4                     브런치 참치에그샐러드만들기             2인분          10분 이내
# ...                              ...             ...             ...
# 166506            몽글 몽글 쉽게 만드는 "계란찜"             2인분          15분 이내
# 166507  새콤달콤한 아삭함이 매력적인 시원한 오이피클 레시피             4인분          20분 이내
# 166508               초 간단 오징어실채 무침~*             3인분           5분 이내
# 166509       새로운 비법양념으로 무친 대파김치청포묵무침             2인분          10분 이내
# 166510           참치캔 고추장 무침 만들어 보세요.             1인분           5분 이내
#
#        recipe_summary3                                 recipe_ingredients  \
# 0                  아무나  {'재료': ['HACCP인증순대90g', 'HACCP인증체다치즈4장', 'HACC...
# 1                  아무나  {'재료': ['신광에코팜시래기1팩(300g)', '된장2T', '멸치1주먹', '...
# 2                  아무나  {'재료': ['폰타나제노바치즈&바질페스토1병', '통마늘6알', '베이컨3줄', ...
# 3                   초급  {'수육 위에 얹어줄 재료': ['돼지고기3덩이', '양파1개', '대파또는쪽파원하...
# 4                  아무나  {'재료': ['달걀(삶은거)4개', '참치캔1개', '상추(or양상추)', '게맛...
# ...                ...                                                ...
# 166506              초급  {'재료': ['계란6개', '간장1수저', '설탕1수저', '미림1수저', '물1...
# 166507             아무나  {'재료': ['오이1개', '소금1/2T'], '소스': ['물1종이컵', '설탕...
# 166508             아무나  {'재료': ['오징어실채110g'], '양념': ['간장2큰술', '참기름1.5큰...
# 166509             아무나  {'재료': ['청포묵1팩', '대파김치1/2컵', '김가루'], '양념': ['갈...
# 166510             아무나  {'재료': ['참치캔1캔', '다진마늘1/2Ts', '고추장2Ts', '설탕1/2...
#
#                                               recipe_step  \
# 0       ['#1 HACCP인증 제품입니다', '#2 맛술,요리당,고추장,후추,굴소스 HAC...
# 1       ['#1 먼저 물에 멸치 한주먹과 다시마 1조각을 넣고 육수를 우려내 주세요~!',...
# 2       ['#1 폰타나 소스를 주로 이용하는 편이예요 베이컨머쉬룸 소스도 맛있더라구요 신랑...
# 3       ['#1 커피 3스푼과 소금 1스푼을 따뜻한 물 1컵에 녹여주세요. 그리고 찜기 밑...
# 4       ['#1 달걀을 먼저 삶아 줍니다. 완숙은 7분정도이고 반숙은 4분이면 됩니다.',...
# ...                                                   ...
# 166506  ['#1 계란 6개를 준비한다', '#2 설탕 1수저와 소금 1/2수저를 넣어준다'...
# 166507  ['#1 손에 소금 1/2T를 얹어 오이 표면을 골고루 비벼주세요. 소금으로 오이표...
# 166508  ['#1 오징어실채 탈탈 털어 볼에담고 가위로 한 두번 잘라준다', '#2 간장,고...
# 166509  ['#1 청포묵을 준비합니다', '#2 물을 끓입니다', '#3 청포묵을 썰어놓습니...
# 166510  ['#1 참치캔은 기름을 제거한다.', '#2 기름을 제거한 참치는 그릇에 담는다....
#
#                                                recipe_tag  recipe_comment  \
# 0          ['HACCP', '해썹인증제품', '맛있는한끼', '순대요리', '순대말이조림']             1.0
# 1       ['시래기', '무청', '시래기국', '된장', '시래기 된장국', '국', '반...             0.0
# 2                             ['폰타나소스로파스타만들기', '바질크림파스타']             0.0
# 3       ['돼지고기', '수육', '보쌈', '보쌈찌기', '수육찌기', '돼지고기요리',...             1.0
# 4       ['샐러드', '참치샐러드', '에그샐러드', '참치에그샐러드', '레몬즙 올리브유...             5.0
# ...                                                   ...             ...
# 166506                                                 []             0.0
# 166507  ['오이', '오이피클', '오이피클만들기', '오이피클만드는방법', '수제오이피클...             0.0
# 166508  ['간단밑반찬', '오징어실채', '마른반찬', '도시락반찬', '아이들반찬', '...             0.0
# 166509  ['대파김치청포묵무침', '청포묵무침', '청포묵', '묵무침', '묵요리', '한...             0.0
# 166510  ['참치캔', '참치캔 레시피', '참치캔 반찬', '참치캔 요리', '참치캔 무침...             0.0
#
#         recipe_view recipe_category_type recipe_category_method  \
# 0             570.0                 메인반찬                     조림
# 1            4449.0                  국/탕                    끓이기
# 2             138.0                   양식                     볶음
# 3            7825.0                 메인반찬                      찜
# 4           10000.0                  샐러드                     기타
# ...             ...                  ...                    ...
# 166506       3714.0                  밑반찬                      찜
# 166507       1210.0                  밑반찬                     절임
# 166508        706.0                  밑반찬                     무침
# 166509        873.0                  밑반찬                     무침
# 166510        587.0                  밑반찬                     무침
#
#        recipe_category_situation
# 0                            술안주
# 1                             일상
# 2                           초스피드
# 3                            영양식
# 4                           초스피드
# ...                          ...
# 166506                        일상
# 166507                        일상
# 166508                        일상
# 166509                        일상
# 166510                        일상
#
# [166511 rows x 13 columns]

# %%
import pandas as pd
data = pd.read_csv(r'data\RecipeData.csv')
recipe_ingre_pd = data[['recipe_title', 'recipe_ingredients']]
recipe_ingre_pd
# Out:
#                          recipe_title  \
# 0       비빔밥재료 애호박나물 애호박볶음 아삭거리게 볶는 방법
# 1               [마늘종볶음]단짠단짠 자꾸만 손이가요~
# 2                       백종원의 부추 달걀 볶음
# 3           간단하게 맛난 반찬 만들기 '베이컨 버섯볶음'
# 4                     고소하고 향긋한 깻잎들깨볶음
# ...                               ...
# 168835                            콩비지
# 168836                  바닐라 견과류 아이스크림
# 168837                    무즙 얹은 흰살 생선
# 168838                    무즙 얹은 흰살 생선
# 168839                 머스크 멜론 맛있게 깍는법
#
#                                        recipe_ingredients
# 0       {'재료': ['애호박1개', '다진마늘0.5큰술', '소금0.5큰술', '참기름1...
# 1       {'재료': ['건새우50g', '물1/4컵', '마늘종300g', '소금1/3큰술...
# 2       {'재료': ['부추1줌', '달걀4개', '식용유2큰술', '밥2공기'], '양념...
# 3       {'재료': ['베이컨5~6줄', '양파1/2개', '미니새송이버섯7개', '다진마...
# 4       {'재료': ['깻잎', '대파', '다진마늘1T', '국간장1T', '참기름1T'...
# ...                                                   ...
# 168835                                                 {}
# 168836                                                 {}
# 168837                                                 {}
# 168838                                                 {}
# 168839                                                 {}
#
# [168840 rows x 2 columns]

# %%
def recipe_preprocessing(raw):
    data = raw.loc[raw['recipe_ingredients'].notnull()].copy()  # None 값 제거

    def clean_ingredients(ingredients):
        if ingredients is not None:
            ingredients = ingredients.replace('\\ufeff', '').replace('\\u200b', '')
        return ingredients

    def not_empty_ingredients(row):
        return row['recipe_ingredients'].strip() != '{}' # 결측치 제거

    data = data[data.apply(not_empty_ingredients, axis=1)]
    data["recipe_ingredients"] = data["recipe_ingredients"].apply(clean_ingredients)
    result = data[['recipe_title', 'recipe_ingredients']]

    return result

func_pre = recipe_preprocessing(func)

# %%
func_pre
# Out:
#                         recipe_title  \
# 0           나 순대라고 말 못해요! HACCP인증 제품
# 1                            시래기 된장국
# 2                         바질크림파스타만들기
# 3            돼지 수육 삶는법? 보쌈 삶지 말고 찌세요
# 4                     브런치 참치에그샐러드만들기
# ...                              ...
# 166506            몽글 몽글 쉽게 만드는 "계란찜"
# 166507  새콤달콤한 아삭함이 매력적인 시원한 오이피클 레시피
# 166508               초 간단 오징어실채 무침~*
# 166509       새로운 비법양념으로 무친 대파김치청포묵무침
# 166510           참치캔 고추장 무침 만들어 보세요.
#
#                                        recipe_ingredients
# 0       {'재료': ['HACCP인증순대90g', 'HACCP인증체다치즈4장', 'HACC...
# 1       {'재료': ['신광에코팜시래기1팩(300g)', '된장2T', '멸치1주먹', '...
# 2       {'재료': ['폰타나제노바치즈&바질페스토1병', '통마늘6알', '베이컨3줄', ...
# 3       {'수육 위에 얹어줄 재료': ['돼지고기3덩이', '양파1개', '대파또는쪽파원하...
# 4       {'재료': ['달걀(삶은거)4개', '참치캔1개', '상추(or양상추)', '게맛...
# ...                                                   ...
# 166506  {'재료': ['계란6개', '간장1수저', '설탕1수저', '미림1수저', '물1...
# 166507  {'재료': ['오이1개', '소금1/2T'], '소스': ['물1종이컵', '설탕...
# 166508  {'재료': ['오징어실채110g'], '양념': ['간장2큰술', '참기름1.5큰...
# 166509  {'재료': ['청포묵1팩', '대파김치1/2컵', '김가루'], '양념': ['갈...
# 166510  {'재료': ['참치캔1캔', '다진마늘1/2Ts', '고추장2Ts', '설탕1/2...
#
# [157263 rows x 2 columns]

# %%
func_pre[func_pre['recipe_title'].isnull()]
# Out:
#        recipe_title                                 recipe_ingredients
# 46742          None  {'재료': ['솎음열무2단', '대파2줄', '적양파1/2개'], '양념': ['...
# 100628         None   {'재료': ['계란3개', '떡20g', '양파1개', '햄1통', '케찹적당량']}
# 133582         None               {'재료': ['말차가루', '딸기', '버터', '제노와즈']}
# 147254         None  {'재료': ['코팅다크초콜릿130g', '코팅화이트초콜릿130g', '마시멜로우'...

# %%
func_pre[func_pre['recipe_ingredients'].isnull()]
# Out:
# Empty DataFrame
# Columns: [recipe_title, recipe_ingredients, ingredient1, quantity1, unit1, ingredient2, quantity2, unit2, ingredient3, quantity3, unit3, ingredient4, quantity4, unit4, ingredient5, quantity5, unit5, ingredient6, quantity6, unit6, ingredient7, quantity7, unit7, ingredient8, quantity8, unit8, ingredient9, quantity9, unit9, ingredient10, quantity10, unit10, ingredient11, quantity11, unit11, ingredient12, quantity12, unit12, ingredient13, quantity13, unit13, ingredient14, quantity14, unit14, ingredient15, quantity15, unit15, ingredient16, quantity16, unit16, ingredient17, quantity17, unit17, ingredient18, quantity18, unit18, ingredient19, quantity19, unit19, ingredient20, quantity20, unit20, ingredient21, quantity21, unit21, ingredient22, quantity22, unit22, ingredient23, quantity23, unit23, ingredient24, quantity24, unit24, ingredient25, quantity25, unit25, ingredient26, quantity26, unit26, ingredient27, quantity27, unit27, ingredient28, quantity28, unit28, ingredient29, quantity29, unit29, ingredient30, quantity30, unit30, ingredient31, quantity31, unit31, ingredient32, quantity32, unit32, ingredient33, quantity33, ...]
# Index: []
#
# [0 rows x 224 columns]

# %%
def combined_filter(data):
    def clean_ingredients(ingredient): # 이상한 문자열 저장방식 지움
        return ingredient.replace('\\ufeff', '').replace('\\u200b', '')

    data['recipe_ingredients'] = clean_ingredients(data['recipe_ingredients'])
    
    def not_empty_ingredients(row):
        return data['recipe_ingredients'].strip() != '{}' # 결측치 제거

    return not_empty_ingredients(data)

recipe_ingre_pd_pre = recipe_ingre_pd[recipe_ingre_pd.apply(combined_filter, axis=1)]
recipe_ingre_pd_pre
# Out:
#                          recipe_title  \
# 0       비빔밥재료 애호박나물 애호박볶음 아삭거리게 볶는 방법
# 1               [마늘종볶음]단짠단짠 자꾸만 손이가요~
# 2                       백종원의 부추 달걀 볶음
# 3           간단하게 맛난 반찬 만들기 '베이컨 버섯볶음'
# 4                     고소하고 향긋한 깻잎들깨볶음
# ...                               ...
# 168819                 쌀뜨물 알뜰하게 사용는 법
# 168820                일반 현미로 발아현미 만들기
# 168821                        건포도 발효종
# 168822           간단, 저렴한 술안주 겸 반찬 3가지
# 168824      9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients
# 0       {'재료': ['애호박1개', '다진마늘0.5큰술', '소금0.5큰술', '참기름1...
# 1       {'재료': ['건새우50g', '물1/4컵', '마늘종300g', '소금1/3큰술...
# 2       {'재료': ['부추1줌', '달걀4개', '식용유2큰술', '밥2공기'], '양념...
# 3       {'재료': ['베이컨5~6줄', '양파1/2개', '미니새송이버섯7개', '다진마...
# 4       {'재료': ['깻잎', '대파', '다진마늘1T', '국간장1T', '참기름1T'...
# ...                                                   ...
# 168819                                    {'재료': ['쌀뜨물']}
# 168820                                   {'재료': ['일반현미']}
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...
#
# [160711 rows x 2 columns]

# %%
for i in range(1, 25):
    func_pre.loc[:, f'ingredient{i}'] = None
    func_pre.loc[:, f'quantity{i}'] = None
    func_pre.loc[:, f'unit{i}'] = None

# %%
from tqdm import tqdm
import ast
import re
import json

non_matching_items = {}

for idx, row in tqdm(func_pre.iterrows(), total = func_pre.shape[0]):
    ingredient_count = 1
    if idx < 160712:
        ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) # SyntaxError: unterminated string literal (detected at line 1)
        for items in ingredients_dict.values():
            for item in items :
                match = re.match(r'([가-힣a-zA-Z]+(\([가-힣a-zA-Z]+\))?|\d+[가-힣a-zA-Z]*|\([가-힣a-zA-Z]+\)[가-힣a-zA-Z]+)([\d.+/~-]*)([가-힣a-zA-Z]+|약간|조금)?', item)
                if match:
                    ingredient, _, quantity, unit = match.groups()

                    func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
                    func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
                    func_pre.loc[idx, f'unit{ingredient_count}'] = unit

                    ingredient_count += 1
                else:
                    non_matching_items[idx] = item

for idx, item in non_matching_items.items():
    print(f'Row {idx}: {item}')
#    recipe_ingre_pd_pre.drop([idx], axis=0, inplace=True)
# Out:
#   0%|          | 599/157263 [00:05<12:29, 208.95it/s] C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
#   5%|▍         | 7448/157263 [00:32<08:34, 291.39it/s]C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\3378606877.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   func_pre.loc[idx, f'unit{ingredient_count}'] = unit
#  49%|████▉     | 77201/157263 [04:48<04:58, 267.88it/s]
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3548 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[209], line 11
#     ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) # SyntaxError: unterminated string literal (detected at line 1)
#
#   File ~\AppData\Local\Programs\Python\Python312\Lib\ast.py:66 in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File ~\AppData\Local\Programs\Python\Python312\Lib\ast.py:52 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     소시지)매콤 꼬치,4인분,60분 이내,아무나,"{'재료': ['사각어묵8장', '떡볶이떡1봉', '비엔나소시지1봉'], '양념': ['고추장2큰술', '고추가루1큰술', '자일리톨1큰술반', '다진마늘1/2큰술', '청량고추2개', '소금1/2큰술', '다시물1L', '대파1뿌리']}","['#1 재료늘 준비하고 떡과 소시를 말수 있게 어묵을잘라주세요', '#2 떡볶이떡은 말랑하게 삶아서 찬물에 행궈 주세요', '#3 어묵에 떡볶이 떡을 말아주세요', '#4 끓으면 빠지지 않게말린 어묵이 안쪽으로 꽂이게 꽂아주세요', '#5 소시도 어묵에 말아서 꽂아주시구요', '#6 소스재료를 넣고 다싯물에 풀어주세요', '#7 준비한 꼬치를 넣고 대파를 넣고 끓여주세요', '#8 센불에서 끓이다가 중간 불에서 양념이 베이게 끓여주세요']","['매운어턱오소꼬치', '매운어묵꼬치']",2,5283,국/탕,끓이기,일상
#        ^
# SyntaxError: unmatched ')'

# %%
from tqdm import tqdm
import ast
import re
import json

non_matching_items = {}

for idx, row in tqdm(recipe_ingre_pd_pre.iterrows(), total = recipe_ingre_pd_pre.shape[0]):
    ingredient_count = 1
    if idx < 160712:
        ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) # SyntaxError: unterminated string literal (detected at line 1)
        for items in ingredients_dict.values():
            for item in items :
                match = re.match(r'([가-힣a-zA-Z]+(\([가-힣a-zA-Z]+\))?|\d+[가-힣a-zA-Z]*|\([가-힣a-zA-Z]+\)[가-힣a-zA-Z]+)([\d.+/~-]*)([가-힣a-zA-Z]+|약간|조금)?', item)
                if match:
                    ingredient, _, quantity, unit = match.groups()

                    recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
                    recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
                    recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit

                    ingredient_count += 1
                else:
                    non_matching_items[idx] = item

for idx, item in non_matching_items.items():
    print(f'Row {idx}: {item}')
#    recipe_ingre_pd_pre.drop([idx], axis=0, inplace=True)
# Out:
#   1%|          | 1764/160253 [07:01<10:31:11,  4.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[188], line 18
#      15 if match:
#      16     ingredient, _, quantity, unit = match.groups()
# ---> 18     recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
#      19     recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
#      20     recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1893, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1890 # align and set the values
#    1891 if take_split_path:
#    1892     # We have to operate column-wise
# -> 1893     self._setitem_with_indexer_split_path(indexer, value, name)
#    1894 else:
#    1895     self._setitem_single_block(indexer, value, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1986, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1983 else:
#    1984     # scalar value
#    1985     for loc in ilocs:
# -> 1986         self._setitem_single_column(loc, value, pi)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:2097, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2092 else:
#    2093     # set value into the column (first attempting to operate inplace, then
#    2094     #  falling back to casting if necessary)
#    2095     self.obj._mgr.column_setitem(loc, plane_indexer, value)
# -> 2097 self.obj._clear_item_cache()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4400, in DataFrame._clear_item_cache(self)
#    4399 def _clear_item_cache(self) -> None:
# -> 4400     self._item_cache.clear()
#
# KeyboardInterrupt:

# %%
recipe_ingre_pd_pre
# Out:
#                          recipe_title  \
# 0       비빔밥재료 애호박나물 애호박볶음 아삭거리게 볶는 방법
# 1               [마늘종볶음]단짠단짠 자꾸만 손이가요~
# 2                       백종원의 부추 달걀 볶음
# 3           간단하게 맛난 반찬 만들기 '베이컨 버섯볶음'
# 4                     고소하고 향긋한 깻잎들깨볶음
# ...                               ...
# 168819                 쌀뜨물 알뜰하게 사용는 법
# 168820                일반 현미로 발아현미 만들기
# 168821                        건포도 발효종
# 168822           간단, 저렴한 술안주 겸 반찬 3가지
# 168824      9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients ingredient1  \
# 0       {'재료': ['애호박1개', '다진마늘0.5큰술', '소금0.5큰술', '참기름1...         애호박
# 1       {'재료': ['건새우50g', '물1/4컵', '마늘종300g', '소금1/3큰술...         건새우
# 2       {'재료': ['부추1줌', '달걀4개', '식용유2큰술', '밥2공기'], '양념...          부추
# 3       {'재료': ['베이컨5~6줄', '양파1/2개', '미니새송이버섯7개', '다진마...         베이컨
# 4       {'재료': ['깻잎', '대파', '다진마늘1T', '국간장1T', '참기름1T'...          깻잎
# ...                                                   ...         ...
# 168819                                    {'재료': ['쌀뜨물']}        None
# 168820                                   {'재료': ['일반현미']}        None
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}        None
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...        None
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...        None
#
#        quantity1 unit1 ingredient2 quantity2 unit2 ingredient3 quantity3  ...  \
# 0              1     개        다진마늘       0.5    큰술          소금       0.5  ...
# 1             50     g           물       1/4     컵         마늘종       300  ...
# 2              1     줌          달걀         4     개         식용유         2  ...
# 3            5~6     줄          양파       1/2     개     미니새송이버섯         7  ...
# 4                 None          대파            None        다진마늘         1  ...
# ...          ...   ...         ...       ...   ...         ...       ...  ...
# 168819      None  None        None      None  None        None      None  ...
# 168820      None  None        None      None  None        None      None  ...
# 168821      None  None        None      None  None        None      None  ...
# 168822      None  None        None      None  None        None      None  ...
# 168824      None  None        None      None  None        None      None  ...
#
#        unit79 ingredient80 quantity80 unit80 ingredient81 quantity81 unit81  \
# 0           n          nan        nan      n           na          n      n
# 1           n          nan        nan      n           na          n      n
# 2           n          nan        nan      n           na          n      n
# 3           n          nan        nan      n           na          n      n
# 4           n          nan        nan      n           na          n      n
# ...       ...          ...        ...    ...          ...        ...    ...
# 168819      n          nan        nan      n           na          n      n
# 168820      n          nan        nan      n           na          n      n
# 168821      n          nan        nan      n           na          n      n
# 168822      n          nan        nan      n           na          n      n
# 168824      n          nan        nan      n           na          n      n
#
#        ingredient82 quantity82 unit82
# 0               nan          n      n
# 1               nan          n      n
# 2               nan          n      n
# 3               nan          n      n
# 4               nan          n      n
# ...             ...        ...    ...
# 168819          nan          n      n
# 168820          nan          n      n
# 168821          nan          n      n
# 168822          nan          n      n
# 168824          nan          n      n
#
# [160711 rows x 248 columns]

# %%
recipe_ingre_pd_pre
# Out:
#                          recipe_title  \
# 0       비빔밥재료 애호박나물 애호박볶음 아삭거리게 볶는 방법
# 1               [마늘종볶음]단짠단짠 자꾸만 손이가요~
# 2                       백종원의 부추 달걀 볶음
# 3           간단하게 맛난 반찬 만들기 '베이컨 버섯볶음'
# 4                     고소하고 향긋한 깻잎들깨볶음
# ...                               ...
# 168819                 쌀뜨물 알뜰하게 사용는 법
# 168820                일반 현미로 발아현미 만들기
# 168821                        건포도 발효종
# 168822           간단, 저렴한 술안주 겸 반찬 3가지
# 168824      9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients ingredient1  \
# 0       {'재료': ['애호박1개', '다진마늘0.5큰술', '소금0.5큰술', '참기름1...         애호박
# 1       {'재료': ['건새우50g', '물1/4컵', '마늘종300g', '소금1/3큰술...         건새우
# 2       {'재료': ['부추1줌', '달걀4개', '식용유2큰술', '밥2공기'], '양념...          부추
# 3       {'재료': ['베이컨5~6줄', '양파1/2개', '미니새송이버섯7개', '다진마...         베이컨
# 4       {'재료': ['깻잎', '대파', '다진마늘1T', '국간장1T', '참기름1T'...          깻잎
# ...                                                   ...         ...
# 168819                                    {'재료': ['쌀뜨물']}        None
# 168820                                   {'재료': ['일반현미']}        None
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}        None
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...        None
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...        None
#
#        quantity1 unit1 ingredient2 quantity2 unit2 ingredient3 quantity3  ...  \
# 0              1     개        다진마늘       0.5    큰술          소금       0.5  ...
# 1             50     g           물       1/4     컵         마늘종       300  ...
# 2              1     줌          달걀         4     개         식용유         2  ...
# 3            5~6     줄          양파       1/2     개     미니새송이버섯         7  ...
# 4                 None          대파            None        다진마늘         1  ...
# ...          ...   ...         ...       ...   ...         ...       ...  ...
# 168819      None  None        None      None  None        None      None  ...
# 168820      None  None        None      None  None        None      None  ...
# 168821      None  None        None      None  None        None      None  ...
# 168822      None  None        None      None  None        None      None  ...
# 168824      None  None        None      None  None        None      None  ...
#
#        unit79 ingredient80 quantity80 unit80 ingredient81 quantity81 unit81  \
# 0           n          nan        nan      n           na          n      n
# 1           n          nan        nan      n           na          n      n
# 2           n          nan        nan      n           na          n      n
# 3           n          nan        nan      n           na          n      n
# 4           n          nan        nan      n           na          n      n
# ...       ...          ...        ...    ...          ...        ...    ...
# 168819      n          nan        nan      n           na          n      n
# 168820      n          nan        nan      n           na          n      n
# 168821      n          nan        nan      n           na          n      n
# 168822      n          nan        nan      n           na          n      n
# 168824      n          nan        nan      n           na          n      n
#
#        ingredient82 quantity82 unit82
# 0               nan          n      n
# 1               nan          n      n
# 2               nan          n      n
# 3               nan          n      n
# 4               nan          n      n
# ...             ...        ...    ...
# 168819          nan          n      n
# 168820          nan          n      n
# 168821          nan          n      n
# 168822          nan          n      n
# 168824          nan          n      n
#
# [160253 rows x 248 columns]

# %%
for_del = recipe_ingre_pd_pre[recipe_ingre_pd_pre[('ingredient1')].isnull()].index
# Out:
#                             recipe_title  \
# 55375                        6寸巧克力慕斯(蛋糕)
# 92924               포슬포슬, 에어프라이어로 만든 찐감자
# 92928                 에어프라이어로 뚝딱! 고구마 간식
# 160712  황태 콩나물 해장국, 황태해장국 사골국처럼 뽀얗게 내는법.
# 160713  황태감자국, 뽀얀 국물이 매력적인 북엇국, 속 편한 아침국
# ...                                  ...
# 168819                    쌀뜨물 알뜰하게 사용는 법
# 168820                   일반 현미로 발아현미 만들기
# 168821                           건포도 발효종
# 168822              간단, 저렴한 술안주 겸 반찬 3가지
# 168824         9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients ingredient1  \
# 55375    {'재료': ['德芙黑巧克力+牛奶丝滑共2条56g', '吉利丁粉12', '饼干碎1t']}        None
# 92924                                {'재료': ['▶재료:감자3개']}        None
# 92928                               {'재료': ['▶재료:고구마6개']}        None
# 160712  {'재료': ['물2+2종이컵', '조각다시마2장', '황태채1줌', '콩나물1줌'...        None
# 160713  {'재료': ['황태포210g', '감자2개', '양파1개', '물1.4L', '두...        None
# ...                                                   ...         ...
# 168819                                    {'재료': ['쌀뜨물']}        None
# 168820                                   {'재료': ['일반현미']}        None
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}        None
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...        None
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...        None
#
#        quantity1 unit1 ingredient2 quantity2 unit2 ingredient3 quantity3  ...  \
# 55375       None  None        None      None  None        None      None  ...
# 92924       None  None        None      None  None        None      None  ...
# 92928       None  None        None      None  None        None      None  ...
# 160712      None  None        None      None  None        None      None  ...
# 160713      None  None        None      None  None        None      None  ...
# ...          ...   ...         ...       ...   ...         ...       ...  ...
# 168819      None  None        None      None  None        None      None  ...
# 168820      None  None        None      None  None        None      None  ...
# 168821      None  None        None      None  None        None      None  ...
# 168822      None  None        None      None  None        None      None  ...
# 168824      None  None        None      None  None        None      None  ...
#
#        unit79 ingredient80 quantity80 unit80 ingredient81 quantity81 unit81  \
# 55375       n          nan        nan      n           na          n      n
# 92924       n          nan        nan      n           na          n      n
# 92928       n          nan        nan      n           na          n      n
# 160712      n          nan        nan      n           na          n      n
# 160713      n          nan        nan      n           na          n      n
# ...       ...          ...        ...    ...          ...        ...    ...
# 168819      n          nan        nan      n           na          n      n
# 168820      n          nan        nan      n           na          n      n
# 168821      n          nan        nan      n           na          n      n
# 168822      n          nan        nan      n           na          n      n
# 168824      n          nan        nan      n           na          n      n
#
#        ingredient82 quantity82 unit82
# 55375           nan          n      n
# 92924           nan          n      n
# 92928           nan          n      n
# 160712          nan          n      n
# 160713          nan          n      n
# ...             ...        ...    ...
# 168819          nan          n      n
# 168820          nan          n      n
# 168821          nan          n      n
# 168822          nan          n      n
# 168824          nan          n      n
#
# [7041 rows x 248 columns]

# %%
recipe_ingre_pd_pre.drop([{for_del}], axis=0, inplace=True)

# %%
recipe_ingre_pd_pre[recipe_ingre_pd_pre[('unit1')].isnull()]
# Out:
#                      recipe_title  \
# 4                 고소하고 향긋한 깻잎들깨볶음
# 28             시금치요리 시금치베이컨볶음 엄지척
# 74          한 입에 쏙! 방울 양배추 소세지 볶음
# 81             아이 반찬/초 간단 어묵 채 볶음
# 82       소세지야채볶음 황금레시피, 쏘야 맛있게만들기
# ...                           ...
# 168819             쌀뜨물 알뜰하게 사용는 법
# 168820            일반 현미로 발아현미 만들기
# 168821                    건포도 발효종
# 168822       간단, 저렴한 술안주 겸 반찬 3가지
# 168824  9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients ingredient1  \
# 4       {'재료': ['깻잎', '대파', '다진마늘1T', '국간장1T', '참기름1T'...          깻잎
# 28                   {'재료': ['시금치', '베이컨', '다진마늘', '통깨']}         시금치
# 74      {'재료': ['방울양배추', '브로콜리', '소세지', '마늘', '소금', '후...       방울양배추
# 81      {'재료': ['사가어묵(2장)170g'], '양념': ['굴소스1/2큰술', '올...        사가어묵
# 82      {'재료': ['비엔나소세지', '양파1/3', '파프리카1/3', '당근1/3',...      비엔나소세지
# ...                                                   ...         ...
# 168819                                    {'재료': ['쌀뜨물']}        None
# 168820                                   {'재료': ['일반현미']}        None
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}        None
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...        None
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...        None
#
#        quantity1 unit1 ingredient2 quantity2 unit2 ingredient3 quantity3  ...  \
# 4                 None          대파            None        다진마늘         1  ...
# 28                None         베이컨            None        다진마늘            ...
# 74                None        브로콜리            None         소세지            ...
# 81                None         굴소스       1/2    큰술        올리고당         1  ...
# 82                None          양파       1/3  None        파프리카       1/3  ...
# ...          ...   ...         ...       ...   ...         ...       ...  ...
# 168819      None  None        None      None  None        None      None  ...
# 168820      None  None        None      None  None        None      None  ...
# 168821      None  None        None      None  None        None      None  ...
# 168822      None  None        None      None  None        None      None  ...
# 168824      None  None        None      None  None        None      None  ...
#
#        unit79 ingredient80 quantity80 unit80 ingredient81 quantity81 unit81  \
# 4           n          nan        nan      n           na          n      n
# 28          n          nan        nan      n           na          n      n
# 74          n          nan        nan      n           na          n      n
# 81          n          nan        nan      n           na          n      n
# 82          n          nan        nan      n           na          n      n
# ...       ...          ...        ...    ...          ...        ...    ...
# 168819      n          nan        nan      n           na          n      n
# 168820      n          nan        nan      n           na          n      n
# 168821      n          nan        nan      n           na          n      n
# 168822      n          nan        nan      n           na          n      n
# 168824      n          nan        nan      n           na          n      n
#
#        ingredient82 quantity82 unit82
# 4               nan          n      n
# 28              nan          n      n
# 74              nan          n      n
# 81              nan          n      n
# 82              nan          n      n
# ...             ...        ...    ...
# 168819          nan          n      n
# 168820          nan          n      n
# 168821          nan          n      n
# 168822          nan          n      n
# 168824          nan          n      n
#
# [25485 rows x 248 columns]

# %% [markdown]
# ### 여기서부터 이전 코드

# %%
from tqdm import tqdm
import ast
import re
import json

non_matching_items = {}

for idx, row in tqdm(recipe_ingre_pd_pre.iterrows(), total = recipe_ingre_pd_pre.shape[0]):
    ingredient_count = 1
    if idx < 160712:
        ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) # SyntaxError: unterminated string literal (detected at line 1)
        for items in ingredients_dict.values():
            for item in items :
                match = re.match(r'([가-힣]+(\([가-힣]+\))?)([\d.+/~-]*)([가-힣a-zA-Z]+|약간|조금)?', item)
                if match:
                    ingredient, _, quantity, unit = match.groups()

                    recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
                    recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
                    recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit

                    ingredient_count += 1
                else:
                    non_matching_items[idx] = item

for idx, item in non_matching_items.items():
    print(f'Row {idx}: {item}')
# Out:
#   1%|          | 1798/160711 [00:07<08:17, 319.73it/s]C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
#   1%|▏         | 2244/160711 [00:09<12:34, 209.91it/s]C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'quantity{ingredient_count}'] = quantity
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'unit{ingredient_count}'] = unit
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# C:\Users\glori\AppData\Local\Temp\ipykernel_14116\4011411790.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe_ingre_pd_pre.loc[idx, f'ingredient{ingredient_count}'] = ingredient
# ...
# Row 123863: (시판)유부초밥1팩
# Row 123879:
# Row 124034: tlrch3T
# Row 124052:
# Row 124084: 2배식초3T
# Row 124251: (건)쌀국수면40g
# Row 124363: MSG1+1/2숟가락
# Row 124409: MSG1숟가락
# Row 124530:
# Row 124531:
# Row 124565: HACCP인증제품후추조금
# Row 124586:
# Row 124604:
# Row 124665:
# Row 124765: haccp인증맛살30g
# Row 124923: 100%엑스트라버진올리브오일4큰술
# Row 124936:
# Row 124990: 1/2하프마요네즈3큰술
# Row 125050:
# Row 125125: monkfruitsweetener/erythritol1/4컵
# Row 125128: (또는일반단호박)2/3개
# Row 125185:
# Row 125265: B.P1/2t
# Row 125282: salt1꼬집
# Row 125307: 90%다크초콜릿100g
# Row 125381: MCT코코넛오일1숟가락
# Row 125509: CJH.O.P.E다이어트쿠키1봉
# Row 125669: X
# Row 125745: Craisins1줌
# Row 125751: CJ제일제당프레시안집두부제품
# Row 126014:
# Row 126019: 1/2국자
# Row 126164: *소고기양념:
# Row 126208:
# Row 126393: XO소스소고기볶음밥2컵
# Row 126475: MSG1.5숟가락
# Row 126497:
# Row 126498:
# Row 126628: 3색모둠느타리버섯80g
# Row 126703:
# Row 126829:
# Row 126845:
# Row 126895:
# Row 126935:
# Row 127036:
# Row 127047:
# Row 127150: 3층치즈
# Row 127151: 3등분한김1장
# Row 127222:
# Row 127289: *볶은당근(중간크기1개분량)
# Row 127320:
# Row 127362: 1회용장갑1장
# Row 127580: HACCP소금1/2작은술
# Row 127651: CJ더비비고우엉소고기덮밥용소스1봉지
# Row 127652: cj더비비고버섯불고기덮밥소스180g
# Row 127754: .오뎅
# Row 127885: ♡밥양념
# Row 127913: 3층치즈
# Row 127916: 3층치즈
# Row 127926: 3층치즈2장
# Row 127960: (오뚜기)맛있는밥1개
# Row 128102: The더건강한브런치슬라이스오리지널4장
# Row 128170:
# Row 128183: CJ알래스카연어오리지널300g
# Row 128214: The더건강한빅크랩5개
# Row 128215: CJ더건강한브런치슬라이스햄250g
# Row 128236: (다시마와청주넣은)고슬한밥
# Row 128593:
# Row 128603:
# Row 128612:
# Row 128726: 6인치또띠아(1인2장)4장
# Row 128732: 3층치즈적당량
# Row 128737:
# Row 128787: (통조림)닭가슴살1캔
# Row 128851: 3층치즈2장
# Row 128858:
# Row 128902: (오뚜기)스위트칠리소스1큰술
# Row 128912: 3층치즈1장
# Row 128915: (시럽용)올리고당
# Row 128982: (밥양념)깨소금0.5T
# Row 129043:
# Row 129158:
# Row 129260:
# Row 129275: 10인치또띠아5장
# Row 129285:
# Row 129403:
# Row 129497:
# Row 129498:
# Row 129527:
# Row 129571: (판)어묵4장
# Row 129596: 3층치즈1장
# Row 129655:
# Row 129716:
# Row 129748: MSG2스푼
# Row 129841: MSG1/2스푼
# Row 130083: (껍질손질한)도라지1줌
# Row 130127:
# Row 130260:
# Row 130339: XO소스4큰술
# Row 130386:
# Row 130588:
# Row 130642:
# Row 130684: la갈비1kg
# Row 130685:
# Row 130745:
# Row 130776: MSG
# Row 130794: 2배식초1큰술
# Row 130904:
# Row 130992: LA갈비12대
# Row 131022:
# Row 131047:
# Row 131049:
# Row 131073:
# Row 131204:
# Row 131267:
# Row 131274:
# Row 131281: LA갈비1키로
# Row 131304: LA갈비2.5키로
# Row 131322: la갈비1kg
# Row 131340: LA갈비13장
# Row 131376: LA거갈비1팩85gX20쪽
# Row 131383: LA갈비5키로
# Row 131450: LA돼지갈비1kg
# Row 131454: MSG1숟가락
# Row 131463: LA갈비2키로
# Row 131466: (붓칠)녹인버터1T
# Row 131480: LA갈비3kg
# Row 131503:
# Row 131522:
# Row 131523: LA갈비1팩
# Row 131524:
# Row 131581:
# Row 131586:
# Row 131590:
# Row 131598:
# Row 131599:
# Row 131693:
# Row 131804:
# Row 131850: 9호닭1마리
# Row 131931:
# Row 131979: .월계수5장
# Row 131983: (건)능이버섯1줌
# Row 132046: 10호닭1마리
# Row 132047: 6호닭1마리
# Row 132050: 6호생닭4마리
# Row 132051: 6년근수삼1뿌리
# Row 132211: 6호닭8마리
# Row 132245: 3)간맞추기:소금1T
# Row 132278: PN풍년압력솥
# Row 132386: 9호닭
# Row 132408: 4등분한양파1개
# Row 132509: 6호닭2마리
# Row 132561:
# Row 132573: MSG1+1/2숟가락
# Row 132629: (육수용)맛간장2스푼
# Row 132815:
# Row 132819:
# Row 132880: MSG1+1/2숟가락
# Row 132922: 3색미니파프리카1개씩
# Row 132927: :두유4팩
# Row 132938: MSG1스푼
# Row 133170: MSG1.5스푼
# Row 133197: (야채와칼국수도준비합니다)
# Row 133218: or달걀지단
# Row 133238:
# Row 133239:
# Row 133254: MSG1숟가락
# Row 133282:
# Row 133304: MSG1숟가락
# Row 133305:
# Row 133396:
# Row 133406: MSG1.5숟가락
# Row 133449: XO소스2큰술
# Row 133475: MSG1스푼
# Row 133496: MSG3숟가락
# Row 133508:
# Row 133526:
# Row 133530:
# Row 133601: 2시간이상불린쌀2컵
# Row 133904: 3색모둠느타리버섯200g
# Row 134011: ※밥숟가락기준
# Row 134127: (고추)
# Row 134165: MSG2숟가락
# Row 134332: (불린)표고버섯
# Row 134395:
# Row 134428:
# Row 134496:
# Row 134497:
# Row 134506:
# Row 134533:
# Row 134578: (허브)소금1작은술
# Row 134616:
# Row 134646: 2배식초1스푼
# Row 134662:
# Row 134728:
# Row 134782: 19잡곡410g
# Row 134788: 17잡곡500g
# Row 134792: 100%원물산들애멸치2g
# Row 134817:
# Row 134857:
# Row 134951:
# Row 134955:
# Row 135033:
# Row 135041: MSG1/2스푼
# Row 135078:
# Row 135157: 3층치즈1장
# Row 135164: 3층치즈크림치즈3장
# Row 135165: 3층치즈3장
# Row 135224:
# Row 135330: (파인애플/베이컨)
# Row 135389: (껍질제거)닭1.8kg
# Row 135419:
# Row 135421: A1소스100ml
# Row 135502: 2배식초50ml
# Row 135537: (다진)마늘1개
# Row 135705: MSG1숟가락
# Row 135708: (팬에바를)식용유약간
# Row 135728:
# Row 135737: B.P3g
# Row 135755: 3층치즈적당량
# Row 135764: (호밀)빵4쪽
# Row 135781: (흑)설탕90그램
# Row 135791:
# Row 135796: (아몬드)우유1컵
# Row 136020: 500~600ml병3개
# Row 136135: 100%사과주스1~2컵
# Row 136210: 2색파프리카2개
# Row 136350: 3층치즈2장
# Row 136608: MSG1.5스푼
# Row 136660:
# Row 136692: (부추)째끔
# Row 136775:
# Row 136800: MSG1숟가락
# Row 136868:
# Row 136947:
# Row 137007:
# Row 137083: 3층치즈1장
# Row 137085: 3층치즈3장
# Row 137290: 3색느타리버섯1/2팩
# Row 137341: MSG3숟가락
# Row 137347: B밀가루6큰술
# Row 137363:
# Row 137392:
# Row 137441:
# Row 137508: LA갈비4대
# Row 137539:
# Row 137556:
# Row 137562: 2배식초2큰술
# Row 137563: 2배식초1큰술
# Row 137566:
# Row 137668: 1인분
# Row 137709: 24*17*2cm직사각형쟁반한개분
# Row 137737: 8인치또띠아2장
# Row 137755:
# Row 137780: m&m1봉지
# Row 137826:
# Row 137913: 15*15cm1호사각틀한개분
# Row 137959: MSG0.5숟가락
# Row 137968: []바나나2개
# Row 138023:
# Row 138027:
# Row 138060:
# Row 138204: THEDAN초당옥수수1개
# Row 138312:
# Row 138325:
# Row 138479: ※밥숟가락기준
# Row 138536: (바닐라에센스)2~3방울
# Row 138620: 3층치즈크림치즈맛
# Row 138646: 3층치즈적당량
# Row 138680: B.P4g
# Row 138698:
# Row 138920: 3층치즈적당량
# Row 138922: 3층치즈
# Row 138923: 3층치즈적당량
# Row 138979: (선택사항)시나몬파우더1t스푼
# Row 139123: CJ제일제당알래스카자연산통살연어올리브유연어캔
# Row 139317:
# Row 139472:
# Row 139758: 15개기준)달걀노른자1개
# Row 139796: 15cm높은틀1개분
# Row 139800:
# Row 139819:
# Row 139834:
# Row 139867: 15cm높은원형틀1개분
# Row 139982: 70%초콜릿170g
# Row 140082: 3색모둠느타리버섯80g
# Row 140341: Mixedspice15g
# Row 140369: 100%피넛버터240g
# Row 140387: 18cm케이크틀
# Row 140398: 15cm사각틀또는미니사각8구실리콘틀
# Row 140525: 18cm원형틀1개분
# Row 140561: ★굽기190도15분->160도10분
# Row 140576: b설탕10그램
# Row 140582: B.P1g
# Row 140589: 15cm높은틀1개분
# Row 140614: 11개정도
# Row 140618: 1호사이즈제누와즈1개
# Row 140658: 15cm1호사각틀한개분
# Row 140669: m&m's미니1통
# Row 140674: 3층치즈적당량
# Row 140699: 3층치즈카야맛1장
# Row 140705: 3층치즈1장
# Row 140708: 3층치즈4장
# Row 140787: (필링)버터100g
# Row 140807: 18cm1개분
# Row 140809: 18cm1개분
# Row 140834: B.p2g
# Row 140836: B.p2g
# Row 140860: :배즙1컵반
# Row 140927: THEDAN초당옥수수2개
# Row 141041:
# Row 141057: B생크림50g
# Row 141087:
# Row 141188:
# Row 141221:
# Row 141233: 220g
# Row 141258:
# Row 141285:
# Row 141308: g버터50g
# Row 141335: 8인치또띠아6장
# Row 141533:
# Row 141613:
# Row 141869: 1호사이즈초코케이크시트3장
# Row 141949: 14*14*6.5cm사각형그릇한개분
# Row 141954: K-MILK우유300ml
# Row 142011: O레오쿠키7개
# Row 142050: 14*14*6.5cm사각형한개분
# Row 142054: 14*14*6.5cm사각형그릇한개분
# Row 142056:
# Row 142063: 3층치즈2장
# Row 142066: 3층치즈
# Row 142067: 3층치즈
# Row 142068: 3층치즈3장
# Row 142072: 3개정도
# Row 142076: 3층치즈2장
# Row 142182: (계란흰자+설탕)
# Row 142215:
# Row 142298:
# Row 142332:
# Row 142337: (우유+연유)얼음
# Row 142396: ABC초콜릿7-8개
# Row 142432:
# Row 142464:
# Row 142488: 18cm제누아즈슬라이스2장
# Row 142567: 2*7cm초콜릿바17개
# Row 142571:
# Row 142590:
# Row 142687: (산)딸기300g
# Row 142707:
# Row 142845: 500g
# Row 142859:
# Row 142864:
# Row 142905:
# Row 142986:
# Row 143088:
# Row 143089:
# Row 143107: 3배식초2숟가락
# Row 143140:
# Row 143203:
# Row 143211:
# Row 143213:
# Row 143237:
# Row 143301: 60도물1/2컵
# Row 143313: (냉동)물만두12개
# Row 143325:
# Row 143421: MSG1숟갈
# Row 143469:
# Row 143512:
# Row 143790:
# Row 143870: (꼬막떡볶이)가래떡300g
# Row 143944:
# Row 143960:
# Row 143964:
# Row 143967:
# Row 144150:
# Row 144190: MSG2스푼
# Row 144259:
# Row 144358: msg1/2티스푼
# Row 144366:
# Row 144414: MSG1T
# Row 144536: ABCT주스1컵
# Row 144539:
# Row 144553: S&B카레3쪽
# Row 144572: 3층치즈적당량
# Row 144595: b물5컵(약1L정도)
# Row 144674: 3층치즈2장
# Row 144757:
# Row 144887:
# Row 144888:
# Row 145004:
# Row 145210: b.p2g
# Row 145212: 3층치즈2장
# Row 145275:
# Row 145277: 8.5cm원형주름컵2개분
# Row 145285: 3색파프리카1/4쪽씩
# Row 145349:
# Row 145469: 3층치즈3장
# Row 145482: ★말차가루(녹차가루)1/2큰술
# Row 145557:
# Row 145730: 3층치즈
# Row 145746: A1소스2스푼
# Row 146026: 250ml병4개분
# Row 146083:
# Row 146104: 1T는아빠숟가락1t는찻숟가락~
# Row 146107:
# Row 146139:
# Row 146141:
# Row 146167:
# Row 146174:
# Row 146249: 0칼로리머스타드소스2-3스푼
# Row 146341: 3층치즈
# Row 146342: 3층치즈2장
# Row 146343: 3층치즈적당량
# Row 146346: 3층치즈2장
# Row 146364:
# Row 146491: ※밥숟가락기준
# Row 146517: 3층치즈
# Row 146518: 3층치즈적당량
# Row 146538: 5개정도
# Row 146571:
# Row 146596:
# Row 146675: 3층치즈
# Row 146676: 3층치즈적당량
# Row 146677: 3층치즈2-3장
# Row 146678: 3층치즈5개
# Row 146679: 3층치즈2~3장
# Row 146765:
# Row 146800: 2배로식초1/3스푼
# Row 146858:
# Row 146872: 3층치즈2/3장
# Row 146904:
# Row 146953:
# Row 146954:
# Row 147061:
# Row 147148: BBQ소스
# Row 147160: 8인치또띠아2장
# Row 147176:
# Row 147181: 11cm스틱과자40~50개
# Row 147204: B생크림200g
# Row 147362: 3층치즈2장
# Row 147431:
# Row 147447: CJ참깨드레싱약간
# Row 147453: CJ알래스카연어화이트마요1개
# Row 147516:
# Row 147732: 12개분량
# Row 147842:
# Row 147856:
# Row 147882: (우유)식빵5장
# Row 147952: (코팅용)설탕충분히
# Row 147955:
# Row 147969:
# Row 147975: B.P1큰술
# Row 148045: 3층치즈
# Row 148047: 3층카야치즈2장
# Row 148080: (따뜻한)우유100~130g
# Row 148168:
# Row 148205: (토핑용)돈까스소스+머스타드소스
# Row 148257:
# Row 148260:
# Row 148267: b.p1t
# Row 148386: MSG2숟가락
# Row 148399:
# Row 148405:
# Row 148518: b.p3g
# Row 148532: (연유버터용)버터35g
# Row 148541: ABC초콜릿(밀크초콜릿)16개(1개당4g)
# Row 148576:
# Row 148720: (토핑용)아몬드슬라이스조금
# Row 148797: b.p2g
# Row 148885: +설탕40g
# Row 148895: (속재료=)황설탕
# Row 148931: bp2g
# Row 148945:
# Row 148987: 18*8.5*6cm혹은16*6*7c
# Row 149003: *아몬드가루가없으면밀가루만200g
# Row 149014: B.P1작은술
# Row 149070:
# Row 149078: 18cm제누아즈슬라이스1장
# Row 149081: 3호타르트팬1개
# Row 149103: 8인치또띠아1장
# Row 149104: 15cm원형팬1개
# Row 149121: 1/2빵팬1개분
# Row 149187:
# Row 149195: 8인치또띠아1개
# Row 149219: BP2g
# Row 149226: 3층카야치즈1장
# Row 149239: B.P2g
# Row 149251: b.p2t
# Row 149278: slicedalmonds적당히
# Row 149296: bs1/4t
# Row 149317: 18*8.5*6cm혹은16*6*7c
# Row 149324: 17cm정도크기케이크1개분
# Row 149332: (마들렌24개분량)박력분100g
# Row 149341: B.P1tsp
# Row 149351: B.P2g
# Row 149355: (강력)쌀가루200g
# Row 149366:
# Row 149378: BP1g
# Row 149394:
# Row 149444: 1/2빵팬1개분
# Row 149463:
# Row 149470: b.p4g
# Row 149492:
# Row 149498: bp1/3t
# Row 149503:
# Row 149519: (지름9cm원형5개분량)우리밀강력분150g
# Row 149522: 100%통밀가루500g
# Row 149527:
# Row 149536: 6인치또띠아1장
# Row 149541: (무염버터의경우)소금약간
# Row 149548:
# Row 149589: 8호또띠아4장
# Row 149613:
# Row 149635: 1호팬
# Row 149677:
# Row 149745: wholemilk(없을경우2%우유1cup+heavy1+1/4cup
# Row 149794: b.s2g
# Row 149814: B.P2g
# Row 149826: BP4g
# Row 149839:
# Row 149862: 11~12개분량
# Row 149876: +버터10g
# Row 149902: (통조림)옥수수3큰술
# Row 149976:
# Row 150016: B.P6g
# Row 150080: 40~43도의물210g
# Row 150116: B)코코아가루20g
# Row 150124: CJ고메베이커리크로와상6개
# Row 150131: B.P1g
# Row 150133: (실온에둔)우유120ml
# Row 150142:
# Row 150722: T55밀가루100g
# Row 150729: T55밀가루강력분105g
# Row 150868: 25cm길이18~19개정도
# Row 150988: B.P5g
# Row 151000: CJ고메크로와상냉동생지5개
# Row 151288: 6개분량
# Row 151300: 1/2풀먼식빵틀한개분
# Row 151317: 2가지색파프리카50g씩
# Row 151324: 3층치즈3장
# Row 151326: 3층치즈4장
# Row 151327: 3층치즈2장
# Row 151328: 3층치즈
# Row 151332: 3층치즈
# Row 151338: 3층치즈
# Row 151339: 3층치즈3장
# Row 151340: 3층치즈3장
# Row 151344: 3층치즈적당량
# Row 151359: 3층치즈2장
# Row 151362: 3층치즈3장
# Row 151421:
# Row 151435: 1/2풀먼식빵틀한개분
# Row 151442:
# Row 151444: Real스트링치즈1개
# Row 151456: (오뚜기)미향1큰술
# Row 151563: Real뿌려먹는자연치즈1개
# Row 151569: B.p1.5g
# Row 151570: B.p2g
# Row 151571: Bp5g
# Row 151586: selfrisingflour3컵
# Row 151588: B.P(베이킹파우더)1g
# Row 151614: B.p48g(3g)
# Row 151620: 28cm이상되는프라이팬
# Row 151621: B.P5g
# Row 151624: B.P14g
# Row 151647: 36cm*26cm롤케이크팬1개분
# Row 151666: 9개분
# Row 151686: 25cm)1장
# Row 151689: (강력분)밀가루국자(대)로4국자
# Row 151699: B.P14g
# Row 151708: self-rising밀가루(없을경우중력분으로대체가1+1/2컵
# Row 151715: B.p8g
# Row 151729: CdP크루아상생지
# Row 151731: B.p6g
# Row 151732: (B.p2g)
# Row 151733: B.p6g
# Row 151734: Cdp크루아상생지
# Row 151743: M&M초콜렛마음껏
# Row 151755: 16*7.5*6.5cm틀1개분
# Row 151881: 35*27*2cm팬1개분
# Row 151885: 8oz투명컵
# Row 151900:
# Row 151903: 18*8.5*6cm혹은16*6*7c
# Row 151912: 18*8.5*6cm혹은16*6*7c
# Row 151925: BP4g
# Row 151943: B.P.4g
# Row 151948: BP4g
# Row 151968: b.p1ts
# Row 152035: m&m초콜릿6개
# Row 152041: 2호바닐라케이크시트1개
# Row 152049: Bacon/CanadianBacon1줄
# Row 152053: 6인치또띠아2장
# Row 152055: B.P3g
# Row 152076: 5cm크기27개정도
# Row 152080: 16*6*7cm1개분
# Row 152084: 36*26*4cm롤케이크1개분
# Row 152097: (▲계량컵&계량스푼기준)
# Row 152117: 6인치퀘사디아2장
# Row 152119: 35*27*2cm롤케이크팬1개분
# Row 152166: B.P2g
# Row 152261: 25*7*6cm한개+머핀컵2개분
# Row 152269: 35*27*2cm롤케이크팬1개분
# Row 152299: 10~15cm원형사이즈2개분
# Row 152330: (아가베)시럽
# Row 152348: 5cm~6cm정도의두께로자른식빵2조각
# Row 152349: (흑)설탕60그램
# Row 152366: (마른)찹쌀가루2cups
# Row 152380: 15cm무스링1개분
# Row 152390: m&m초콜릿1~2봉지
# Row 152415: 1/2빵팬1개
# Row 152432: (마스코바도)설탕50그램
# Row 152445: 1/2빵팬1개분
# Row 152457: (실온에30분이상꺼내놓은)우유400ml
# Row 152473:
# Row 152481: 1/2빵팬1개((39*29*4.5cm)
# Row 152527:
# Row 152536:
# Row 152544: M&M초콜릿
# Row 152545: 1/2빵팬1개분
# Row 152547: B.P5g
# Row 152549: 10.9cm*6.5cm미니케이크틀두개
# Row 152552: Plain코코넛오일1큰술
# Row 152556: B.P3g
# Row 152557: 18cm원형2호틀한개+머핀틀한개분량
# Row 152562: B.P2g
# Row 152649: (손바닥반만한크기로30개나왔어요.)팥앙금1kg
# Row 152700: 0세~2세까지아기멸치50g
# Row 152830: A4용지1장
# Row 153001:
# Row 153003: m&m’s초콜릿150~200g
# Row 153028: 8cm타르트쉘5개
# Row 153041: (실온에둔)버터100g
# Row 153094: b.p2.5g
# Row 153095: m&m초콜릿적당량
# Row 153099: 11인치타르트팬1개
# Row 153114: M&M초콜릿약간
# Row 153266: 16개정도
# Row 153305: bs1/4t
# Row 153369: (따뜻)물1/4머그컵
# Row 153408: 8개분량
# Row 153417: (아이싱)흰자40g
# Row 153446: (선택사항)
# Row 153482: bp2g
# Row 153503: b.p4g
# Row 153507: b.p2g
# Row 153551: *커스터드크림:달걀노른자1개
# Row 153631: 11cm빼빼로쿠키15개
# Row 153741: M&M's초콜릿14개
# Row 153780: 12개분량
# Row 153903: 16개분량
# Row 153965: 5cm스쿱12개분량
# Row 154093: B.P0.5g
# Row 154097: 24개분량
# Row 154100: 12개분량
# Row 154138: M&M초콜릿
# Row 154146: 24개정도
# Row 154194: 20개정도
# Row 154202: 18cm쉬폰틀1개분
# Row 154205: 12개정도
# Row 154250: (바닐라향)바닐라오일1g(한방울)
# Row 154257: B.p14g
# Row 154281: m&m초콜릿1봉지
# Row 154297: ]우유180g
# Row 154339: B.p2g
# Row 154342: (옵션:판젤라틴1장)
# Row 154346: 4*5cm크기15개정도
# Row 154353: 15~16개분량
# Row 154405: m&m초콜릿1봉
# Row 154407: m&m초콜릿
# Row 154422: 1/2쿠킹스위트50g
# Row 154465: Butterfingers'BakingBites1봉지(283g)
# Row 154478: 15x21인치쿠키팬2개
# Row 154520: 1/2빵팬1개분
# Row 154526: 2호각각1개분
# Row 154528: B.P5g
# Row 154544:
# Row 154563: philadelphia크림치즈25g
# Row 154569: 21cm빼빼로쿠키13개
# Row 154573: 12개분량
# Row 154580: 34~35개분량
# Row 154587:
# Row 154625: (필링)우유150g
# Row 154663: 15cm원형타르트팬1개분
# Row 154710: (빨간색아이싱)슈가파우더2Ts
# Row 154714: (버터크림)버터100g
# Row 154746: m&m초콜릿1개
# Row 154775: (장식로즈)사과2개
# Row 154783: (필링)다크초콜릿80g
# Row 154785: b.s1/2ts
# Row 154787: (바닐라반죽)박력분150g
# Row 154790: b.p1/4ts
# Row 154796: 8인치또띠아3장
# Row 154934: M&M초콜릿
# Row 154948:
# Row 154956:
# Row 155040: 10cm원형타르트링2개
# Row 155071:
# Row 155072:
# Row 155089:
# Row 155127:
# Row 155128: 11.7cm빼빼로스틱35개분빼빼로스틱35개
# Row 155139:
# Row 155142:
# Row 155155:
# Row 155237: bp1/2t
# Row 155247: bp1/2t
# Row 155257: BP4g
# Row 155268:
# Row 155270: bp1/2t
# Row 155272: bp1/2t
# Row 155282:
# Row 155283: BP5g
# Row 155284: bp1ts
# Row 155294:
# Row 155328: bp1/2T
# Row 155339: BP1t
# Row 155342: BP(베이킹파우더)3g
# Row 155346: bp1t
# Row 155347: b.s1g
# Row 155353: BP1/2T
# Row 155386:
# Row 155387: bp4t
# Row 155389: BP1t
# Row 155393:
# Row 155400:
# Row 155401: bp1t
# Row 155408: B.P1작은술
# Row 155427: B.P3g
# Row 155445: '라이트라'오일60g
# Row 155457: ⓑ박력분85g
# Row 155460: b.p1/2t
# Row 155464: bp2g
# Row 155495:
# Row 155498:
# Row 155509:
# Row 155513: g박력분120g
# Row 155522:
# Row 155525:
# Row 155557: b.p2g
# Row 155562:
# Row 155582: b.p2g
# Row 155702:
# Row 155718: 3층치즈2봉
# Row 155722: (참깨라떼)토핑용참기름4~5방울
# Row 155756:
# Row 155781: candyeyeballs작은크기
# Row 155881: 12cm막대과자8개
# Row 155882: 12cm막대과자
# Row 155886: 11cm빼빼로스틱10개정도
# Row 155890: 11cm빼빼로스틱20개
# Row 155901: 24*17cm직사각팬1개분
# Row 155904: L사이즈스뎅볼
# Row 155911: B밀크초콜릿40g
# Row 155918: MSG3숟가락
# Row 155960:
# Row 155973: (코팅용)화이트초콜릿
# Row 155989:
# Row 156026:
# Row 156035:
# Row 156063: ⓑ다크커버춰20g
# Row 156114: 50%이상다크초콜릿조금
# Row 156225: 500ml공병2개
# Row 156290: 350ml공병2개
# Row 156361:
# Row 156456: ↑카누등믹스커피대체가능.
# Row 156887: (수박주스)오미자액
# Row 156891:
# Row 156959: 100%오렌지주스1컵
# Row 157002:
# Row 157088:
# Row 157145: (찹쌀.맵쌀.검은쌀)1.5kg
# Row 157155:
# Row 157439:
# Row 157486: 100%발효종170g
# Row 157689: a4용지1장
# Row 157695: (밀가루와우유계량기준은후라이팬밑바닥28cm이니팬에크기에따라양을조금
# Row 157699: A4용지1장
# Row 157704: CGV바질어니언팝콘L1통(믹서에갈아서3소주컵)
# Row 157797: HACCP소금약간
# Row 158060: 3색모둠느타리버섯80g
# Row 158152: 30cm또띠야1장
# Row 158185: .파슬리가루약간
# Row 158267: 3층크림치즈3장
# Row 158308:
# Row 158312: 10cm길이의긴떡볶이떡7개
# Row 158505: 3층치즈1장
# Row 158508: 3층치즈2장
# Row 158590: MSG1스푼
# Row 158643: msg한꼬집1g
# Row 158704: 5향중의하나인'팔각'1개
# Row 159132: CJ맛고구마1봉지
# Row 159184: 3분짜장(1팩)200g
# Row 159208: (대추)방울토마토7개
# Row 159235: (백)후추약간
# Row 159249:
# Row 159292: (시판)돈까스
# Row 159335: 3층치즈
# Row 159429: BBQ시즈닝약간
# Row 159437: ABC초코렛
# Row 159627:
# Row 159644: LA갈비2줄
# Row 159660: A1소스5TS
# Row 159662:
# Row 159760:
# Row 159816: green색소
# Row 159841: MSG약간
# Row 159863: LA갈비1대
# Row 159922: Groundbeef250g
# Row 160181:
# Row 160194: (시판)(블루화이팅)청대구냉동튀김생선4개
# Row 160196:
# Row 160220: Darksoysauce2T
# Row 160226:
# Row 160253: only유화이트참기름1T
# Row 160374: B.P1g
# Row 160412: (통)식빵100g
# Row 160425: (화이트발사믹)식초
# Row 160515: (리큐르)피오니15g
# Row 160523: m&m초콜렛(작은젤리)
# Row 160561: GrahamCrackers/다이제스티브갈아서2cup+
# Row 160573:
# Row 160606: 100%과일주스포도또는오렌지
# Row 160685: 3층치즈
# Row 160698:

# %%
recipe_ingre_pd_pre[('recipe_ingredients')][15384]
# Out:
# "{'재료': ['사각어묵8장', '양파1/2개이상', '다시육수(또는물)1.5컵이상', '양조간장1.5큰술', '3311양념장1.5큰술', '다진파약간', '깨소금약간', '참기름약간'], '3311양념장 비율': ['다시육수(또는물)3큰술', '고춧가루3큰술', '다진마늘1큰술', '액젓(국간장)1큰술']}"

# %%
recipe_ingre_pd_pre[('unit1')][15205]
# Out:
# 'g'

# %%
recipe_ingre_pd_pre[('recipe_ingredients')][12657]
# Out:
# "{'재료': ['(부침용)두부3모', '양파(大)1개', '대파1대', '애호박1개', '다시마(10*10cm)2장', '청양고추5개', '팽이버섯약간', '포도씨유4T', '참기름1T'], '양념': ['고춧가루5T', '고추장2T', '다진마늘3T', '다진생강1t', '멸치육수1L', '국간장4T', '맛술4T']}"

# %%
recipe_ingre_pd_pre[('ingredient1')][12657]
# Out:
# '양파'

# %%
recipe_ingre_pd_pre

# %%
recipe_ingre_pd_pre[recipe_ingre_pd_pre[('ingredient1')].isnull()]
# Out:
#                      recipe_title  \
# 55375                 6寸巧克力慕斯(蛋糕)
# 83473                       츄러스크림
# 92924        포슬포슬, 에어프라이어로 만든 찐감자
# 92928          에어프라이어로 뚝딱! 고구마 간식
# 95240      계란후라이 만들기,에어프라이어계란후라이,
# ...                           ...
# 168819             쌀뜨물 알뜰하게 사용는 법
# 168820            일반 현미로 발아현미 만들기
# 168821                    건포도 발효종
# 168822       간단, 저렴한 술안주 겸 반찬 3가지
# 168824  9월 28일 마이드림네식단~ 밤조림, 돼지수육
#
#                                        recipe_ingredients ingredient1  \
# 55375    {'재료': ['德芙黑巧克力+牛奶丝滑共2条56g', '吉利丁粉12', '饼干碎1t']}        None
# 83473   {'재료': ['CGV소프트아이스크림200G', 'CGV츄러스2개', 'CGV쵸코시...        None
# 92924                                {'재료': ['▶재료:감자3개']}        None
# 92928                               {'재료': ['▶재료:고구마6개']}        None
# 95240                    {'계란': ['2개소금'], '올리브유': ['1T']}        None
# ...                                                   ...         ...
# 168819                                    {'재료': ['쌀뜨물']}        None
# 168820                                   {'재료': ['일반현미']}        None
# 168821           {'재료': ['건포도50g', '물100ml', '설탕1/2작은술']}        None
# 168822  {'골뱅이고구마무침': ['골뱅이135g', '사과1/2개', '오이1/3개', '...        None
# 168824  {'밤조림 레시피': ['깐밤2kg', '설탕400~600g', '마른치자3개', ...        None
#
#        quantity1 unit1 ingredient2 quantity2 unit2 ingredient3 quantity3  ...  \
# 55375       None  None        None      None  None        None      None  ...
# 83473       None  None        None      None  None        None      None  ...
# 92924       None  None        None      None  None        None      None  ...
# 92928       None  None        None      None  None        None      None  ...
# 95240       None  None        None      None  None        None      None  ...
# ...          ...   ...         ...       ...   ...         ...       ...  ...
# 168819      None  None        None      None  None        None      None  ...
# 168820      None  None        None      None  None        None      None  ...
# 168821      None  None        None      None  None        None      None  ...
# 168822      None  None        None      None  None        None      None  ...
# 168824      None  None        None      None  None        None      None  ...
#
#        unit79 ingredient80 quantity80 unit80 ingredient81 quantity81 unit81  \
# 55375       n          nan        nan      n           na          n      n
# 83473       n          nan        nan      n           na          n      n
# 92924       n          nan        nan      n           na          n      n
# 92928       n          nan        nan      n           na          n      n
# 95240       n          nan        nan      n           na          n      n
# ...       ...          ...        ...    ...          ...        ...    ...
# 168819      n          nan        nan      n           na          n      n
# 168820      n          nan        nan      n           na          n      n
# 168821      n          nan        nan      n           na          n      n
# 168822      n          nan        nan      n           na          n      n
# 168824      n          nan        nan      n           na          n      n
#
#        ingredient82 quantity82 unit82
# 55375           nan          n      n
# 83473           nan          n      n
# 92924           nan          n      n
# 92928           nan          n      n
# 95240           nan          n      n
# ...             ...        ...    ...
# 168819          nan          n      n
# 168820          nan          n      n
# 168821          nan          n      n
# 168822          nan          n      n
# 168824          nan          n      n
#
# [7047 rows x 248 columns]

# %%
recipe_ingre_pd_pre['recipe_ingredients'][8344]

# %%
recipe_ingre_pd_pre.loc[8272]

# %%
recipe_ingre_pd_pre['recipe_ingredients'][7288]

# %%
recipe_ingre_pd_pre['recipe_title'][7288]

# %%
recipe_ingre_pd_pre['recipe_ingredients'][6427]

# %%
recipe_ingre_pd_pre['recipe_title'][6427]

# %%
recipe_ingre_pd_pre['recipe_ingredients'][6154]

# %%
recipe_ingre_pd_pre['recipe_title'][6154]

# %%
recipe_ingre_pd_pre['recipe_ingredients'][5883]

# %%
recipe_ingre_pd_pre['recipe_title'][5883]

# %%
recipe_ingre_pd_pre[recipe_ingre_pd_pre[('ingredient24')].notnull()]

# %%
recipe_ingre_pd_pre_del = recipe_ingre_pd_pre.copy()
recipe_ingre_pd_pre_del.drop([1853], axis = 0, inplace=True)
recipe_ingre_pd_pre_del.drop(['recipe_ingredients', 'ingredient21', 'quantity21', 'unit21', 'ingredient22', 'quantity22', 'unit22', 'ingredient23', 'quantity23', 'unit23', 'ingredient24', 'quantity24', 'unit24', 'ingredient25', 'quantity25', 'unit25', 'ingredient26', 'quantity26', 'unit26', 'ingredient27', 'quantity27', 'unit27', 'ingredient28', 'quantity28', 'unit28', 'ingredient29', 'quantity29', 'unit29'], axis = 1, inplace = True)
recipe_ingre_pd_pre_del

# %%
#약간/적당량 다 빼기
units = [recipe_ingre_pd_pre_del[f'ingredient{i}'] for i in range(1, 21)]

combined_ingredients = []
for unit_tuple in zip(*units):
    for unit in unit_tuple:
        if unit:  # 빈 값이 아닌 경우에만 추가
            combined_units.append(unit)

# 중복 제거
unique_units = list(set(combined_units))

from collections import Counter

unit_counts = Counter(combined_units)
for unit, count in unit_counts.items():
    print(f"{unit}: {count}번")

# %%
units = [recipe_ingre_pd_pre[f'unit{i}'] for i in range(1, 21)]

combined_units = []
for unit_tuple in zip(*units):
    for unit in unit_tuple:
        if unit:  # 빈 값이 아닌 경우에만 추가
            combined_units.append(unit)

# 중복 제거
unique_units = list(set(combined_units))

from collections import Counter

unit_counts = Counter(combined_units)
for unit, count in unit_counts.items():
    print(f"{unit}: {count}번")

# %%
#{'칼럼이름': {'찾을 문자열': '대체 문자열'}} > 이렇게 칼럼도 지정 가능하나, 그냥 unit 1~20 다 적용하려면 replace 사용해서 완벽일치하는 걸 찾아 치환하는 게 더 낫겠다 생각함
recipe_ingre_pd_pre_del.replace({'개': '100', '큰술': '15', 'g': '1', '컵': '240', '줌': '50', '공기': '210', '줄': '100', 't': '15', 'T': '15', '쪽': '5', '통': '150', '팩': '100'. '대': '100', '수저': '15', '작은수저': '5', '밥숟가락': '15', '봉지': '100', '모': '300', '그람': '1', '스푼': '15', 'Ts': '5', '주먹': '50', '티스푼': '5', '대접': '50', '숟가락': '15', '캔': '350'}, inplace = True)

# %%
recipe_step = data[['recipe_title', 'recipe_step']]
recipe_step
# Out:
#                          recipe_title  \
# 0       비빔밥재료 애호박나물 애호박볶음 아삭거리게 볶는 방법
# 1               [마늘종볶음]단짠단짠 자꾸만 손이가요~
# 2                       백종원의 부추 달걀 볶음
# 3           간단하게 맛난 반찬 만들기 '베이컨 버섯볶음'
# 4                     고소하고 향긋한 깻잎들깨볶음
# ...                               ...
# 168835                            콩비지
# 168836                  바닐라 견과류 아이스크림
# 168837                    무즙 얹은 흰살 생선
# 168838                    무즙 얹은 흰살 생선
# 168839                 머스크 멜론 맛있게 깍는법
#
#                                               recipe_step
# 0       ['#1 호박은 0.5cm 정도 두께로 자른 후 편하게 채썰어주세요.', '#2 너...
# 1       ['#1 마늘종 300g을 4cm길이로 썰어주세요', '#2 달궈진 마른팬에 건새우...
# 2       ['#1 부추는 적당한 크기로 썰고 달걀은 여러번 저어서 곱게 풀어 놓습니다', '...
# 3       ['#1 버섯과 양파를 잘라줍니다.', '#2 올리브유를 두르고 양파와 다진마늘을 ...
# 4       ['#1 깻잎 을 씻어줍니다.저는 자잘한 깻잎순으로 했지만. 그냥 큰 잎을 잘라서 ...
# ...                                                   ...
# 168835                                                 []
# 168836                                                 []
# 168837                                                 []
# 168838                                                 []
# 168839                                                 []
#
# [168840 rows x 2 columns]

# %%
recipe_step[('recipe_step')][9704]
# Out:
# "['#1 감자 4개 껍질을 벗겨 삶아주세요.', '#2 감자가 다 익으면 큰볼에 담으시고 다진파를 2수푼 넣어주세요. fresh coriander 를 잘게 잘라 넣으셔도 좋습니다.', '#3 준비된 향신료를 모두 넣어주세요. Coriander powder, chille powder 넣어주셔도 좋아요. 저는 그냥 집에 있는 걸로 했어요. Kasuri Methi 는 넣지 않으셔도 되요. 초록색 이 Kasuri Methi 예요. 정말 향기가 좋아요.', '#4 감자를 잘 으깨어 주세요.', '#5 Chapatti 1장을 깔고 으깬 감자를 사이에 넣고 반으로 접어주세요. 2장으로 샌드위치처럼 만들어도 됩니다.', '#6 찜기에 약 10분간 쪄주세요', '#7 프라이팬에 올리브유 넉넉히 두르고 앞뒤로 노릇노릇하게 구워주세요. 구우면서 Cumin seed 를 조금씩 뿌려주세요. Chilly Powder 뿌려주셔도 좋아요.', '#8 뜨거울때 드세요', '#9 사용된 향신료 입니다. 이상하게 사진이 이렇게 들어가네요.. ㅠㅠ', '#10 콜스에서 판매하는 냉동 Chapatti 예요. 간단하게 프라이팬에 구워서 드실수 있습니다.']"

# %%
recipe_servings = recipe[['RECIPE_SUMMARY1']]
recipe_servings

# %%
query = 'select * from title_ingre_unit'
title_ingre_unit = oracleTopd(query)
title_ingre_unit

# %%
query = 'select * from nutri_multi_table'
nutri_multi_table = oracleTopd(query)
nutri_multi_table

# %%
query = 'select * from recipe_nutrient'
recipe_nutrient = oracleTopd(query)
recipe_nutrient

# %% [markdown]
# ------------ 구분선 ------------

# %%
recipe.info()
#진짜로 NA인 것도 있는데, 그냥 [] 이런 식으로 정보가 들어가 있어 내용이 없는 경우도 있음
#여기서 임베딩에 필요한/필수적인/내가 활용할 column이 뭐가 있는지 다시 잘 생각해볼 것!
#레시피 데이터를 어떻게 정규화하고 어떤 식으로 전처리를 할 것인지도 고민!

# %%
nutri.info()
#영양소 측면에 들어가면 최소 46, 최대 77,100임. 없더라도 상관없음?
#이 영양소들을 식재료와 어떻게 합칠 것인가? one-hot encoding처럼?
#임베딩 관련해서 어떠한 방법들이 있고, 어떻게 이루어지고 있는지 옛날 논문이랑 요즘 SOTA 방식 연구
#여기서도 사용할 column들 확인할 것! 앞부분의 대분류 등은 나중에 분류/sort 기준으로?
#여기서도 정규화/전처리 고민!

# %%
import pandas as pd

toy = pd.read_csv("data/toy.csv") #레시피 toy data

# %%
def oracleTopd(query):
    import oracledb as od
    import pandas as pd
    import config

    # db connection
    od.init_oracle_client(lib_dir=r"C:\Program Files\Oracle\instantclient_21_12")
    conn = od.connect(user = config.DB_CONFIG['user'], password = config .DB_CONFIG['password'], dsn = config.DB_CONFIG['dsn'])
    exe = conn.cursor()
    exe.execute(query)

    row = exe.fetchall() # row 불러오기

    column_name = exe.description # column 불러오기
    columns=[]

    for i in column_name:
        columns.append(i[0])

    # row, column을 pandas DataFrame으로 나타내기
    result = pd.DataFrame(row, columns=columns)

    # dtype clob을 string으로 변환
    for clob in result.columns:
        if result[clob].dtype == object:
            result[clob] = result[clob].astype("string")

    conn.close()

    return result

# %%
query = 'select * from recipe_data_table where rownum <= 100'
recipe = oracleTopd(query)
recipe

# %%
recipe_ingre = recipe[['RECIPE_TITLE', 'RECIPE_INGREDIENTS']]
recipe_ingre
