# %%
#func.py
import oracledb as od
import pandas as pd
import numpy as np
import config
from tqdm import tqdm
import ast
import re
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
from scipy.linalg import svd

# %%
def load_recipe(n = 166511):
    od.init_oracle_client(lib_dir=r"C:\Program Files\Oracle\instantclient_21_12") # db connection
    conn = od.connect(user = config.DB_CONFIG['user'], password = config.DB_CONFIG['password'],  dsn = config.DB_CONFIG['dsn'])
    exe = conn.cursor()
    exe.execute(f'select * from recipe_table where rownum <= {n}')
    row = exe.fetchall() # row 불러오기
    column_name = exe.description # column 불러오기
    columns=[]
    for i in column_name:
        columns.append(i[0])
    result = pd.DataFrame(row, columns=columns) # row, column을 pandas DataFrame으로 나타내기
    result.rename(mapper=str.lower, axis='columns', inplace=True)
    conn.close()
    return result

func = load_recipe()

# %%
func
# Out:
#                                        recipe_url  \
# 0       http://www.10000recipe.com/recipe/6899436
# 1       http://www.10000recipe.com/recipe/6846414
# 2       http://www.10000recipe.com/recipe/6922757
# 3       http://www.10000recipe.com/recipe/6188436
# 4       http://www.10000recipe.com/recipe/6892998
# ...                                           ...
# 166506  http://www.10000recipe.com/recipe/6968010
# 166507  http://www.10000recipe.com/recipe/6909255
# 166508  http://www.10000recipe.com/recipe/6895249
# 166509  http://www.10000recipe.com/recipe/6859337
# 166510  http://www.10000recipe.com/recipe/6960715
#
#                         recipe_title recipe_summary1 recipe_summary2  \
# 0               백종원 콩나물불고기 간단해서 조하 ♪             4인분          60분 이내
# 1                     부드럽고 고소한 [새우죽]             2인분          60분 이내
# 2                            자연산 홍합전             2인분          15분 이내
# 3        미니떡갈비 버거와 크레이프, 생크림삼겹살 스파게티             5인분          60분 이내
# 4               열무물김치쉽게담기, 시원한국물열무김치             4인분          60분 이내
# ...                              ...             ...             ...
# 166506                   일본식 닭조림 만들기             3인분          30분 이내
# 166507         블랙라벨스테이크 깨쟁이요리 럭셔리도시락             2인분          10분 이내
# 166508  특별한 별미 곤약조림 탱글탱글 짭쪼름 맛있는 밑반찬             4인분          60분 이내
# 166509                오믈렛만드는법*브런치만들기             1인분          30분 이내
# 166510       누들 로제 떡볶이 만들기 (황금비율양념장)             3인분          30분 이내
#
#        recipe_summary3                                 recipe_ingredients  \
# 0                  아무나  {'재료': ['소고기불고기거리400g', '콩나물1줌', '양파1개', '깻잎10...
# 1                  아무나  {'재료': ['새우(큰사이즈)5마리', '당근1/2개', '감자(중간크기)2개',...
# 2                   초급  {'재료': ['자연산홍합25개', '홍합육수1컵반', '부침가루1컵반', '달걀1...
# 3                   중급  {'미니떡갈비 버거': ['모닝빵5개', '머스터드소스', '다진소고기150g', ...
# 4                   초급  {'재료': ['열무1단', '양파5개', '당근1개', '찹쌀1/2컵', '배즙5...
# ...                ...                                                ...
# 166506              초급  {'재료': ['닭다리또는닭봉1팩', '감자2개', '당근1/2개', '표고버섯3개...
# 166507             아무나  {'재료': ['블랙라벨스테이크260g', '양파1/3', '그린빈4개', '방울토...
# 166508             아무나  {'재료': ['통곤약600g', '물900ml', '간장60ml', '매실액10m...
# 166509             아무나  {'계란 오믈렛 재료': ['계란2개', '소금약간', '소세지약간', '모짜렐라치...
# 166510             아무나  {'재료': ['누들떡500g', '긴소세지1개', '생크림200ml', '물500...
#
#                                               recipe_step  \
# 0       ['#1 야채는 취향이나 냉장고사정에따라 더 추가하셔도 좋고요저는 고기를 800g ...
# 1       ['#1 냉동새우를 해동한 후흐르는 물에 깨끗히 씻어준비합니다.', '#2 등을 반...
# 2       ['#1 자연산 홍합인 섭은 양식에 비해 껍질이 두껍고 크기가 커요. 해초나 이물질...
# 3       ['#1 미니 떡갈비 버거: 다진 소고기, 다진돼지고기에 고기 양념장을 구워주세요....
# 4       ['#1 우선 젤 중요한 육수요번엔 육수에 여러가지를 넣었어요.육수가 맛있어야 열무...
# ...                                                   ...
# 166506  ['#1 재료를 준비합니다.', '#2 닭을 손질합니다.닭에 붙어있는 노란 기름덩어...
# 166507  ['#1 재료준비 고기+야채', '#2 준비된고기는 소금.후추뿌리고오일을한스푼문질러...
# 166508  ['#1 통곤약을 흐르는 물에 한번 헹궈내고 1cm두께로 썰어줍니다.', '#2 곤...
# 166509  ['#1 이제 계란 오믈렛을 준비할게요.소세지는 끓는 물에 데쳐서 준비하고체더치즈와...
# 166510  ['#1 준비한 재료들입니다소세지는 비엔나소세지가 없어서 큰소세지를 잘라서 대체했어...
#
#                                                recipe_tag  recipe_comment  \
# 0         ['콩나물불고기', '백종원콩나물불고기', '콩나물불고기만드는법', '백종원레시피']             0.0
# 1                                                      []             2.0
# 2       ['홍합전', '홍합', '자연산홍합', '자연산홍합전', '섭전', '부침요리',...             0.0
# 3                                                      []             2.0
# 4       ['열무물김치', '여름별미물김치', '육수열무물김치', '열무물김치담기', '열무...             2.0
# ...                                                   ...             ...
# 166506  ['닭조림', '일본식닭조림', '일본식닭조림만들기', '닭조림레시피', '간장닭조...             0.0
# 166507            ['스테이크', '깨쟁이요리', '주말요리', '술안주', '소고기']             0.0
# 166508             ['밑반찬', '곤약조림', '조림요리', '곤약요리', '초간단']             0.0
# 166509             ['강아지오믈렛', '오믈렛만들기', '계란오믈렛', '치즈오믈렛']             2.0
# 166510  ['배떡', '로제', '배떡로제', '집에서로제', '로제떡볶이황금비율', '이색...             0.0
#
#         recipe_view recipe_category_type recipe_category_method  \
# 0            2019.0                 메인반찬                     볶음
# 1            3074.0                밥/죽/떡                    끓이기
# 2            1175.0                   기타                     부침
# 3            6745.0                  디저트                     기타
# 4           11000.0             김치/젓갈/장류                     절임
# ...             ...                  ...                    ...
# 166506        501.0                 메인반찬                     조림
# 166507       1001.0                   양식                     굽기
# 166508       5183.0                  밑반찬                     조림
# 166509      16000.0                   양식                     부침
# 166510       2566.0                밥/죽/떡                    끓이기
#
#        recipe_category_situation
# 0                             일상
# 1                            영양식
# 2                             일상
# 3                             간식
# 4                             일상
# ...                          ...
# 166506                        일상
# 166507                        일상
# 166508                        일상
# 166509                        일상
# 166510                        일상
#
# [166511 rows x 13 columns]

# %%
# def recipe_preprocessing(raw):
#     data = raw.loc[raw['recipe_ingredients'].notnull()].copy()  # None 값 제거
#     def ano_pre(raw):    
#         def clean_ingredients(ingredients):
#             if ingredients is not None:
#                 ingredients = ingredients.replace('\\ufeff', '').replace('\\u200b', '')
#             return ingredients
    
#         data["recipe_ingredients"] = clean_ingredients(data["recipe_ingredients"])
    
#         def not_empty_ingredients(row):
#             #return row['recipe_ingredients'].str.strip() != '{}'
#             return row[row.recipe_ingredients != '{}'] # 결측치 제거

            # #return row['recipe_ingredients'].strip() != '{}'
            # #return row[row.recipe_ingredients != '{}']
            # idx = row[row['recipe_ingredients'] == '{}'].index
            # row.drop(idx, inplace = True) # 결측치 제거
        
#         return not_empty_ingredients(data)

#     data = data[data.apply(ano_pre, axis=1)]
#     result = data[['recipe_title', 'recipe_ingredients']]

#     return result

def recipe_preprocessing(raw):
    data = raw.loc[raw['recipe_ingredients'].notnull()].copy()  # None 값 제거

    def clean_ingredients(ingredients):
        if ingredients is not None:
            ingredients = ingredients.replace('\\ufeff', '').replace('\\u200b', '')
        return ingredients

    def not_empty_ingredients(row):
        return row['recipe_ingredients'].strip() != '{}' # 결측치 제거

    data["recipe_ingredients"] = data["recipe_ingredients"].apply(clean_ingredients)
    data = data[data.apply(not_empty_ingredients, axis=1)]
    result = data[['recipe_title', 'recipe_ingredients']]

    return result

func_pre = recipe_preprocessing(func)

# %%
func_pre
# Out:
#                         recipe_title  \
# 0               백종원 콩나물불고기 간단해서 조하 ♪
# 1                     부드럽고 고소한 [새우죽]
# 2                            자연산 홍합전
# 3        미니떡갈비 버거와 크레이프, 생크림삼겹살 스파게티
# 4               열무물김치쉽게담기, 시원한국물열무김치
# ...                              ...
# 166506                   일본식 닭조림 만들기
# 166507         블랙라벨스테이크 깨쟁이요리 럭셔리도시락
# 166508  특별한 별미 곤약조림 탱글탱글 짭쪼름 맛있는 밑반찬
# 166509                오믈렛만드는법*브런치만들기
# 166510       누들 로제 떡볶이 만들기 (황금비율양념장)
#
#                                        recipe_ingredients
# 0       {'재료': ['소고기불고기거리400g', '콩나물1줌', '양파1개', '깻잎10...
# 1       {'재료': ['새우(큰사이즈)5마리', '당근1/2개', '감자(중간크기)2개',...
# 2       {'재료': ['자연산홍합25개', '홍합육수1컵반', '부침가루1컵반', '달걀1...
# 3       {'미니떡갈비 버거': ['모닝빵5개', '머스터드소스', '다진소고기150g', ...
# 4       {'재료': ['열무1단', '양파5개', '당근1개', '찹쌀1/2컵', '배즙5...
# ...                                                   ...
# 166506  {'재료': ['닭다리또는닭봉1팩', '감자2개', '당근1/2개', '표고버섯3개...
# 166507  {'재료': ['블랙라벨스테이크260g', '양파1/3', '그린빈4개', '방울토...
# 166508  {'재료': ['통곤약600g', '물900ml', '간장60ml', '매실액10m...
# 166509  {'계란 오믈렛 재료': ['계란2개', '소금약간', '소세지약간', '모짜렐라치...
# 166510  {'재료': ['누들떡500g', '긴소세지1개', '생크림200ml', '물500...
#
# [157263 rows x 2 columns]

# %%
func_pre
# Out:
#                         recipe_title  \
# 0           나 순대라고 말 못해요! HACCP인증 제품
# 1                            시래기 된장국
# 2                         바질크림파스타만들기
# 3            돼지 수육 삶는법? 보쌈 삶지 말고 찌세요
# 4                     브런치 참치에그샐러드만들기
# ...                              ...
# 166506                   일본식 닭조림 만들기
# 166507         블랙라벨스테이크 깨쟁이요리 럭셔리도시락
# 166508  특별한 별미 곤약조림 탱글탱글 짭쪼름 맛있는 밑반찬
# 166509                오믈렛만드는법*브런치만들기
# 166510       누들 로제 떡볶이 만들기 (황금비율양념장)
#
#                                        recipe_ingredients
# 0       {'재료': ['HACCP인증순대90g', 'HACCP인증체다치즈4장', 'HACC...
# 1       {'재료': ['신광에코팜시래기1팩(300g)', '된장2T', '멸치1주먹', '...
# 2       {'재료': ['폰타나제노바치즈&바질페스토1병', '통마늘6알', '베이컨3줄', ...
# 3       {'수육 위에 얹어줄 재료': ['돼지고기3덩이', '양파1개', '대파또는쪽파원하...
# 4       {'재료': ['달걀(삶은거)4개', '참치캔1개', '상추(or양상추)', '게맛...
# ...                                                   ...
# 166506  {'재료': ['닭다리또는닭봉1팩', '감자2개', '당근1/2개', '표고버섯3개...
# 166507  {'재료': ['블랙라벨스테이크260g', '양파1/3', '그린빈4개', '방울토...
# 166508  {'재료': ['통곤약600g', '물900ml', '간장60ml', '매실액10m...
# 166509  {'계란 오믈렛 재료': ['계란2개', '소금약간', '소세지약간', '모짜렐라치...
# 166510  {'재료': ['누들떡500g', '긴소세지1개', '생크림200ml', '물500...
#
# [157263 rows x 2 columns]

# %%
func_pre[func_pre['recipe_title'].isnull()].index
# Out:
#        recipe_title                                 recipe_ingredients
# 46510          None  {'재료': ['솎음열무2단', '대파2줄', '적양파1/2개'], '양념': ['...
# 97279          None   {'재료': ['계란3개', '떡20g', '양파1개', '햄1통', '케찹적당량']}
# 141211         None               {'재료': ['말차가루', '딸기', '버터', '제노와즈']}
# 147046         None  {'재료': ['코팅다크초콜릿130g', '코팅화이트초콜릿130g', '마시멜로우'...

# %%
def split_ingredient(data):
    for i in range(1, 75):
        data.loc[:, f'ingredient{i}'] = None
        data.loc[:, f'quantity{i}'] = None
        data.loc[:, f'unit{i}'] = None


    non_matching_items = {} # 패턴과 일치하지 않는 데이터를 저장할 딕셔너리

    for idx, row in tqdm(data.iterrows(), total=data.shape[0]): #tqdm으로 진행상황 확인
        if row['recipe_ingredients']:
            ingredients_dict = ast.literal_eval(row["recipe_ingredients"]) #딕셔너리 형태로 저장된 recipe_ingredients 불러오기
            ingredient_count = 1
            for category, items in ingredients_dict.items(): #category : 재료, 양념재료, items: 사과1개, 돼지고기600g
                if items:  # 아이템이 존재하는 경우
                    for item in items:
                        match = re.match(r'([가-힣a-zA-Z]+(\([가-힣a-zA-Z]+\))?|\d+[가-힣a-zA-Z]*|\([가-힣a-zA-Z]+\)[가-힣a-zA-Z]+)([\d.+/~-]*)([가-힣a-zA-Z]+|약간|조금)?', item) # 정규식
                        if match:
                            ingredient, _, quantity, unit = match.groups()

                            data.loc[idx, f'ingredient{ingredient_count}'] = ingredient
                            data.loc[idx, f'quantity{ingredient_count}'] = quantity
                            data.loc[idx, f'unit{ingredient_count}'] = unit

                            ingredient_count += 1
                        else:
                            # 패턴과 일치하지 않는 경우 딕셔너리에 추가
                            non_matching_items[idx] = item
        else:
            pass

    # 패턴과 일치하지 않는 데이터 출력 X => 날려버리기!
    for idx, item in non_matching_items.items():
        print(f'Row {idx}: {item}')
#        recipe_ingre_pd_pre.drop([idx], axis=0, inplace=True)
    return data

# %%
func_pre['recipe_ingredients'][77640:77650]
# Out:
# 81888                                  {'재료': ['전복원하는만큼']}
# 81889    {'주재료': ['돼지고기통째로된것'], '준비물': ['일회용비닐'], '보관방법...
# 81890    {'재료': ['도토리묵2모', '상추20장', '새싹2팩', '오이1개', '당근...
# 81891    {'재료': ['엔젤헤어파스타2인분', '골뱅이통조림1캔', '올리브유2큰술', '...
# 81892    {'재료': ['케찹4T', '굴소스4T', '간장2T', '우스터드소스4T', '...
# 81893    {'재료': ['우동면1개', '냉동솔방울오징어12개', '작은양파1/2개', '청...
# 81896    소시지)매콤 꼬치,4인분,60분 이내,아무나,"{'재료': ['사각어묵8장', '떡...
# 81897    {'필수재료': ['스파게티면1인분', '꽃게2마리', '마늘2톨', '페페로치노2...
# 81898    {'재료': ['에그누들2개', '새우3마리', '해물믹스조금', '숙주적당량', ...
# 81899    {'재료': ['스파게티면2인분', '완숙방울토마토2개', '양파1/2개', '마늘...
# Name: recipe_ingredients, dtype: object

# %%
del_idx = func_pre[func_pre['recipe_ingredients'].str.startswith('소시지')].index

# %%
func_pre.drop(del_idx, inplace=True)

# %%
func_pre_split = split_ingredient(func_pre)
# Out:
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'ingredient{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'quantity{i}'] = None
# C:\Users\glori\AppData\Local\Temp\ipykernel_11840\2982804087.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data.loc[:, f'unit{i}'] = None
#  64%|████████████████████████████████████████████████████████████████▉                                    | 101097/157262 [04:38<02:39, 352.83it/s]

# %%
func_pre_split

# %%
for_del = func_pre_split[func_pre_split[('ingredient1')].isnull()].index

# %%
func_pre_split.drop([{for_del}], axis=0, inplace=True)

# %%
func_pre_split[func_pre_split[('unit1')].isnull()]

# %%
recipe_ingre_pd_pre[recipe_ingre_pd_pre[('ingredient24')].notnull()]

# %%
recipe_ingre_pd_pre_del = recipe_ingre_pd_pre.copy()
recipe_ingre_pd_pre_del.drop([1853], axis = 0, inplace=True)
recipe_ingre_pd_pre_del.drop(['recipe_ingredients', 'ingredient21', 'quantity21', 'unit21', 'ingredient22', 'quantity22', 'unit22', 'ingredient23', 'quantity23', 'unit23', 'ingredient24', 'quantity24', 'unit24', 'ingredient25', 'quantity25', 'unit25', 'ingredient26', 'quantity26', 'unit26', 'ingredient27', 'quantity27', 'unit27', 'ingredient28', 'quantity28', 'unit28', 'ingredient29', 'quantity29', 'unit29'], axis = 1, inplace = True)
recipe_ingre_pd_pre_del

# %%
#약간/적당량 다 빼기
units = [recipe_ingre_pd_pre_del[f'ingredient{i}'] for i in range(1, 21)]

combined_ingredients = []
for unit_tuple in zip(*units):
    for unit in unit_tuple:
        if unit:  # 빈 값이 아닌 경우에만 추가
            combined_units.append(unit)

# 중복 제거
unique_units = list(set(combined_units))

from collections import Counter

unit_counts = Counter(combined_units)
for unit, count in unit_counts.items():
    print(f"{unit}: {count}번")
