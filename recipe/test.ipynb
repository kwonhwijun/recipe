# %%
import oracledb as od
import config
import pandas as pd
import rec as rec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\HwijunKwon\github\recipe\recipe\test.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/HwijunKwon/github/recipe/recipe/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import oracledb as od
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HwijunKwon/github/recipe/recipe/test.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import config
#       <a href='vscode-notebook-cell:/c%3A/Users/HwijunKwon/github/recipe/recipe/test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/HwijunKwon/github/recipe/recipe/test.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import rec as rec
#
# ModuleNotFoundError: No module named 'config'

# %%
raw = rec.load_recipe(num =100)
raw1 =rec.recipe_preprocessing(raw)
raw2 = rec.split_ingredient(raw1)
rec.process_ingredient(raw2)
# Out:
# 100%|██████████| 96/96 [00:00<00:00, 306.45it/s]
# c:\Users\HwijunKwon\github\recipe\recipe\rec.py:105: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dataframe[unit_col_name] = np.where(dataframe[col_name].notna() & dataframe[col_name].str.contains(pattern, regex=True), replacement, dataframe[unit_col_name])
#                          recipe_title  \
# 0                   호박 새우젓찌개 만드는 방법~★
# 1                        바글바글 전복 된장찌개
# 2   순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!
# 3                       정통 바지락 순두부 찌개
# 4                         크림토마토 비프 스튜
# ..                                ...
# 95    달달한 바나나와 오도독 아몬드가 씹히는 치지한 치즈토스트
# 96                     노란색 양배추전 # 치즈전
# 97           아이들도 좋아하는 단맛 가득한 양배추 볶음밥
# 98      추운 겨울 따듯함을 담은 달콤함 ' 꿀고구마 찹쌀전'
# 99                             고구마 찰전
#
#                                    recipe_ingredients  \
# ...

# %%
# Out:
# c:\Users\HwijunKwon\github\recipe\recipe\rec.py:103: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dataframe[unit_col_name] = np.where(dataframe[col_name].notna() & dataframe[col_name].str.contains(pattern, regex=True), replacement, dataframe[unit_col_name])
#                                   recipe_title  \
# 0                            호박 새우젓찌개 만드는 방법~★
# 1                                 바글바글 전복 된장찌개
# 2            순두부찌개....오도독 씹히는 미더덕이 들어간 순두부찌개!!
# 3                                정통 바지락 순두부 찌개
# 4                                  크림토마토 비프 스튜
# ..                                         ...
# 995                                  버섯 와인 닭조림
# 996                             복숭아 우유 아이스크림~*
# 997                                   토마토 아이스바
# 998                           < 간식> 감자칩 / 전자렌지
# 999  노오븐! 간단한 크렘브륄레 만들기 [NO BAKE] Creme brulee
#
# ...
